# %% [markdown]
# <a href="https://colab.research.google.com/github/hchristiaan/TrainCNN4SignatureVerification/blob/master/ProjectCode_Transfer_0_lr000001_seed30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Please note that:
#     # - Means comment explaining the code
#     ### - Means things that need to be addressed

# %%
# Henri code

from google.colab import auth
auth.authenticate_user()

import requests
gcloud_token = !gcloud auth print-access-token
gcloud_tokeninfo = requests.get('https://www.googleapis.com/oauth2/v3/tokeninfo?access_token=' + gcloud_token[0]).json()
email = gcloud_tokeninfo['email']
username = email.split('@')[0]
print(username)
# Out:
# jlu851

# %%
# Import all required repositories for the project
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2

import keras
import keras.backend as K
import tensorflow as tf
from keras import applications
from keras.models import Model
from keras.layers import Flatten, Dense, Input,concatenate
from keras.optimizers import Adam
from keras.models import load_model, model_from_json

import random
# Out:
# Using TensorFlow backend.

# %%
# Import the google drive to upload the data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Unzip the image dataset
# !unzip '/content/drive/Team Drives/inputdataset/UTSig.zip' -d /content
# Out:
# Archive:  /content/drive/Team Drives/inputdataset/UTSig.zip
#    creating: /content/UTSig/Forgery/
#    creating: /content/UTSig/Forgery/Opposite Hand/
#    creating: /content/UTSig/Forgery/Opposite Hand/1/
#   inflating: /content/UTSig/Forgery/Opposite Hand/1/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/1/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/1/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/10/
#   inflating: /content/UTSig/Forgery/Opposite Hand/10/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/10/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/10/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/100/
#   inflating: /content/UTSig/Forgery/Opposite Hand/100/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/100/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/100/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/101/
#   inflating: /content/UTSig/Forgery/Opposite Hand/101/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/101/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/101/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/102/
#   inflating: /content/UTSig/Forgery/Opposite Hand/102/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/102/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/102/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/103/
#   inflating: /content/UTSig/Forgery/Opposite Hand/103/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/103/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/103/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/104/
#   inflating: /content/UTSig/Forgery/Opposite Hand/104/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/104/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/104/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/105/
#   inflating: /content/UTSig/Forgery/Opposite Hand/105/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/105/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/105/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/106/
#   inflating: /content/UTSig/Forgery/Opposite Hand/106/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/106/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/106/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/107/
#   inflating: /content/UTSig/Forgery/Opposite Hand/107/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/107/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/107/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/108/
#   inflating: /content/UTSig/Forgery/Opposite Hand/108/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/108/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/108/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/109/
#   inflating: /content/UTSig/Forgery/Opposite Hand/109/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/109/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/109/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/11/
#   inflating: /content/UTSig/Forgery/Opposite Hand/11/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/11/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/11/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/110/
#   inflating: /content/UTSig/Forgery/Opposite Hand/110/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/110/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/110/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/111/
#   inflating: /content/UTSig/Forgery/Opposite Hand/111/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/111/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/111/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/112/
#   inflating: /content/UTSig/Forgery/Opposite Hand/112/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/112/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/112/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/113/
#   inflating: /content/UTSig/Forgery/Opposite Hand/113/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/113/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/113/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/114/
#   inflating: /content/UTSig/Forgery/Opposite Hand/114/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/114/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/114/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/115/
#   inflating: /content/UTSig/Forgery/Opposite Hand/115/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/115/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/115/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/12/
#   inflating: /content/UTSig/Forgery/Opposite Hand/12/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/12/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/12/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/13/
#   inflating: /content/UTSig/Forgery/Opposite Hand/13/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/13/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/13/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/14/
#   inflating: /content/UTSig/Forgery/Opposite Hand/14/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/14/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/14/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/15/
#   inflating: /content/UTSig/Forgery/Opposite Hand/15/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand
1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/81/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/81/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/82/
#   inflating: /content/UTSig/Forgery/Opposite Hand/82/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/82/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/82/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/83/
#   inflating: /content/UTSig/Forgery/Opposite Hand/83/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/83/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/83/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/84/
#   inflating: /content/UTSig/Forgery/Opposite Hand/84/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/84/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/84/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/85/
#   inflating: /content/UTSig/Forgery/Opposite Hand/85/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/85/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/85/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/86/
#   inflating: /content/UTSig/Forgery/Opposite Hand/86/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/86/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/86/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/87/
#   inflating: /content/UTSig/Forgery/Opposite Hand/87/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/87/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/87/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/88/
#   inflating: /content/UTSig/Forgery/Opposite Hand/88/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/88/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/88/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/89/
#   inflating: /content/UTSig/Forgery/Opposite Hand/89/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/89/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/89/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/9/
#   inflating: /content/UTSig/Forgery/Opposite Hand/9/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/9/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/9/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/90/
#   inflating: /content/UTSig/Forgery/Opposite Hand/90/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/90/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/90/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/91/
#   inflating: /content/UTSig/Forgery/Opposite Hand/91/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/91/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/91/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/92/
#   inflating: /content/UTSig/Forgery/Opposite Hand/92/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/92/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/92/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/93/
#   inflating: /content/UTSig/Forgery/Opposite Hand/93/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/93/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/93/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/94/
#   inflating: /content/UTSig/Forgery/Opposite Hand/94/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/94/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/94/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/95/
#   inflating: /content/UTSig/Forgery/Opposite Hand/95/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/95/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/95/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/96/
#   inflating: /content/UTSig/Forgery/Opposite Hand/96/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/96/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/96/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/97/
#   inflating: /content/UTSig/Forgery/Opposite Hand/97/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/97/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/97/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/98/
#   inflating: /content/UTSig/Forgery/Opposite Hand/98/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/98/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/98/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/99/
#   inflating: /content/UTSig/Forgery/Opposite Hand/99/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/99/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/99/3.tif
#    creating: /content/UTSig/Forgery/Simple/
#    creating: /content/UTSig/Forgery/Simple/1/
#   inflating: /content/UTSig/Forgery/Simple/1/11.tif
#   inflating: /content/UTSig/Forgery/Simple/1/12.tif
#   inflating: /content/UTSig/Forgery/Simple/1/13.tif
#   inflating: /content/UTSig/Forgery/Simple/1/14.tif
#   inflating: /content/UTSig/Forgery/Simple/1/15.tif
#   inflating: /content/UTSig/Forgery/Simple/1/16.tif
#   inflating: /content/UTSig/Forgery/Simple/1/21.tif
#   inflating: /content/UTSig/Forgery/Simple/1/22.tif
#   inflating: /content/UTSig/Forgery/Simple/1/23.tif
#   inflating: /content/UTSig/Forgery/Simple/1/24.tif
#   inflating: /content/UTSig/Forgery/Simple/1/25.tif
#   inflating: /content/UTSig/Forgery/Simple/1/26.tif
#   inflating: /content/UTSig/Forgery/Simple/1/31.tif
#   inflating: /content/UTSig/Forgery/Simple/1/32.tif
#   inflating: /content/UTSig/Forgery/Simple/1/33.tif
#   inflating: /content/UTSig/Forgery/Simple/1/34.tif
#   inflating: /content/UTSig/Forgery/Simple/1/35.tif
#   inflating: /content/UTSig/Forgery/Simple/1/36.tif
#   inflating: /content/UTSig/Forgery/Simple/1/41.tif
#   inflating: /content/UTSig/Forgery/Simple/1/42.tif
#   inflating: /content/UTSig/Forgery/Simple/106/63.tif
#   inflating: /content/UTSig/Forgery/Simple/106/64.tif
#   inflating: /content/UTSig/Forgery/Simple/106/65.tif
#   inflating: /content/UTSig/Forgery/Simple/106/66.tif
#    creating: /content/UTSig/Forgery/Simple/107/
#   inflating: /content/UTSig/Forgery/Simple/107/11.tif
#   inflating: /content/UTSig/Forgery/Simple/107/12.tif
#   inflating: /content/UTSig/Forgery/Simple/107/13.tif
#   inflating: /content/UTSig/Forgery/Simple/107/14.tif
#   inflating: /content/UTSig/Forgery/Simple/107/15.tif
#   inflating: /content/UTSig/Forgery/Simple/107/16.tif
#   inflating: /content/UTSig/Forgery/Simple/107/21.tif
#   inflating: /content/UTSig/Forgery/Simple/107/22.tif
#   inflating: /content/UTSig/Forgery/Simple/107/23.tif
#   inflating: /content/UTSig/Forgery/Simple/107/24.tif
#   inflating: /content/UTSig/Forgery/Simple/107/25.tif
#   inflating: /content/UTSig/Forgery/Simple/107/26.tif
#   inflating: /content/UTSig/Forgery/Simple/107/31.tif
#   inflating: /content/UTSig/Forgery/Simple/107/32.tif
#   inflating: /content/UTSig/Forgery/Simple/107/33.tif
#   inflating: /content/UTSig/Forgery/Simple/107/34.tif
#   inflating: /content/UTSig/Forgery/Simple/107/35.tif
#   inflating: /content/UTSig/Forgery/Simple/107/36.tif
#   inflating: /content/UTSig/Forgery/Simple/107/41.tif
#   inflating: /content/UTSig/Forgery/Simple/107/42.tif
#   inflating: /content/UTSig/Forgery/Simple/107/43.tif
#   inflating: /content/UTSig/Forgery/Simple/107/44.tif
#   inflating: /content/UTSig/Forgery/Simple/107/45.tif
#   inflating: /content/UTSig/Forgery/Simple/107/46.tif
#   inflating: /content/UTSig/Forgery/Simple/107/51.tif
#   inflating: /content/UTSig/Forgery/Simple/107/52.tif
#   inflating: /content/UTSig/Forgery/Simple/107/53.tif
#   inflating: /content/UTSig/Forgery/Simple/107/54.tif
#   inflating: /content/UTSig/Forgery/Simple/107/55.tif
#   inflating: /content/UTSig/Forgery/Simple/107/56.tif
#   inflating: /content/UTSig/Forgery/Simple/107/61.tif
#   inflating: /content/UTSig/Forgery/Simple/107/62.tif
#   inflating: /content/UTSig/Forgery/Simple/107/63.tif
#   inflating: /content/UTSig/Forgery/Simple/107/64.tif
#   inflating: /content/UTSig/Forgery/Simple/107/65.tif
# ...
#   inflating: /content/UTSig/Genuine/88/8.tif
#   inflating: /content/UTSig/Genuine/88/9.tif
#    creating: /content/UTSig/Genuine/89/
#   inflating: /content/UTSig/Genuine/89/1.tif
#   inflating: /content/UTSig/Genuine/89/10.tif
#   inflating: /content/UTSig/Genuine/89/11.tif
#   inflating: /content/UTSig/Genuine/89/12.tif
#   inflating: /content/UTSig/Genuine/89/13.tif
#   inflating: /content/UTSig/Genuine/89/14.tif
#   inflating: /content/UTSig/Genuine/89/15.tif
#   inflating: /content/UTSig/Genuine/89/16.tif
#   inflating: /content/UTSig/Genuine/89/17.tif
#   inflating: /content/UTSig/Genuine/89/18.tif
#   inflating: /content/UTSig/Genuine/89/19.tif
#   inflating: /content/UTSig/Genuine/89/2.tif
#   inflating: /content/UTSig/Genuine/89/20.tif
#   inflating: /content/UTSig/Genuine/89/21.tif
#   inflating: /content/UTSig/Genuine/89/22.tif
#   inflating: /content/UTSig/Genuine/89/23.tif
#   inflating: /content/UTSig/Genuine/89/24.tif
#   inflating: /content/UTSig/Genuine/89/25.tif
#   inflating: /content/UTSig/Genuine/89/26.tif
#   inflating: /content/UTSig/Genuine/89/27.tif
#   inflating: /content/UTSig/Genuine/89/3.tif
#   inflating: /content/UTSig/Genuine/89/4.tif
#   inflating: /content/UTSig/Genuine/89/5.tif
#   inflating: /content/UTSig/Genuine/89/6.tif
#   inflating: /content/UTSig/Genuine/89/7.tif
#   inflating: /content/UTSig/Genuine/89/8.tif
#   inflating: /content/UTSig/Genuine/89/9.tif
#    creating: /content/UTSig/Genuine/9/
#   inflating: /content/UTSig/Genuine/9/1.tif
#   inflating: /content/UTSig/Genuine/9/10.tif
#   inflating: /content/UTSig/Genuine/9/11.tif
#   inflating: /content/UTSig/Genuine/9/12.tif
#   inflating: /content/UTSig/Genuine/9/13.tif
#   inflating: /content/UTSig/Genuine/9/14.tif
#   inflating: /content/UTSig/Genuine/9/15.tif
#   inflating: /content/UTSig/Genuine/9/16.tif
#   inflating: /content/UTSig/Genuine/9/17.tif
#   inflating: /content/UTSig/Genuine/9/18.tif
#   inflating: /content/UTSig/Genuine/9/19.tif
#   inflating: /content/UTSig/Genuine/9/2.tif
#   inflating: /content/UTSig/Genuine/9/20.tif
#   inflating: /content/UTSig/Genuine/9/21.tif
#   inflating: /content/UTSig/Genuine/9/22.tif
#   inflating: /content/UTSig/Genuine/9/23.tif
#   inflating: /content/UTSig/Genuine/9/24.tif
#   inflating: /content/UTSig/Genuine/9/25.tif
#   inflating: /content/UTSig/Genuine/9/26.tif
#   inflating: /content/UTSig/Genuine/9/27.tif
#   inflating: /content/UTSig/Genuine/9/3.tif
#   inflating: /content/UTSig/Genuine/9/4.tif
#   inflating: /content/UTSig/Genuine/9/5.tif
#   inflating: /content/UTSig/Genuine/9/6.tif
#   inflating: /content/UTSig/Genuine/9/7.tif
#   inflating: /content/UTSig/Genuine/9/8.tif
#   inflating: /content/UTSig/Genuine/9/9.tif
#    creating: /content/UTSig/Genuine/90/
#   inflating: /content/UTSig/Genuine/90/1.tif
#   inflating: /content/UTSig/Genuine/90/10.tif
#   inflating: /content/UTSig/Genuine/90/11.tif
#   inflating: /content/UTSig/Genuine/90/12.tif
#   inflating: /content/UTSig/Genuine/90/13.tif
#   inflating: /content/UTSig/Genuine/90/14.tif
#   inflating: /content/UTSig/Genuine/90/15.tif
#   inflating: /content/UTSig/Genuine/90/16.tif
#   inflating: /content/UTSig/Genuine/90/17.tif
#   inflating: /content/UTSig/Genuine/90/18.tif
#   inflating: /content/UTSig/Genuine/90/19.tif
#   inflating: /content/UTSig/Genuine/90/2.tif
#   inflating: /content/UTSig/Genuine/90/20.tif
#   inflating: /content/UTSig/Genuine/94/27.tif
#   inflating: /content/UTSig/Genuine/94/3.tif
#   inflating: /content/UTSig/Genuine/94/4.tif
#   inflating: /content/UTSig/Genuine/94/5.tif
#   inflating: /content/UTSig/Genuine/94/6.tif
#   inflating: /content/UTSig/Genuine/94/7.tif
#   inflating: /content/UTSig/Genuine/94/8.tif
#   inflating: /content/UTSig/Genuine/94/9.tif
#    creating: /content/UTSig/Genuine/95/
#   inflating: /content/UTSig/Genuine/95/1.tif
#   inflating: /content/UTSig/Genuine/95/10.tif
#   inflating: /content/UTSig/Genuine/95/11.tif
#   inflating: /content/UTSig/Genuine/95/12.tif
#   inflating: /content/UTSig/Genuine/95/13.tif
#   inflating: /content/UTSig/Genuine/95/14.tif
#   inflating: /content/UTSig/Genuine/95/15.tif
#   inflating: /content/UTSig/Genuine/95/16.tif
#   inflating: /content/UTSig/Genuine/95/17.tif
#   inflating: /content/UTSig/Genuine/95/18.tif
#   inflating: /content/UTSig/Genuine/95/19.tif
#   inflating: /content/UTSig/Genuine/95/2.tif
#   inflating: /content/UTSig/Genuine/95/20.tif
#   inflating: /content/UTSig/Genuine/95/21.tif
#   inflating: /content/UTSig/Genuine/95/22.tif
#   inflating: /content/UTSig/Genuine/95/23.tif
#   inflating: /content/UTSig/Genuine/95/24.tif
#   inflating: /content/UTSig/Genuine/95/25.tif
#   inflating: /content/UTSig/Genuine/95/26.tif
#   inflating: /content/UTSig/Genuine/95/27.tif
#   inflating: /content/UTSig/Genuine/95/3.tif
#   inflating: /content/UTSig/Genuine/95/4.tif
#   inflating: /content/UTSig/Genuine/95/5.tif
#   inflating: /content/UTSig/Genuine/95/6.tif
#   inflating: /content/UTSig/Genuine/95/7.tif
#   inflating: /content/UTSig/Genuine/95/8.tif
#   inflating: /content/UTSig/Genuine/95/9.tif
#    creating: /content/UTSig/Genuine/96/
#   inflating: /content/UTSig/Genuine/96/1.tif
#   inflating: /content/UTSig/Genuine/96/10.tif
#   inflating: /content/UTSig/Genuine/96/11.tif
#   inflating: /content/UTSig/Genuine/96/12.tif
#   inflating: /content/UTSig/Genuine/96/13.tif
#   inflating: /content/UTSig/Genuine/96/14.tif
#   inflating: /content/UTSig/Genuine/96/15.tif
#   inflating: /content/UTSig/Genuine/96/16.tif
#   inflating: /content/UTSig/Genuine/96/17.tif
#   inflating: /content/UTSig/Genuine/96/18.tif
#   inflating: /content/UTSig/Genuine/96/19.tif
#   inflating: /content/UTSig/Genuine/96/2.tif
#   inflating: /content/UTSig/Genuine/96/20.tif
#   inflating: /content/UTSig/Genuine/96/21.tif
#   inflating: /content/UTSig/Genuine/96/22.tif
#   inflating: /content/UTSig/Genuine/96/23.tif
#   inflating: /content/UTSig/Genuine/96/24.tif
#   inflating: /content/UTSig/Genuine/96/25.tif
#   inflating: /content/UTSig/Genuine/96/26.tif
#   inflating: /content/UTSig/Genuine/96/27.tif
#   inflating: /content/UTSig/Genuine/96/3.tif
#   inflating: /content/UTSig/Genuine/96/4.tif
#   inflating: /content/UTSig/Genuine/98/9.tif
#    creating: /content/UTSig/Genuine/99/
#   inflating: /content/UTSig/Genuine/99/1.tif
#   inflating: /content/UTSig/Genuine/99/10.tif
#   inflating: /content/UTSig/Genuine/99/11.tif
#   inflating: /content/UTSig/Genuine/99/12.tif
#   inflating: /content/UTSig/Genuine/99/13.tif
#   inflating: /content/UTSig/Genuine/99/14.tif
#   inflating: /content/UTSig/Genuine/99/15.tif
#   inflating: /content/UTSig/Genuine/99/16.tif
#   inflating: /content/UTSig/Genuine/99/17.tif
#   inflating: /content/UTSig/Genuine/99/18.tif
#   inflating: /content/UTSig/Genuine/99/19.tif
#   inflating: /content/UTSig/Genuine/99/2.tif
#   inflating: /content/UTSig/Genuine/99/20.tif
#   inflating: /content/UTSig/Genuine/99/21.tif
#   inflating: /content/UTSig/Genuine/99/22.tif
#   inflating: /content/UTSig/Genuine/99/23.tif
#   inflating: /content/UTSig/Genuine/99/24.tif
#   inflating: /content/UTSig/Genuine/99/25.tif
#   inflating: /content/UTSig/Genuine/99/26.tif
#   inflating: /content/UTSig/Genuine/99/27.tif
#   inflating: /content/UTSig/Genuine/99/3.tif
#   inflating: /content/UTSig/Genuine/99/4.tif
#   inflating: /content/UTSig/Genuine/99/5.tif
#   inflating: /content/UTSig/Genuine/99/6.tif
#   inflating: /content/UTSig/Genuine/99/7.tif
#   inflating: /content/UTSig/Genuine/99/8.tif
#   inflating: /content/UTSig/Genuine/99/9.tif

# %%
# Proposed file restructing to fit this code
import os, shutil

filePath = '/content/UTSig'

filePathGen = filePath + '/Genuine'
filePathFor = filePath + '/Forgery'
filePathForSk = filePath + '/Forgery/Skilled' 
filePathForOh = filePath + '/Forgery/Opposite Hand' 
filePathForSi = filePath + '/Forgery/Simple' 

if "Simple" in os.listdir(filePathFor):
  if "1" in os.listdir(filePathGen):
      for i in os.listdir(filePathGen):
          author = i
          for j in os.listdir(filePathGen + '/' + author):
              os.rename(filePathGen + '/' + author + "/" + j, filePathGen + "/" + "g_" + author + "_" + j)
          os.removedirs(filePathGen + "/" + author)

  if "Skilled" in os.listdir(filePathFor):
      for i in os.listdir(filePathForSk):
          author = i
          for j in os.listdir(filePathForSk + '/' + author):
              os.rename(filePathForSk + '/' + author + "/" + j, filePathFor + "/" + "fSk_" + author + "_" + j)
          os.removedirs(filePathForSk + "/" + author)

  if "Opposite Hand" in os.listdir(filePathFor):
      for i in os.listdir(filePathForOh):
          author = i
          for j in os.listdir(filePathForOh + '/' + author):
              os.rename(filePathForOh + '/' + author + "/" + j, filePathFor + "/" + "fOh_" + author + "_" + j)
          os.removedirs(filePathForOh + "/" + author)

  if "Simple" in os.listdir(filePathFor):
    for i in os.listdir(filePathForSi):
        author = i
        count = 1
        for j in os.listdir(filePathForSi + '/' + author):
            os.rename(filePathForSi + '/' + author + "/" + j, filePathFor + "/" + "fSi_" + author + "_" + str(count) + ".tif")
            count = count + 1
        os.removedirs(filePathForSi + "/" + author)

# %%
### Need code for altering .tif files into .png? or can we go ahead and just work with .tif? ###

# %%
# File paths of the image data used later in the project
### Need to discuss how we will seperate our data. 80% 20% rule? ###
gentr="/content/UTSig/Genuine"
forgtr="/content/UTSig/Forgery"

gent="/content/UTSig/Genuine"
forgt="/content/UTSig/Forgery"

# %%
random.seed(30)

sigIndex = list(range(1,116))
random.shuffle(sigIndex)

folds = [sigIndex[0:30],sigIndex[30:60],sigIndex[60:90]]
test =sigIndex[90:116]
train1 = list(set(folds[0]+folds[1]))
train2 = list(set(folds[1]+folds[2]))
train3 = list(set(folds[0]+folds[2]))
train = [train1,train2,train3]
valid = [folds[2],folds[0], folds[1]]

# %%
# Code block for working with the image files (resizing, retreiving files, etc.)

# Standard height weight for images
img_width, img_height, channels = 224, 224, 3

dim = (img_width, img_height)

# Converts the images to rgb which is what VGG-16 takes as input
def to_rgb(img):
    img = cv2.resize(img, dim, interpolation = cv2.INTER_AREA) 
    img_rgb = np.asarray(np.dstack((img, img, img)), dtype=np.uint8)
    return img_rgb


# Takes in file path and image name and returns resized image
def returnimages(path,img):
    image=cv2.imread(path+"/"+ img)                  #bringing the image
    image=cv2.resize(image, (img_width, img_height))
    image=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image=to_rgb(image).reshape(1,img_width, img_height,3)/255.0       #resizing and normalizing    
    return image     

# Takes in number of author, path for genuine and forged signatures
# Returns one image name (m.pop()), and two arrays of file names n = forgary, m = genuine
# Used for generator()
def getfiles(num,gen,forg):
    genList=os.listdir(gen)
    forgList=os.listdir(forg)
    author=str(num)
           
    forgArr,genArr=[],[]
    for i in forgList:
        if ("_" + author + "_") in i:
            forgArr = forgArr + [i]
            
    for i in genList:
        if ("_" + author + "_") in i:
            genArr = genArr + [i]
     
    return genArr.pop(), forgArr, genArr
######################################

# Same as getfiles but returns two files
def getfilest(num,gen,forg):
    genList=os.listdir(gen)
    forgList=os.listdir(forg)
    author=str(num)
           
    forgArr,genArr=[],[]
    for i in forgList:
        if ("_" + author + "_") in i:
            forgArr = forgArr + [i]
            
    for i in genList:
        if ("_" + author + "_") in i:
            genArr = genArr + [i]

    return genArr.pop(), genArr.pop(), forgArr, genArr

# %%
# Function for defining loss variable in model, leave for now, look into altering?
### Unsure what y_pred is doing, or how this works....
def triplet_loss(y_true, y_pred):
    alpha = 0.5
    anchor, positive, negative =y_pred[0,0:512], y_pred[0,512:1024], y_pred[0,1024:1536]
    
    positive_distance = K.mean(K.square(anchor - positive),axis=-1)
    negative_distance = K.mean(K.square(anchor - negative),axis=-1)
    return K.mean(K.maximum(0.0, positive_distance - negative_distance + alpha))

# %%
#*****# Defining the architecture. Three as we are doing 3 fold cross validation
model1 = applications.vgg16.VGG16(weights='imagenet', include_top=False, pooling='max')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 2s 0us/step

# %%
model1.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None, None, 3)     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# global_max_pooling2d_1 (Glob (None, 512)               0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
# For layers from 1 to 15 freeze the weights

### We will need to do a test for each layer to find the optimal transfer* ###
### For now just copying over the code from example
#for layer in model1.layers[:4]:
#    layer.trainable = False
    
#for layer in model2.layers[:4]:
#    layer.trainable = False
    
#for layer in model3.layers[:4]:
    #print(layer)
#    layer.trainable = False

# %%
#*****# all "in" variables are defining the input "shape" for the model
# Input is a function in Keras
# Positive represents genuine / Negative represents Forgary 
anchor_in = Input(shape=(img_width, img_height, channels))
pos_in = Input(shape=(img_width, img_height, channels))
neg_in = Input(shape=(img_width, img_height, channels))

# Defining output of model
#for i in range(3):
anchor_out1 = model1(anchor_in)
pos_out1 = model1(pos_in)
neg_out1 = model1(neg_in)
merged_vector1 = concatenate([anchor_out1, pos_out1, neg_out1],axis=1)

# %%
#*****# Setting inputs and outputs of the model
# Model function - potentially overwrites the input and output layers
### Unsure what the output is... Need to research ###
# Input is 3 images: image in question (anchor), postitive image, negative image (same authors)

model1 = Model(inputs=[anchor_in, pos_in, neg_in], outputs=merged_vector1)

# %%
#******# Compiling the model
# loss function set to function defined earlier
# Optimizer is for learning rate of the function
### unsure what Adam function does

model1.compile(optimizer=Adam(lr=0.000001),loss=triplet_loss)

# %%
import datetime

now = datetime.datetime.now()
date = now.strftime("%Y%m%d%H%M")

print(date)

path = "/content/drive/Team Drives/results/" + username + "/" + date + "/"
os.mkdir(path)
# Out:
# 201905290324

# %%
# Generator - Goes through every author (in test) and returns an anchor (last image) and an array of file names (negative=forged) (positive=genuine) 
def generator(x):
  #  for i in range(1,96):
    print("Training " + str(x))
    for i in x:
      # Returns last genuine image, array of pos/genuine files, array of neg/forgary files
        anc,neg,pos=getfiles(i,gentr,forgtr)
        
#When we have the list of images/arrays for that author, we then loop through for the length of the negative list (total number of forged)
  #For each negative image, we are going to loop through the length of the positive list
    #For each positive image we resize the anchor, first
    
        for i in range(len(neg)):           
            for j in range(len(pos)):        
                anchor=returnimages(gentr,anc)
                positive=returnimages(gentr,pos[j])
                negative=returnimages(forgtr,neg[i])
               # yield ([anc,pos[j],neg[i]],[0])
                yield ([anchor,positive,negative],[0])

# %%
# Generator - Goes through every author (in test) and returns an anchor (last image) and an array of file names (negative=forged) (positive=genuine) 
def generator_validator(x):
    print("Validation " + str(x))
    for i in x:
      # Returns last genuine image, array of pos/genuine files, array of neg/forgary files
        anc,neg,pos=getfiles(i,gentr,forgtr)
        
#When we have the list of images/arrays for that author, we then loop through for the length of the negative list (total number of forged)
  #For each negative image, we are going to loop through the length of the positive list
    #For each positive image we resize the anchor, first
    
        for i in range(len(neg)):           
            for j in range(len(pos)):        
                anchor=returnimages(gentr,anc)
                positive=returnimages(gentr,pos[j])
                negative=returnimages(forgtr,neg[i])
               # yield ([anc,pos[j],neg[i]],[0])
                yield ([anchor,positive,negative],[0])

# %%
#*****### These values were taken from example, need to decide on what they should be
logs = ["freeze0_lr000001_training1.log"]
weights = ["freeze0_lr000001_model_weights_1.h5"]

# %%
print("Starting model: 1")
#for i in range(3):

print("Iteration: 1")
#initial_weights = path + "initial_weights.h5"
  #baseModel.load_weights(initial_weights)
  #baseModel.trainable = True
weight = path + weights[0]
log = path + logs[0]
csv = keras.callbacks.CSVLogger(log)
es = keras.callbacks.EarlyStopping(monitor='val_loss', patience=50, verbose=1, mode='auto', baseline=.48, restore_best_weights=True)
  #es_list = [es, csv]
cb_list = [es, csv]
#history = baseModel.fit_generator(generator(),steps_per_epoch=200,epochs=10,callbacks= es_list,validation_data=generator_validator(),validation_steps=5)
history = model1.fit_generator(generator(train[0]),steps_per_epoch=200,epochs=90,callbacks = cb_list, validation_data=generator_validator(valid[0]),validation_steps=100)
model1.save_weights(weight)
# Out:
# Starting model: 1
# Iteration: 1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Epoch 1/90
# Training [3, 5, 6, 12, 14, 16, 19, 20, 22, 23, 24, 25, 26, 28, 29, 30, 31, 34, 35, 37, 39, 42, 43, 44, 46, 47, 48, 53, 54, 56, 57, 58, 59, 61, 62, 63, 66, 74, 75, 76, 78, 85, 86, 87, 88, 89, 91, 92, 93, 94, 97, 98, 99, 103, 105, 107, 110, 113, 114, 115]Validation [2, 50, 8, 41, 102, 101, 100, 65, 108, 71, 112, 17, 40, 64, 15, 72, 81, 13, 82, 55, 36, 73, 96, 95, 90, 9, 69, 45, 109, 52]
#
# 200/200 [==============================] - 29s 143ms/step - loss: 0.1556 - val_loss: 0.2779
# Epoch 2/90
# 200/200 [==============================] - 21s 107ms/step - loss: 0.0094 - val_loss: 0.1438
# Epoch 3/90
# 200/200 [==============================] - 22s 109ms/step - loss: 0.0056 - val_loss: 0.2889
# Epoch 4/90
# 200/200 [==============================] - 22s 110ms/step - loss: 4.3260e-05 - val_loss: 0.0901
# Epoch 5/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0000e+00 - val_loss: 0.2728
# Epoch 6/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0073 - val_loss: 0.2080
# Epoch 7/90
# 200/200 [==============================] - 23s 113ms/step - loss: 0.0059 - val_loss: 0.0903
# Epoch 8/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0010 - val_loss: 0.0413
# Epoch 9/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0015 - val_loss: 0.0648
# Epoch 10/90
# 200/200 [==============================] - 22s 112ms/step - loss: 7.0982e-04 - val_loss: 0.0068
# Epoch 11/90
# 200/200 [==============================] - 22s 112ms/step - loss: 4.8072e-04 - val_loss: 0.0010
# Epoch 12/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0319 - val_loss: 0.0371
# Epoch 13/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0024 - val_loss: 0.2232
# Epoch 14/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0000e+00 - val_loss: 0.3654
# Epoch 15/90
# 200/200 [==============================] - 22s 112ms/step - loss: 1.8315e-04 - val_loss: 0.0585
# Epoch 16/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0000e+00 - val_loss: 0.4094
# Epoch 17/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0000e+00 - val_loss: 0.0995
# Epoch 18/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0124 - val_loss: 0.2409
# Epoch 19/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0218 - val_loss: 0.3520
# Epoch 20/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0059 - val_loss: 0.2261
# Epoch 21/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0055 - val_loss: 0.0816
# Epoch 22/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0000e+00 - val_loss: 0.0682
# Epoch 23/90
# 200/200 [==============================] - 22s 111ms/step - loss: 3.4230e-04 - val_loss: 0.0710
# Epoch 24/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0384 - val_loss: 0.1238
# Epoch 25/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0119 - val_loss: 0.0214
# Epoch 26/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0000e+00 - val_loss: 0.0955
# Epoch 27/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0023 - val_loss: 0.0902
# Epoch 28/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0000e+00 - val_loss: 0.0913
# Epoch 29/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0000e+00 - val_loss: 0.0829
# Epoch 30/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0021 - val_loss: 0.0310
# Epoch 31/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0000e+00 - val_loss: 8.1550e-04
# Epoch 32/90
# 200/200 [==============================] - 22s 112ms/step - loss: 5.7757e-04 - val_loss: 0.0077
# Epoch 33/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0000e+00 - val_loss: 0.0103
# Epoch 34/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0000e+00 - val_loss: 0.0256
# Epoch 35/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0000e+00 - val_loss: 0.0392
# Epoch 36/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0109 - val_loss: 0.0275
# Epoch 37/90
# 200/200 [==============================] - 22s 111ms/step - loss: 6.9005e-04 - val_loss: 0.0169
# Epoch 38/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0000e+00 - val_loss: 0.1578
# Epoch 39/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0000e+00 - val_loss: 0.0558
# Epoch 40/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0000e+00 - val_loss: 0.0088
# Epoch 41/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0000e+00 - val_loss: 0.0046
# Epoch 42/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0073 - val_loss: 0.0030
# Epoch 43/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0045 - val_loss: 0.0082
# Epoch 44/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0070 - val_loss: 0.0244
# Epoch 45/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0000e+00 - val_loss: 0.0098
# Epoch 46/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 47/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0154 - val_loss: 0.0603
# Epoch 48/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0000e+00 - val_loss: 1.8727
# Epoch 49/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0039 - val_loss: 2.0334
# Epoch 50/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0050 - val_loss: 1.7484
# Epoch 51/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0000e+00 - val_loss: 1.6489
# Epoch 52/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0000e+00 - val_loss: 1.3971
# Epoch 53/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0063 - val_loss: 2.2915
# Epoch 54/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0021 - val_loss: 1.3273
# Epoch 55/90
# 200/200 [==============================] - 22s 111ms/step - loss: 1.5941e-04 - val_loss: 1.9164
# Epoch 56/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0013 - val_loss: 1.6898
# Epoch 57/90
# 200/200 [==============================] - 22s 111ms/step - loss: 1.6125e-04 - val_loss: 1.1778
# Epoch 58/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0016 - val_loss: 0.6586
# Epoch 59/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0311 - val_loss: 0.9576
# Epoch 60/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0133 - val_loss: 7.8459e-04
# Epoch 61/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0011 - val_loss: 0.0443
# Epoch 62/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0000e+00 - val_loss: 0.0206
# Epoch 63/90
# 200/200 [==============================] - 22s 111ms/step - loss: 9.3228e-04 - val_loss: 0.1554
# Epoch 64/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0035 - val_loss: 0.0250
# Epoch 65/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0111 - val_loss: 0.0274
# Epoch 66/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0023 - val_loss: 0.0082
# Epoch 67/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0000e+00 - val_loss: 0.0019
# Epoch 68/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0000e+00 - val_loss: 0.0690
# Epoch 69/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0000e+00 - val_loss: 0.0421
# Epoch 70/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0000e+00 - val_loss: 0.0381
# Epoch 71/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0042 - val_loss: 0.8642
# Epoch 72/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0017 - val_loss: 0.3800
# Epoch 73/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0000e+00 - val_loss: 0.5239
# Epoch 74/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0000e+00 - val_loss: 0.1322
# Epoch 75/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0000e+00 - val_loss: 0.2431
# Epoch 76/90
# 200/200 [==============================] - 22s 111ms/step - loss: 2.7834e-04 - val_loss: 0.4370
# Epoch 77/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0233 - val_loss: 0.3169
# Epoch 78/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0052 - val_loss: 0.2704
# Epoch 79/90
# 200/200 [==============================] - 22s 112ms/step - loss: 8.6398e-04 - val_loss: 0.4881
# Epoch 80/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0023 - val_loss: 0.3951
# Epoch 81/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0000e+00 - val_loss: 0.4959
# Epoch 82/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0043 - val_loss: 0.4613
# Epoch 83/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0185 - val_loss: 0.0281
# Epoch 84/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0222 - val_loss: 0.7842
# Epoch 85/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0207 - val_loss: 0.6264
# Epoch 86/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0014 - val_loss: 0.4284
# Epoch 87/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0000e+00 - val_loss: 0.4379
# Epoch 88/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0041 - val_loss: 0.4992
# Epoch 89/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0011 - val_loss: 0.2362
# Epoch 90/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0019 - val_loss: 0.4262

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

print(min(val_loss))

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.ylim([0,max(plt.ylim())])
plt.title('Training and Validation Loss')
plt.show()
# Out:
# 0.0

# %%
### Unsure purpose of this part ###

# used for validation

tneg,tpos = 0, 0

for k in test: #the id of signatures you want to check
    #print("When k is ", k)
    anc,neg,pos=getfiles(k,gent,forgt)
    tneg=tneg+len(neg)
    tpos=tpos+len(pos)
print("Forgary Image Total: " + str(tneg),"Genuine Image Total: " + str(tpos))
# Out:
# Forgary Image Total: 1125 Genuine Image Total: 650

# %%
#******

i = 0
print("Iteration: " + str(i))
weight = path + weights[0]
model1.load_weights(weight)
  
forg_passed=0
gen_flagged=0

for k in test: #the id of signatures you want to check
    print("When k is ", k)
    anc,neg,pos=getfiles(k,gent,forgt)
    
    anchor=returnimages(gent,anc)
    for i in range(len(pos)): #pos
        positive=returnimages(gent,pos[i])
        x=model1.predict([anchor,positive,anchor])
        a, p, useless = x[0,0:512], x[0,512:1024], x[0,1024:1536]
        #dist=sum(a-p)
        dist=np.linalg.norm(a-p)
        #print("positive distance is ",dist)
        if(dist>32):
        #  print("0")
            gen_flagged=gen_flagged+1
            print("gen flagged - ",dist, "file name is - ", pos[i])
            
        else:
            gen_flagged=gen_flagged
        #   print("1")
        
    for j in range(len(neg)): #neg
        negative=returnimages(forgt,neg[j])
        x=model1.predict([anchor,negative,anchor])
        a, n, useless = x[0,0:512], x[0,512:1024], x[0,1024:1536]
        #dist=sum(a-n)
        dist=np.linalg.norm(a-n)
        #print("negative distance is ",dist)
        if(dist>32):
            forg_passed=forg_passed
          #  print("0")
        else:
            forg_passed=forg_passed+1
            print("forg passed - ",dist, "file name is - ", neg[j])
          #  print("1")

print("base_forg_passed is ",forg_passed)
print("base_gen_flagged is ",gen_flagged)
print("False Acceptance Rate (FAR) = ", str(100*forg_passed/tneg), "%")
print("False Rejection Rate (FRR) = ", str(100*gen_flagged/tpos), "%")
# Out:
# Iteration: 0
# When k is  68
# gen flagged -  45.470158 file name is -  g_68_27.tif
# gen flagged -  33.213932 file name is -  g_68_11.tif
# gen flagged -  38.715824 file name is -  g_68_23.tif
# gen flagged -  32.87228 file name is -  g_68_9.tif
# gen flagged -  34.597366 file name is -  g_68_10.tif
# gen flagged -  35.173836 file name is -  g_68_24.tif
# gen flagged -  35.83998 file name is -  g_68_15.tif
# gen flagged -  35.36846 file name is -  g_68_22.tif
# gen flagged -  32.578545 file name is -  g_68_6.tif
# gen flagged -  32.59086 file name is -  g_68_21.tif
# gen flagged -  32.533447 file name is -  g_68_8.tif
# gen flagged -  34.200195 file name is -  g_68_13.tif
# gen flagged -  33.47228 file name is -  g_68_25.tif
# gen flagged -  37.70018 file name is -  g_68_26.tif
# gen flagged -  32.86851 file name is -  g_68_16.tif
# gen flagged -  34.683487 file name is -  g_68_4.tif
# gen flagged -  33.59429 file name is -  g_68_19.tif
# gen flagged -  39.986813 file name is -  g_68_20.tif
# gen flagged -  44.28456 file name is -  g_68_2.tif
# gen flagged -  38.102245 file name is -  g_68_7.tif
# gen flagged -  37.3012 file name is -  g_68_3.tif
# gen flagged -  32.199577 file name is -  g_68_14.tif
# When k is  77
# gen flagged -  40.7389 file name is -  g_77_15.tif
# gen flagged -  40.87041 file name is -  g_77_4.tif
# gen flagged -  39.458107 file name is -  g_77_19.tif
# gen flagged -  47.057632 file name is -  g_77_26.tif
# gen flagged -  50.804832 file name is -  g_77_16.tif
# gen flagged -  41.95123 file name is -  g_77_3.tif
# gen flagged -  38.380493 file name is -  g_77_2.tif
# gen flagged -  38.055744 file name is -  g_77_23.tif
# gen flagged -  41.43727 file name is -  g_77_6.tif
# gen flagged -  45.18007 file name is -  g_77_11.tif
# gen flagged -  41.66291 file name is -  g_77_8.tif
# gen flagged -  38.555805 file name is -  g_77_25.tif
# gen flagged -  47.394142 file name is -  g_77_20.tif
# gen flagged -  47.33509 file name is -  g_77_14.tif
# gen flagged -  40.079693 file name is -  g_77_9.tif
# gen flagged -  49.543434 file name is -  g_77_17.tif
# gen flagged -  47.20456 file name is -  g_77_12.tif
# gen flagged -  60.424835 file name is -  g_77_18.tif
# gen flagged -  48.49749 file name is -  g_77_27.tif
# gen flagged -  43.023197 file name is -  g_77_10.tif
# gen flagged -  36.746567 file name is -  g_77_7.tif
# gen flagged -  36.7957 file name is -  g_77_1.tif
# gen flagged -  47.0877 file name is -  g_77_22.tif
# gen flagged -  37.797306 file name is -  g_77_13.tif
# gen flagged -  51.1178 file name is -  g_77_24.tif
# gen flagged -  45.86998 file name is -  g_77_5.tif
# When k is  21
# gen flagged -  40.288605 file name is -  g_21_6.tif
# gen flagged -  32.227486 file name is -  g_21_22.tif
# gen flagged -  38.883446 file name is -  g_21_3.tif
# gen flagged -  32.311954 file name is -  g_21_15.tif
# gen flagged -  35.713932 file name is -  g_21_10.tif
# gen flagged -  40.377094 file name is -  g_21_26.tif
# gen flagged -  33.034405 file name is -  g_21_9.tif
# gen flagged -  44.062572 file name is -  g_21_4.tif
# gen flagged -  38.08409 file name is -  g_21_21.tif
# gen flagged -  36.83678 file name is -  g_21_5.tif
# gen flagged -  35.190506 file name is -  g_21_1.tif
# gen flagged -  37.223797 file name is -  g_21_7.tif
# gen flagged -  42.584496 file name is -  g_21_2.tif
# gen flagged -  37.210815 file name is -  g_21_14.tif
# gen flagged -  41.438778 file name is -  g_21_11.tif
# gen flagged -  52.980057 file name is -  g_21_25.tif
# gen flagged -  36.03178 file name is -  g_21_12.tif
# When k is  10
# gen flagged -  44.13299 file name is -  g_10_17.tif
# gen flagged -  39.167973 file name is -  g_10_3.tif
# gen flagged -  48.471172 file name is -  g_10_25.tif
# gen flagged -  48.96642 file name is -  g_10_2.tif
# gen flagged -  49.051052 file name is -  g_10_27.tif
# gen flagged -  33.146187 file name is -  g_10_20.tif
# gen flagged -  40.007023 file name is -  g_10_24.tif
# gen flagged -  46.824135 file name is -  g_10_15.tif
# gen flagged -  46.305984 file name is -  g_10_9.tif
# gen flagged -  47.232433 file name is -  g_10_4.tif
# gen flagged -  46.69219 file name is -  g_10_11.tif
# gen flagged -  42.08129 file name is -  g_10_19.tif
# gen flagged -  43.449528 file name is -  g_10_18.tif
# gen flagged -  43.063393 file name is -  g_10_14.tif
# gen flagged -  42.785397 file name is -  g_10_22.tif
# gen flagged -  44.29927 file name is -  g_10_10.tif
# gen flagged -  36.080387 file name is -  g_10_12.tif
# gen flagged -  44.192383 file name is -  g_10_6.tif
# gen flagged -  38.844204 file name is -  g_10_8.tif
# gen flagged -  41.212807 file name is -  g_10_1.tif
# gen flagged -  37.02339 file name is -  g_10_23.tif
# gen flagged -  41.231083 file name is -  g_10_16.tif
# gen flagged -  47.036877 file name is -  g_10_26.tif
# gen flagged -  35.82045 file name is -  g_10_7.tif
# gen flagged -  32.384132 file name is -  g_10_13.tif
# gen flagged -  51.37774 file name is -  g_10_21.tif
# When k is  111
# gen flagged -  49.309204 file name is -  g_111_7.tif
# gen flagged -  42.022556 file name is -  g_111_24.tif
# gen flagged -  35.62719 file name is -  g_111_14.tif
# gen flagged -  41.11295 file name is -  g_111_27.tif
# gen flagged -  40.328075 file name is -  g_111_15.tif
# gen flagged -  47.20967 file name is -  g_111_3.tif
# gen flagged -  35.859047 file name is -  g_111_20.tif
# gen flagged -  41.1134 file name is -  g_111_2.tif
# gen flagged -  53.84275 file name is -  g_111_8.tif
# gen flagged -  45.26127 file name is -  g_111_10.tif
# gen flagged -  40.005695 file name is -  g_111_16.tif
# gen flagged -  51.52947 file name is -  g_111_5.tif
# gen flagged -  38.84074 file name is -  g_111_21.tif
# gen flagged -  49.827404 file name is -  g_111_1.tif
# gen flagged -  40.713436 file name is -  g_111_12.tif
# gen flagged -  44.808853 file name is -  g_111_11.tif
# gen flagged -  51.192303 file name is -  g_111_9.tif
# gen flagged -  37.08245 file name is -  g_111_23.tif
# gen flagged -  36.645164 file name is -  g_111_25.tif
# gen flagged -  53.145397 file name is -  g_111_6.tif
# gen flagged -  40.5676 file name is -  g_111_19.tif
# gen flagged -  51.135345 file name is -  g_111_4.tif
# gen flagged -  43.21174 file name is -  g_111_13.tif
# gen flagged -  47.0429 file name is -  g_111_26.tif
# gen flagged -  39.501213 file name is -  g_111_22.tif
# When k is  32
# gen flagged -  55.900623 file name is -  g_32_16.tif
# gen flagged -  47.158245 file name is -  g_32_7.tif
# gen flagged -  34.49257 file name is -  g_32_17.tif
# gen flagged -  46.09334 file name is -  g_32_25.tif
# gen flagged -  38.459015 file name is -  g_32_18.tif
# gen flagged -  38.435955 file name is -  g_32_19.tif
# gen flagged -  50.80773 file name is -  g_32_5.tif
# gen flagged -  33.822437 file name is -  g_32_10.tif
# gen flagged -  35.430485 file name is -  g_32_2.tif
# gen flagged -  43.129295 file name is -  g_32_9.tif
# gen flagged -  41.592854 file name is -  g_32_8.tif
# gen flagged -  51.82448 file name is -  g_32_15.tif
# gen flagged -  60.926144 file name is -  g_32_1.tif
# gen flagged -  46.23864 file name is -  g_32_22.tif
# gen flagged -  56.896057 file name is -  g_32_23.tif
# gen flagged -  53.294636 file name is -  g_32_13.tif
# gen flagged -  53.258663 file name is -  g_32_4.tif
# gen flagged -  59.029285 file name is -  g_32_6.tif
# gen flagged -  58.696465 file name is -  g_32_20.tif
# gen flagged -  39.94736 file name is -  g_32_21.tif
# gen flagged -  47.821346 file name is -  g_32_3.tif
# gen flagged -  43.76942 file name is -  g_32_11.tif
# gen flagged -  34.01685 file name is -  g_32_27.tif
# gen flagged -  50.137917 file name is -  g_32_12.tif
# gen flagged -  51.14457 file name is -  g_32_14.tif
# When k is  67
# gen flagged -  37.87688 file name is -  g_67_7.tif
# gen flagged -  33.747326 file name is -  g_67_8.tif
# gen flagged -  35.786144 file name is -  g_67_23.tif
# gen flagged -  37.997498 file name is -  g_67_6.tif
# gen flagged -  34.645123 file name is -  g_67_17.tif
# gen flagged -  37.9708 file name is -  g_67_3.tif
# gen flagged -  40.659176 file name is -  g_67_5.tif
# gen flagged -  35.293137 file name is -  g_67_13.tif
# gen flagged -  33.43669 file name is -  g_67_19.tif
# gen flagged -  38.166183 file name is -  g_67_4.tif
# gen flagged -  38.009018 file name is -  g_67_18.tif
# gen flagged -  47.24267 file name is -  g_67_10.tif
# gen flagged -  36.474194 file name is -  g_67_16.tif
# gen flagged -  35.60537 file name is -  g_67_25.tif
# gen flagged -  39.603767 file name is -  g_67_22.tif
# gen flagged -  33.260403 file name is -  g_67_26.tif
# gen flagged -  39.776623 file name is -  g_67_21.tif
# gen flagged -  39.718735 file name is -  g_67_9.tif
# gen flagged -  48.88971 file name is -  g_67_15.tif
# gen flagged -  32.214054 file name is -  g_67_14.tif
# gen flagged -  35.19545 file name is -  g_67_12.tif
# gen flagged -  38.01487 file name is -  g_67_11.tif
# gen flagged -  33.292492 file name is -  g_67_1.tif
# gen flagged -  33.874447 file name is -  g_67_24.tif
# When k is  1
# gen flagged -  43.910908 file name is -  g_1_8.tif
# gen flagged -  46.142025 file name is -  g_1_3.tif
# gen flagged -  50.277946 file name is -  g_1_26.tif
# gen flagged -  38.690857 file name is -  g_1_20.tif
# gen flagged -  45.25683 file name is -  g_1_25.tif
# gen flagged -  37.268406 file name is -  g_1_1.tif
# gen flagged -  41.464283 file name is -  g_1_2.tif
# gen flagged -  43.357574 file name is -  g_1_17.tif
# gen flagged -  36.02175 file name is -  g_1_22.tif
# gen flagged -  40.45882 file name is -  g_1_6.tif
# gen flagged -  41.441772 file name is -  g_1_9.tif
# gen flagged -  46.12989 file name is -  g_1_27.tif
# gen flagged -  44.64775 file name is -  g_1_15.tif
# gen flagged -  39.61199 file name is -  g_1_19.tif
# gen flagged -  50.402035 file name is -  g_1_10.tif
# gen flagged -  41.315857 file name is -  g_1_13.tif
# gen flagged -  51.71917 file name is -  g_1_4.tif
# gen flagged -  39.657803 file name is -  g_1_16.tif
# gen flagged -  43.12766 file name is -  g_1_23.tif
# gen flagged -  44.758312 file name is -  g_1_14.tif
# gen flagged -  48.89348 file name is -  g_1_18.tif
# gen flagged -  43.09565 file name is -  g_1_11.tif
# gen flagged -  46.11547 file name is -  g_1_5.tif
# gen flagged -  52.265385 file name is -  g_1_7.tif
# gen flagged -  47.00373 file name is -  g_1_21.tif
# gen flagged -  34.43311 file name is -  g_1_12.tif
# When k is  60
# gen flagged -  43.114586 file name is -  g_60_27.tif
# gen flagged -  47.81851 file name is -  g_60_8.tif
# gen flagged -  47.841072 file name is -  g_60_6.tif
# gen flagged -  37.3401 file name is -  g_60_21.tif
# gen flagged -  51.353058 file name is -  g_60_9.tif
# gen flagged -  40.437035 file name is -  g_60_17.tif
# gen flagged -  46.78714 file name is -  g_60_24.tif
# gen flagged -  50.92683 file name is -  g_60_19.tif
# gen flagged -  43.187344 file name is -  g_60_23.tif
# gen flagged -  47.508423 file name is -  g_60_13.tif
# gen flagged -  43.007317 file name is -  g_60_11.tif
# gen flagged -  46.897053 file name is -  g_60_4.tif
# gen flagged -  43.43685 file name is -  g_60_2.tif
# gen flagged -  38.58944 file name is -  g_60_14.tif
# gen flagged -  34.58161 file name is -  g_60_16.tif
# gen flagged -  39.145798 file name is -  g_60_3.tif
# gen flagged -  59.56852 file name is -  g_60_26.tif
# gen flagged -  33.525898 file name is -  g_60_18.tif
# gen flagged -  42.621513 file name is -  g_60_5.tif
# gen flagged -  52.063652 file name is -  g_60_10.tif
# gen flagged -  49.977337 file name is -  g_60_20.tif
# gen flagged -  53.494125 file name is -  g_60_1.tif
# gen flagged -  42.02991 file name is -  g_60_7.tif
# gen flagged -  37.35418 file name is -  g_60_22.tif
# gen flagged -  37.973095 file name is -  g_60_15.tif
# gen flagged -  36.93188 file name is -  g_60_12.tif
# When k is  11
# gen flagged -  53.873596 file name is -  g_11_13.tif
# gen flagged -  57.84078 file name is -  g_11_4.tif
# gen flagged -  59.164185 file name is -  g_11_7.tif
# gen flagged -  53.48915 file name is -  g_11_24.tif
# gen flagged -  47.991142 file name is -  g_11_3.tif
# gen flagged -  57.307705 file name is -  g_11_21.tif
# gen flagged -  48.693905 file name is -  g_11_6.tif
# gen flagged -  46.40357 file name is -  g_11_27.tif
# gen flagged -  54.31484 file name is -  g_11_10.tif
# gen flagged -  52.49389 file name is -  g_11_23.tif
# gen flagged -  52.573063 file name is -  g_11_14.tif
# gen flagged -  49.061172 file name is -  g_11_2.tif
# gen flagged -  45.887295 file name is -  g_11_22.tif
# gen flagged -  52.30415 file name is -  g_11_11.tif
# gen flagged -  62.579006 file name is -  g_11_25.tif
# gen flagged -  48.761246 file name is -  g_11_26.tif
# gen flagged -  39.08848 file name is -  g_11_20.tif
# gen flagged -  54.37142 file name is -  g_11_12.tif
# gen flagged -  42.117416 file name is -  g_11_16.tif
# gen flagged -  53.702103 file name is -  g_11_1.tif
# gen flagged -  58.04394 file name is -  g_11_5.tif
# gen flagged -  47.595463 file name is -  g_11_18.tif
# gen flagged -  52.259007 file name is -  g_11_9.tif
# gen flagged -  48.539425 file name is -  g_11_15.tif
# gen flagged -  60.142982 file name is -  g_11_8.tif
# gen flagged -  39.8375 file name is -  g_11_17.tif
# When k is  18
# gen flagged -  44.448227 file name is -  g_18_8.tif
# gen flagged -  41.753525 file name is -  g_18_2.tif
# gen flagged -  45.35272 file name is -  g_18_15.tif
# gen flagged -  52.266556 file name is -  g_18_1.tif
# gen flagged -  40.74089 file name is -  g_18_9.tif
# gen flagged -  39.58507 file name is -  g_18_21.tif
# gen flagged -  37.068497 file name is -  g_18_6.tif
# gen flagged -  42.865627 file name is -  g_18_13.tif
# gen flagged -  39.058273 file name is -  g_18_19.tif
# gen flagged -  46.01894 file name is -  g_18_24.tif
# gen flagged -  43.606995 file name is -  g_18_22.tif
# gen flagged -  42.47631 file name is -  g_18_4.tif
# gen flagged -  49.20916 file name is -  g_18_20.tif
# gen flagged -  37.092804 file name is -  g_18_25.tif
# gen flagged -  47.218353 file name is -  g_18_14.tif
# gen flagged -  36.379642 file name is -  g_18_7.tif
# gen flagged -  49.54042 file name is -  g_18_18.tif
# gen flagged -  48.46495 file name is -  g_18_11.tif
# gen flagged -  36.70044 file name is -  g_18_12.tif
# gen flagged -  40.3276 file name is -  g_18_17.tif
# gen flagged -  46.47074 file name is -  g_18_16.tif
# gen flagged -  47.604195 file name is -  g_18_27.tif
# gen flagged -  38.819363 file name is -  g_18_5.tif
# gen flagged -  47.56428 file name is -  g_18_26.tif
# gen flagged -  50.93242 file name is -  g_18_23.tif
# gen flagged -  42.079796 file name is -  g_18_10.tif
# When k is  83
# gen flagged -  40.281765 file name is -  g_83_16.tif
# gen flagged -  32.06445 file name is -  g_83_14.tif
# gen flagged -  32.32774 file name is -  g_83_7.tif
# gen flagged -  33.61925 file name is -  g_83_8.tif
# gen flagged -  32.90186 file name is -  g_83_27.tif
# gen flagged -  38.031483 file name is -  g_83_18.tif
# gen flagged -  35.55814 file name is -  g_83_12.tif
# gen flagged -  32.784733 file name is -  g_83_6.tif
# gen flagged -  33.33357 file name is -  g_83_22.tif
# gen flagged -  37.684727 file name is -  g_83_21.tif
# gen flagged -  35.28915 file name is -  g_83_24.tif
# gen flagged -  35.39932 file name is -  g_83_10.tif
# gen flagged -  33.649696 file name is -  g_83_2.tif
# gen flagged -  33.927795 file name is -  g_83_17.tif
# gen flagged -  38.05421 file name is -  g_83_1.tif
# gen flagged -  41.81743 file name is -  g_83_19.tif
# gen flagged -  33.738758 file name is -  g_83_9.tif
# gen flagged -  33.555912 file name is -  g_83_4.tif
# gen flagged -  39.97921 file name is -  g_83_23.tif
# gen flagged -  40.845783 file name is -  g_83_3.tif
# gen flagged -  35.95194 file name is -  g_83_15.tif
# gen flagged -  36.041374 file name is -  g_83_11.tif
# gen flagged -  37.54549 file name is -  g_83_26.tif
# gen flagged -  36.716682 file name is -  g_83_20.tif
# When k is  49
# gen flagged -  48.70684 file name is -  g_49_19.tif
# gen flagged -  54.66617 file name is -  g_49_12.tif
# gen flagged -  51.7456 file name is -  g_49_26.tif
# gen flagged -  53.252594 file name is -  g_49_6.tif
# gen flagged -  45.11845 file name is -  g_49_25.tif
# gen flagged -  50.708923 file name is -  g_49_16.tif
# gen flagged -  54.279224 file name is -  g_49_15.tif
# gen flagged -  52.506046 file name is -  g_49_11.tif
# gen flagged -  43.91929 file name is -  g_49_4.tif
# gen flagged -  57.964275 file name is -  g_49_24.tif
# gen flagged -  52.313293 file name is -  g_49_17.tif
# gen flagged -  53.01378 file name is -  g_49_2.tif
# gen flagged -  44.71091 file name is -  g_49_14.tif
# gen flagged -  44.759525 file name is -  g_49_3.tif
# gen flagged -  51.26476 file name is -  g_49_13.tif
# gen flagged -  46.532257 file name is -  g_49_21.tif
# gen flagged -  45.62236 file name is -  g_49_7.tif
# gen flagged -  57.037033 file name is -  g_49_18.tif
# gen flagged -  57.1696 file name is -  g_49_23.tif
# gen flagged -  53.789093 file name is -  g_49_1.tif
# gen flagged -  50.017185 file name is -  g_49_10.tif
# gen flagged -  53.080956 file name is -  g_49_5.tif
# gen flagged -  57.487667 file name is -  g_49_8.tif
# gen flagged -  52.505737 file name is -  g_49_22.tif
# gen flagged -  45.90827 file name is -  g_49_20.tif
# gen flagged -  45.02225 file name is -  g_49_9.tif
# When k is  51
# gen flagged -  63.217426 file name is -  g_51_5.tif
# gen flagged -  74.91553 file name is -  g_51_17.tif
# gen flagged -  62.435295 file name is -  g_51_2.tif
# gen flagged -  66.720474 file name is -  g_51_26.tif
# gen flagged -  66.85352 file name is -  g_51_10.tif
# gen flagged -  68.787575 file name is -  g_51_4.tif
# gen flagged -  61.21927 file name is -  g_51_12.tif
# gen flagged -  68.231 file name is -  g_51_15.tif
# gen flagged -  63.369576 file name is -  g_51_18.tif
# gen flagged -  67.45218 file name is -  g_51_6.tif
# gen flagged -  72.129 file name is -  g_51_8.tif
# gen flagged -  75.04952 file name is -  g_51_20.tif
# gen flagged -  77.066505 file name is -  g_51_13.tif
# gen flagged -  68.62945 file name is -  g_51_21.tif
# gen flagged -  59.31207 file name is -  g_51_16.tif
# gen flagged -  81.40396 file name is -  g_51_22.tif
# gen flagged -  70.11463 file name is -  g_51_7.tif
# gen flagged -  62.515724 file name is -  g_51_11.tif
# gen flagged -  77.64082 file name is -  g_51_3.tif
# gen flagged -  65.65641 file name is -  g_51_27.tif
# gen flagged -  66.03213 file name is -  g_51_25.tif
# gen flagged -  75.74702 file name is -  g_51_9.tif
# gen flagged -  77.78311 file name is -  g_51_19.tif
# gen flagged -  61.682793 file name is -  g_51_1.tif
# gen flagged -  74.33598 file name is -  g_51_14.tif
# gen flagged -  68.67653 file name is -  g_51_24.tif
# When k is  7
# gen flagged -  42.438213 file name is -  g_7_7.tif
# gen flagged -  43.37929 file name is -  g_7_13.tif
# gen flagged -  42.383896 file name is -  g_7_24.tif
# gen flagged -  44.808308 file name is -  g_7_3.tif
# gen flagged -  47.67484 file name is -  g_7_21.tif
# gen flagged -  49.455936 file name is -  g_7_18.tif
# gen flagged -  39.59633 file name is -  g_7_5.tif
# gen flagged -  45.824482 file name is -  g_7_8.tif
# gen flagged -  43.46241 file name is -  g_7_15.tif
# gen flagged -  39.50642 file name is -  g_7_17.tif
# gen flagged -  40.653492 file name is -  g_7_10.tif
# gen flagged -  44.827126 file name is -  g_7_4.tif
# gen flagged -  40.52074 file name is -  g_7_9.tif
# gen flagged -  47.78047 file name is -  g_7_12.tif
# gen flagged -  52.667297 file name is -  g_7_6.tif
# gen flagged -  58.77929 file name is -  g_7_20.tif
# gen flagged -  42.48924 file name is -  g_7_16.tif
# gen flagged -  53.47521 file name is -  g_7_19.tif
# gen flagged -  47.04562 file name is -  g_7_26.tif
# gen flagged -  39.260338 file name is -  g_7_22.tif
# gen flagged -  43.166046 file name is -  g_7_23.tif
# gen flagged -  46.51772 file name is -  g_7_11.tif
# gen flagged -  52.229813 file name is -  g_7_27.tif
# gen flagged -  40.32992 file name is -  g_7_25.tif
# gen flagged -  39.196148 file name is -  g_7_1.tif
# gen flagged -  49.747246 file name is -  g_7_2.tif
# When k is  33
# gen flagged -  38.637146 file name is -  g_33_22.tif
# gen flagged -  39.85406 file name is -  g_33_27.tif
# gen flagged -  34.859077 file name is -  g_33_1.tif
# gen flagged -  37.325214 file name is -  g_33_23.tif
# gen flagged -  36.73392 file name is -  g_33_7.tif
# gen flagged -  47.13337 file name is -  g_33_12.tif
# gen flagged -  40.57613 file name is -  g_33_24.tif
# gen flagged -  32.690567 file name is -  g_33_21.tif
# gen flagged -  38.473995 file name is -  g_33_25.tif
# gen flagged -  41.326702 file name is -  g_33_18.tif
# gen flagged -  40.84678 file name is -  g_33_16.tif
# gen flagged -  39.021927 file name is -  g_33_11.tif
# gen flagged -  37.373657 file name is -  g_33_15.tif
# gen flagged -  38.06497 file name is -  g_33_8.tif
# gen flagged -  37.209595 file name is -  g_33_4.tif
# gen flagged -  40.591854 file name is -  g_33_14.tif
# gen flagged -  38.957054 file name is -  g_33_2.tif
# gen flagged -  36.753025 file name is -  g_33_17.tif
# gen flagged -  33.77577 file name is -  g_33_5.tif
# gen flagged -  33.63011 file name is -  g_33_19.tif
# gen flagged -  38.285088 file name is -  g_33_9.tif
# gen flagged -  44.56413 file name is -  g_33_10.tif
# gen flagged -  34.30327 file name is -  g_33_6.tif
# gen flagged -  36.28297 file name is -  g_33_26.tif
# forg passed -  29.473946 file name is -  fSi_33_13.tif
# When k is  27
# gen flagged -  52.25195 file name is -  g_27_2.tif
# gen flagged -  53.164307 file name is -  g_27_16.tif
# gen flagged -  62.95592 file name is -  g_27_1.tif
# gen flagged -  51.371872 file name is -  g_27_25.tif
# gen flagged -  51.996643 file name is -  g_27_22.tif
# gen flagged -  51.258747 file name is -  g_27_13.tif
# gen flagged -  48.70846 file name is -  g_27_15.tif
# gen flagged -  52.938915 file name is -  g_27_23.tif
# gen flagged -  46.248993 file name is -  g_27_11.tif
# gen flagged -  62.840797 file name is -  g_27_26.tif
# gen flagged -  58.57829 file name is -  g_27_3.tif
# gen flagged -  51.021854 file name is -  g_27_27.tif
# gen flagged -  47.103397 file name is -  g_27_9.tif
# gen flagged -  48.710953 file name is -  g_27_7.tif
# gen flagged -  61.8339 file name is -  g_27_24.tif
# gen flagged -  57.891308 file name is -  g_27_20.tif
# gen flagged -  63.038025 file name is -  g_27_8.tif
# gen flagged -  53.564358 file name is -  g_27_19.tif
# gen flagged -  56.31875 file name is -  g_27_10.tif
# gen flagged -  48.738228 file name is -  g_27_14.tif
# gen flagged -  49.806072 file name is -  g_27_18.tif
# gen flagged -  53.60238 file name is -  g_27_12.tif
# gen flagged -  51.9181 file name is -  g_27_5.tif
# gen flagged -  45.608006 file name is -  g_27_4.tif
# gen flagged -  53.60238 file name is -  g_27_6.tif
# gen flagged -  52.730484 file name is -  g_27_21.tif
# When k is  106
# gen flagged -  39.773968 file name is -  g_106_2.tif
# gen flagged -  48.792465 file name is -  g_106_7.tif
# gen flagged -  46.59825 file name is -  g_106_23.tif
# gen flagged -  43.63205 file name is -  g_106_19.tif
# gen flagged -  48.503345 file name is -  g_106_8.tif
# gen flagged -  43.136024 file name is -  g_106_9.tif
# gen flagged -  43.52238 file name is -  g_106_1.tif
# gen flagged -  43.695915 file name is -  g_106_24.tif
# gen flagged -  40.686943 file name is -  g_106_11.tif
# gen flagged -  44.138496 file name is -  g_106_12.tif
# gen flagged -  60.085552 file name is -  g_106_25.tif
# gen flagged -  43.07856 file name is -  g_106_4.tif
# gen flagged -  52.02217 file name is -  g_106_26.tif
# gen flagged -  35.27385 file name is -  g_106_21.tif
# gen flagged -  45.052124 file name is -  g_106_18.tif
# gen flagged -  47.40379 file name is -  g_106_3.tif
# gen flagged -  48.21313 file name is -  g_106_10.tif
# gen flagged -  45.8236 file name is -  g_106_17.tif
# gen flagged -  46.849155 file name is -  g_106_6.tif
# gen flagged -  50.332638 file name is -  g_106_16.tif
# gen flagged -  44.001568 file name is -  g_106_27.tif
# gen flagged -  47.20735 file name is -  g_106_15.tif
# gen flagged -  45.457832 file name is -  g_106_5.tif
# gen flagged -  47.486927 file name is -  g_106_14.tif
# gen flagged -  59.940063 file name is -  g_106_20.tif
# gen flagged -  42.45609 file name is -  g_106_13.tif
# When k is  84
# gen flagged -  42.980495 file name is -  g_84_6.tif
# gen flagged -  37.934307 file name is -  g_84_22.tif
# gen flagged -  38.386066 file name is -  g_84_2.tif
# gen flagged -  38.707573 file name is -  g_84_11.tif
# gen flagged -  36.553097 file name is -  g_84_26.tif
# gen flagged -  44.92565 file name is -  g_84_13.tif
# gen flagged -  38.598045 file name is -  g_84_25.tif
# gen flagged -  38.604626 file name is -  g_84_3.tif
# gen flagged -  47.780155 file name is -  g_84_17.tif
# gen flagged -  37.664085 file name is -  g_84_16.tif
# gen flagged -  34.91326 file name is -  g_84_8.tif
# gen flagged -  40.477398 file name is -  g_84_19.tif
# gen flagged -  36.139256 file name is -  g_84_24.tif
# gen flagged -  33.655964 file name is -  g_84_23.tif
# gen flagged -  39.74972 file name is -  g_84_10.tif
# gen flagged -  49.587196 file name is -  g_84_9.tif
# gen flagged -  36.045574 file name is -  g_84_21.tif
# gen flagged -  40.784817 file name is -  g_84_15.tif
# gen flagged -  35.02982 file name is -  g_84_14.tif
# gen flagged -  43.246563 file name is -  g_84_18.tif
# gen flagged -  40.84489 file name is -  g_84_1.tif
# gen flagged -  37.864086 file name is -  g_84_27.tif
# gen flagged -  41.413857 file name is -  g_84_7.tif
# gen flagged -  37.104637 file name is -  g_84_12.tif
# gen flagged -  48.758873 file name is -  g_84_20.tif
# When k is  80
# gen flagged -  38.053482 file name is -  g_80_8.tif
# gen flagged -  49.438522 file name is -  g_80_15.tif
# gen flagged -  38.9013 file name is -  g_80_12.tif
# gen flagged -  38.081528 file name is -  g_80_11.tif
# gen flagged -  57.71575 file name is -  g_80_14.tif
# gen flagged -  40.48197 file name is -  g_80_2.tif
# gen flagged -  38.76265 file name is -  g_80_7.tif
# gen flagged -  44.25838 file name is -  g_80_16.tif
# gen flagged -  43.13292 file name is -  g_80_17.tif
# gen flagged -  44.19624 file name is -  g_80_3.tif
# gen flagged -  53.075813 file name is -  g_80_19.tif
# gen flagged -  39.078472 file name is -  g_80_9.tif
# gen flagged -  49.896065 file name is -  g_80_18.tif
# gen flagged -  42.77192 file name is -  g_80_1.tif
# gen flagged -  38.566853 file name is -  g_80_23.tif
# gen flagged -  50.05877 file name is -  g_80_22.tif
# gen flagged -  55.399517 file name is -  g_80_5.tif
# gen flagged -  39.075897 file name is -  g_80_13.tif
# gen flagged -  44.694057 file name is -  g_80_20.tif
# gen flagged -  49.299862 file name is -  g_80_27.tif
# gen flagged -  47.93217 file name is -  g_80_26.tif
# gen flagged -  48.37761 file name is -  g_80_21.tif
# gen flagged -  36.57362 file name is -  g_80_4.tif
# gen flagged -  38.148403 file name is -  g_80_24.tif
# gen flagged -  74.43511 file name is -  g_80_6.tif
# gen flagged -  37.499393 file name is -  g_80_10.tif
# When k is  4
# gen flagged -  34.43434 file name is -  g_4_21.tif
# gen flagged -  47.776707 file name is -  g_4_1.tif
# gen flagged -  41.655037 file name is -  g_4_15.tif
# gen flagged -  42.51757 file name is -  g_4_5.tif
# gen flagged -  34.992496 file name is -  g_4_8.tif
# gen flagged -  32.81505 file name is -  g_4_27.tif
# gen flagged -  32.521305 file name is -  g_4_13.tif
# gen flagged -  32.172363 file name is -  g_4_18.tif
# gen flagged -  34.285248 file name is -  g_4_14.tif
# gen flagged -  47.174984 file name is -  g_4_22.tif
# gen flagged -  35.87415 file name is -  g_4_24.tif
# gen flagged -  34.66126 file name is -  g_4_4.tif
# gen flagged -  36.140568 file name is -  g_4_11.tif
# gen flagged -  33.106438 file name is -  g_4_9.tif
# gen flagged -  53.980186 file name is -  g_4_26.tif
# gen flagged -  41.52351 file name is -  g_4_25.tif
# gen flagged -  39.772263 file name is -  g_4_17.tif
# gen flagged -  43.36693 file name is -  g_4_2.tif
# gen flagged -  38.75723 file name is -  g_4_19.tif
# gen flagged -  37.410595 file name is -  g_4_12.tif
# gen flagged -  39.211163 file name is -  g_4_20.tif
# gen flagged -  43.60602 file name is -  g_4_10.tif
# When k is  79
# gen flagged -  36.796745 file name is -  g_79_18.tif
# gen flagged -  36.57357 file name is -  g_79_13.tif
# gen flagged -  46.444588 file name is -  g_79_26.tif
# gen flagged -  39.026814 file name is -  g_79_5.tif
# gen flagged -  35.458332 file name is -  g_79_10.tif
# gen flagged -  39.063374 file name is -  g_79_17.tif
# gen flagged -  35.113747 file name is -  g_79_16.tif
# gen flagged -  34.521973 file name is -  g_79_12.tif
# gen flagged -  37.36815 file name is -  g_79_11.tif
# gen flagged -  32.687485 file name is -  g_79_20.tif
# gen flagged -  34.774227 file name is -  g_79_3.tif
# gen flagged -  35.137993 file name is -  g_79_24.tif
# gen flagged -  37.19746 file name is -  g_79_14.tif
# gen flagged -  39.105793 file name is -  g_79_21.tif
# gen flagged -  48.107395 file name is -  g_79_9.tif
# gen flagged -  42.909042 file name is -  g_79_1.tif
# gen flagged -  37.600735 file name is -  g_79_25.tif
# gen flagged -  36.782932 file name is -  g_79_6.tif
# gen flagged -  38.91809 file name is -  g_79_23.tif
# gen flagged -  33.94142 file name is -  g_79_2.tif
# gen flagged -  39.52505 file name is -  g_79_15.tif
# gen flagged -  41.41326 file name is -  g_79_8.tif
# gen flagged -  32.491524 file name is -  g_79_22.tif
# When k is  38
# gen flagged -  39.887077 file name is -  g_38_4.tif
# gen flagged -  36.61166 file name is -  g_38_23.tif
# gen flagged -  32.12226 file name is -  g_38_2.tif
# gen flagged -  36.98824 file name is -  g_38_17.tif
# gen flagged -  44.74602 file name is -  g_38_13.tif
# gen flagged -  39.969173 file name is -  g_38_20.tif
# gen flagged -  39.545055 file name is -  g_38_26.tif
# gen flagged -  36.66027 file name is -  g_38_24.tif
# gen flagged -  35.507576 file name is -  g_38_18.tif
# gen flagged -  37.07587 file name is -  g_38_25.tif
# gen flagged -  37.97033 file name is -  g_38_6.tif
# gen flagged -  36.60576 file name is -  g_38_21.tif
# gen flagged -  33.471703 file name is -  g_38_11.tif
# gen flagged -  38.53063 file name is -  g_38_7.tif
# gen flagged -  40.07434 file name is -  g_38_8.tif
# gen flagged -  37.39539 file name is -  g_38_9.tif
# gen flagged -  35.618515 file name is -  g_38_12.tif
# gen flagged -  36.10158 file name is -  g_38_19.tif
# gen flagged -  35.98603 file name is -  g_38_14.tif
# gen flagged -  39.199764 file name is -  g_38_5.tif
# When k is  104
# gen flagged -  38.121338 file name is -  g_104_21.tif
# gen flagged -  45.45468 file name is -  g_104_24.tif
# gen flagged -  37.949535 file name is -  g_104_20.tif
# gen flagged -  46.950348 file name is -  g_104_9.tif
# gen flagged -  41.58161 file name is -  g_104_15.tif
# gen flagged -  36.87155 file name is -  g_104_2.tif
# gen flagged -  37.646534 file name is -  g_104_13.tif
# gen flagged -  41.592247 file name is -  g_104_14.tif
# gen flagged -  44.058258 file name is -  g_104_4.tif
# gen flagged -  39.599117 file name is -  g_104_7.tif
# gen flagged -  40.02748 file name is -  g_104_23.tif
# gen flagged -  43.825966 file name is -  g_104_18.tif
# gen flagged -  46.614315 file name is -  g_104_25.tif
# gen flagged -  42.716415 file name is -  g_104_16.tif
# gen flagged -  38.873642 file name is -  g_104_27.tif
# gen flagged -  41.803955 file name is -  g_104_8.tif
# gen flagged -  45.601524 file name is -  g_104_6.tif
# gen flagged -  37.73449 file name is -  g_104_19.tif
# gen flagged -  39.093647 file name is -  g_104_22.tif
# gen flagged -  37.058758 file name is -  g_104_3.tif
# gen flagged -  38.345234 file name is -  g_104_12.tif
# gen flagged -  41.2445 file name is -  g_104_1.tif
# gen flagged -  41.93584 file name is -  g_104_26.tif
# gen flagged -  39.595947 file name is -  g_104_17.tif
# gen flagged -  45.765614 file name is -  g_104_5.tif
# When k is  70
# gen flagged -  43.245636 file name is -  g_70_15.tif
# gen flagged -  43.70214 file name is -  g_70_3.tif
# gen flagged -  47.955696 file name is -  g_70_11.tif
# gen flagged -  42.625164 file name is -  g_70_17.tif
# gen flagged -  50.021698 file name is -  g_70_26.tif
# gen flagged -  44.070526 file name is -  g_70_2.tif
# gen flagged -  53.526188 file name is -  g_70_9.tif
# gen flagged -  60.303715 file name is -  g_70_7.tif
# gen flagged -  41.513653 file name is -  g_70_23.tif
# gen flagged -  46.86108 file name is -  g_70_5.tif
# gen flagged -  47.87654 file name is -  g_70_14.tif
# gen flagged -  57.99998 file name is -  g_70_18.tif
# gen flagged -  42.34137 file name is -  g_70_21.tif
# gen flagged -  50.823364 file name is -  g_70_25.tif
# gen flagged -  49.07227 file name is -  g_70_4.tif
# gen flagged -  37.98761 file name is -  g_70_1.tif
# gen flagged -  44.213383 file name is -  g_70_12.tif
# gen flagged -  48.41391 file name is -  g_70_8.tif
# gen flagged -  38.601917 file name is -  g_70_27.tif
# gen flagged -  42.348583 file name is -  g_70_24.tif
# gen flagged -  43.879665 file name is -  g_70_10.tif
# gen flagged -  49.195618 file name is -  g_70_16.tif
# gen flagged -  56.46301 file name is -  g_70_20.tif
# gen flagged -  38.901592 file name is -  g_70_22.tif
# gen flagged -  49.51464 file name is -  g_70_6.tif
# gen flagged -  32.452305 file name is -  g_70_19.tif
# base_forg_passed is  1
# base_gen_flagged is  614
# False Acceptance Rate (FAR) =  0.08888888888888889 %
# False Rejection Rate (FRR) =  94.46153846153847 %

# %%
  #****
  i = 0
  print("Iteration: " + str(i))
  weight = path + weights[0]
  model1.load_weights(weight)
  
  forg_passed=0
  gen_flagged=0

  for k in test: #the id of signatures you want to check
    print("When k is ", k)
    anc1,anc2,neg,pos=getfilest(k,gent,forgt)
    
    anchor1=returnimages(gent,anc1)
    anchor2=returnimages(gent,anc2)
    for i in range(len(pos)): #pos
        positive=returnimages(gent,pos[i])
        x=model1.predict([anchor1,positive,anchor2])
        a1, p, a2 = x[0,0:512], x[0,512:1024], x[0,1024:1536]
        #dist=sum(a-p)
        
        #Taking two distances (two anchor images), and taking average between the two
        dist1=np.linalg.norm(a1-p)
        dist2=np.linalg.norm(a2-p)
        dist=(dist1+dist2)/2
        #print("positive distance is ",dist)
        if(dist>32):
        #  print("0")
            gen_flagged=gen_flagged+1
            print("gen flagged - ",dist, "file name is - ", pos[i])
            
        else:
            gen_flagged=gen_flagged
        #   print("1")
        
    for j in range(len(neg)): #neg
        negative=returnimages(forgt,neg[j])
        x=model1.predict([anchor1,negative,anchor2])
        a1, n, a2 = x[0,0:512], x[0,512:1024], x[0,1024:1536]
        #dist=sum(a-n)
        dist1=np.linalg.norm(a1-n)
        dist2=np.linalg.norm(a2-n)
        #print("negative distance is ",dist)
        dist=(dist1+dist2)/2
        if(dist>32):
            forg_passed=forg_passed
          #  print("0")
        else:
            forg_passed=forg_passed+1
            print("forg passed - ",dist, "file name is - ", neg[j])
          #  print("1")

  print("base_forg_passed is ",forg_passed)
  print("base_gen_flagged is ",gen_flagged)
  print("False Acceptance Rate (FAR) = ", str(100*forg_passed/tneg), "%")
  print("False Rejection Rate (FRR) = ", str(100*gen_flagged/tpos), "%")
# Out:
# Iteration: 0
# When k is  68
# gen flagged -  47.522430419921875 file name is -  g_68_27.tif
# gen flagged -  39.76295471191406 file name is -  g_68_23.tif
# gen flagged -  33.80369186401367 file name is -  g_68_10.tif
# gen flagged -  37.645294189453125 file name is -  g_68_24.tif
# gen flagged -  33.596092224121094 file name is -  g_68_15.tif
# gen flagged -  37.49573516845703 file name is -  g_68_22.tif
# gen flagged -  32.589454650878906 file name is -  g_68_6.tif
# gen flagged -  32.64154815673828 file name is -  g_68_21.tif
# gen flagged -  32.30549621582031 file name is -  g_68_8.tif
# gen flagged -  35.18745040893555 file name is -  g_68_25.tif
# gen flagged -  39.551429748535156 file name is -  g_68_26.tif
# gen flagged -  33.14993667602539 file name is -  g_68_4.tif
# gen flagged -  34.7947998046875 file name is -  g_68_1.tif
# gen flagged -  32.776397705078125 file name is -  g_68_19.tif
# gen flagged -  42.32879638671875 file name is -  g_68_20.tif
# gen flagged -  44.92810821533203 file name is -  g_68_2.tif
# gen flagged -  40.09933090209961 file name is -  g_68_7.tif
# gen flagged -  39.120887756347656 file name is -  g_68_3.tif
# When k is  77
# gen flagged -  43.1390495300293 file name is -  g_77_15.tif
# gen flagged -  43.54696273803711 file name is -  g_77_4.tif
# gen flagged -  43.42375946044922 file name is -  g_77_19.tif
# gen flagged -  45.321075439453125 file name is -  g_77_26.tif
# gen flagged -  49.19605255126953 file name is -  g_77_16.tif
# gen flagged -  39.467689514160156 file name is -  g_77_3.tif
# gen flagged -  41.314788818359375 file name is -  g_77_2.tif
# gen flagged -  41.07881164550781 file name is -  g_77_23.tif
# gen flagged -  37.33265686035156 file name is -  g_77_6.tif
# gen flagged -  45.28124237060547 file name is -  g_77_11.tif
# gen flagged -  40.3082160949707 file name is -  g_77_8.tif
# gen flagged -  42.59561538696289 file name is -  g_77_25.tif
# gen flagged -  47.86181640625 file name is -  g_77_20.tif
# gen flagged -  45.814029693603516 file name is -  g_77_14.tif
# gen flagged -  43.682106018066406 file name is -  g_77_9.tif
# gen flagged -  49.65812683105469 file name is -  g_77_17.tif
# gen flagged -  46.28936004638672 file name is -  g_77_12.tif
# gen flagged -  51.72294235229492 file name is -  g_77_18.tif
# gen flagged -  47.23286056518555 file name is -  g_77_27.tif
# gen flagged -  47.11512756347656 file name is -  g_77_10.tif
# gen flagged -  39.314029693603516 file name is -  g_77_7.tif
# gen flagged -  42.86451721191406 file name is -  g_77_1.tif
# gen flagged -  47.17079162597656 file name is -  g_77_22.tif
# gen flagged -  38.834983825683594 file name is -  g_77_13.tif
# gen flagged -  48.50383758544922 file name is -  g_77_24.tif
# When k is  21
# gen flagged -  40.5243034362793 file name is -  g_21_6.tif
# gen flagged -  32.2088737487793 file name is -  g_21_3.tif
# gen flagged -  39.03755569458008 file name is -  g_21_15.tif
# gen flagged -  37.30644607543945 file name is -  g_21_10.tif
# gen flagged -  36.84685134887695 file name is -  g_21_26.tif
# gen flagged -  33.039756774902344 file name is -  g_21_13.tif
# gen flagged -  34.21287536621094 file name is -  g_21_9.tif
# gen flagged -  42.575496673583984 file name is -  g_21_4.tif
# gen flagged -  32.115570068359375 file name is -  g_21_21.tif
# gen flagged -  35.58290100097656 file name is -  g_21_5.tif
# gen flagged -  33.87849807739258 file name is -  g_21_19.tif
# gen flagged -  33.509857177734375 file name is -  g_21_1.tif
# gen flagged -  34.48912048339844 file name is -  g_21_2.tif
# gen flagged -  36.61945724487305 file name is -  g_21_14.tif
# gen flagged -  42.531219482421875 file name is -  g_21_11.tif
# gen flagged -  53.39182662963867 file name is -  g_21_25.tif
# When k is  10
# gen flagged -  43.84056091308594 file name is -  g_10_17.tif
# gen flagged -  51.570350646972656 file name is -  g_10_3.tif
# gen flagged -  44.91661071777344 file name is -  g_10_25.tif
# gen flagged -  47.32788848876953 file name is -  g_10_2.tif
# gen flagged -  47.45770263671875 file name is -  g_10_27.tif
# gen flagged -  44.1453742980957 file name is -  g_10_20.tif
# gen flagged -  42.857627868652344 file name is -  g_10_24.tif
# gen flagged -  46.336692810058594 file name is -  g_10_15.tif
# gen flagged -  43.50617218017578 file name is -  g_10_9.tif
# gen flagged -  45.0760498046875 file name is -  g_10_4.tif
# gen flagged -  45.158966064453125 file name is -  g_10_11.tif
# gen flagged -  44.15476989746094 file name is -  g_10_19.tif
# gen flagged -  43.9630012512207 file name is -  g_10_18.tif
# gen flagged -  43.463592529296875 file name is -  g_10_14.tif
# gen flagged -  53.22594451904297 file name is -  g_10_22.tif
# gen flagged -  42.73548126220703 file name is -  g_10_10.tif
# gen flagged -  48.97707748413086 file name is -  g_10_12.tif
# gen flagged -  44.93633270263672 file name is -  g_10_6.tif
# gen flagged -  41.653865814208984 file name is -  g_10_8.tif
# gen flagged -  41.903480529785156 file name is -  g_10_1.tif
# gen flagged -  42.47594451904297 file name is -  g_10_23.tif
# gen flagged -  44.10242462158203 file name is -  g_10_16.tif
# gen flagged -  45.492942810058594 file name is -  g_10_26.tif
# gen flagged -  46.298316955566406 file name is -  g_10_7.tif
# gen flagged -  43.12914276123047 file name is -  g_10_13.tif
# When k is  111
# gen flagged -  50.25006103515625 file name is -  g_111_7.tif
# gen flagged -  40.84687042236328 file name is -  g_111_24.tif
# gen flagged -  37.656532287597656 file name is -  g_111_14.tif
# gen flagged -  43.254425048828125 file name is -  g_111_27.tif
# gen flagged -  41.661128997802734 file name is -  g_111_15.tif
# gen flagged -  47.95829772949219 file name is -  g_111_3.tif
# gen flagged -  38.468482971191406 file name is -  g_111_20.tif
# gen flagged -  41.68576431274414 file name is -  g_111_2.tif
# gen flagged -  53.12836456298828 file name is -  g_111_8.tif
# gen flagged -  46.368289947509766 file name is -  g_111_10.tif
# gen flagged -  41.2820930480957 file name is -  g_111_16.tif
# gen flagged -  47.43733215332031 file name is -  g_111_5.tif
# gen flagged -  40.78559875488281 file name is -  g_111_21.tif
# gen flagged -  46.030067443847656 file name is -  g_111_1.tif
# gen flagged -  41.017189025878906 file name is -  g_111_12.tif
# gen flagged -  42.11903381347656 file name is -  g_111_11.tif
# gen flagged -  51.05531692504883 file name is -  g_111_9.tif
# gen flagged -  39.350791931152344 file name is -  g_111_23.tif
# gen flagged -  37.887969970703125 file name is -  g_111_25.tif
# gen flagged -  53.26322555541992 file name is -  g_111_6.tif
# gen flagged -  38.70623016357422 file name is -  g_111_19.tif
# gen flagged -  37.10969543457031 file name is -  g_111_18.tif
# gen flagged -  49.89344787597656 file name is -  g_111_4.tif
# gen flagged -  38.08129119873047 file name is -  g_111_13.tif
# gen flagged -  46.436500549316406 file name is -  g_111_26.tif
# When k is  32
# gen flagged -  51.332374572753906 file name is -  g_32_16.tif
# gen flagged -  44.346221923828125 file name is -  g_32_7.tif
# gen flagged -  33.85135269165039 file name is -  g_32_17.tif
# gen flagged -  41.65778350830078 file name is -  g_32_25.tif
# gen flagged -  36.46803665161133 file name is -  g_32_18.tif
# gen flagged -  37.81468200683594 file name is -  g_32_19.tif
# gen flagged -  48.78057098388672 file name is -  g_32_5.tif
# gen flagged -  33.092315673828125 file name is -  g_32_10.tif
# gen flagged -  37.363746643066406 file name is -  g_32_2.tif
# gen flagged -  41.62859344482422 file name is -  g_32_9.tif
# gen flagged -  41.87810134887695 file name is -  g_32_8.tif
# gen flagged -  48.852882385253906 file name is -  g_32_15.tif
# gen flagged -  56.46344757080078 file name is -  g_32_1.tif
# gen flagged -  44.21770477294922 file name is -  g_32_22.tif
# gen flagged -  53.72714614868164 file name is -  g_32_23.tif
# gen flagged -  49.13436508178711 file name is -  g_32_13.tif
# gen flagged -  49.21240234375 file name is -  g_32_4.tif
# gen flagged -  54.82255172729492 file name is -  g_32_6.tif
# gen flagged -  56.8756103515625 file name is -  g_32_20.tif
# gen flagged -  38.75595474243164 file name is -  g_32_21.tif
# gen flagged -  44.087646484375 file name is -  g_32_3.tif
# gen flagged -  43.122955322265625 file name is -  g_32_11.tif
# gen flagged -  36.16035461425781 file name is -  g_32_27.tif
# gen flagged -  49.400665283203125 file name is -  g_32_12.tif
# gen flagged -  48.21641540527344 file name is -  g_32_14.tif
# When k is  67
# gen flagged -  37.857383728027344 file name is -  g_67_7.tif
# gen flagged -  33.378089904785156 file name is -  g_67_8.tif
# gen flagged -  35.46495819091797 file name is -  g_67_23.tif
# gen flagged -  37.71010208129883 file name is -  g_67_6.tif
# gen flagged -  37.82098388671875 file name is -  g_67_17.tif
# gen flagged -  36.43586730957031 file name is -  g_67_3.tif
# gen flagged -  36.354949951171875 file name is -  g_67_5.tif
# gen flagged -  34.613365173339844 file name is -  g_67_13.tif
# gen flagged -  35.56809997558594 file name is -  g_67_19.tif
# gen flagged -  38.83726501464844 file name is -  g_67_4.tif
# gen flagged -  37.01994323730469 file name is -  g_67_18.tif
# gen flagged -  43.9629020690918 file name is -  g_67_10.tif
# gen flagged -  34.33592987060547 file name is -  g_67_16.tif
# gen flagged -  32.01124954223633 file name is -  g_67_25.tif
# gen flagged -  41.13487243652344 file name is -  g_67_22.tif
# gen flagged -  33.45055389404297 file name is -  g_67_26.tif
# gen flagged -  39.79986572265625 file name is -  g_67_21.tif
# gen flagged -  36.30095672607422 file name is -  g_67_9.tif
# gen flagged -  45.70356369018555 file name is -  g_67_15.tif
# gen flagged -  34.36901092529297 file name is -  g_67_14.tif
# gen flagged -  36.985687255859375 file name is -  g_67_12.tif
# gen flagged -  37.870460510253906 file name is -  g_67_11.tif
# gen flagged -  34.73162841796875 file name is -  g_67_1.tif
# gen flagged -  33.79443359375 file name is -  g_67_20.tif
# When k is  1
# gen flagged -  42.42998504638672 file name is -  g_1_8.tif
# gen flagged -  43.86041259765625 file name is -  g_1_3.tif
# gen flagged -  48.0782585144043 file name is -  g_1_26.tif
# gen flagged -  38.413204193115234 file name is -  g_1_20.tif
# gen flagged -  44.320091247558594 file name is -  g_1_25.tif
# gen flagged -  36.36946105957031 file name is -  g_1_1.tif
# gen flagged -  42.683067321777344 file name is -  g_1_2.tif
# gen flagged -  40.72038269042969 file name is -  g_1_17.tif
# gen flagged -  34.90617370605469 file name is -  g_1_22.tif
# gen flagged -  40.04961013793945 file name is -  g_1_6.tif
# gen flagged -  36.79090118408203 file name is -  g_1_9.tif
# gen flagged -  44.72665023803711 file name is -  g_1_27.tif
# gen flagged -  42.99578094482422 file name is -  g_1_15.tif
# gen flagged -  41.00306701660156 file name is -  g_1_19.tif
# gen flagged -  48.13499450683594 file name is -  g_1_10.tif
# gen flagged -  39.308692932128906 file name is -  g_1_13.tif
# gen flagged -  49.32520294189453 file name is -  g_1_4.tif
# gen flagged -  39.77325439453125 file name is -  g_1_16.tif
# gen flagged -  38.665733337402344 file name is -  g_1_23.tif
# gen flagged -  43.2536506652832 file name is -  g_1_14.tif
# gen flagged -  47.44678497314453 file name is -  g_1_18.tif
# gen flagged -  41.80803298950195 file name is -  g_1_11.tif
# gen flagged -  44.25600814819336 file name is -  g_1_5.tif
# gen flagged -  47.94103240966797 file name is -  g_1_7.tif
# gen flagged -  43.53843688964844 file name is -  g_1_21.tif
# When k is  60
# gen flagged -  38.785789489746094 file name is -  g_60_27.tif
# gen flagged -  40.90114212036133 file name is -  g_60_8.tif
# gen flagged -  43.45764923095703 file name is -  g_60_6.tif
# gen flagged -  35.010902404785156 file name is -  g_60_21.tif
# gen flagged -  44.971473693847656 file name is -  g_60_9.tif
# gen flagged -  37.372314453125 file name is -  g_60_17.tif
# gen flagged -  44.543663024902344 file name is -  g_60_24.tif
# gen flagged -  49.65345764160156 file name is -  g_60_19.tif
# gen flagged -  39.67382049560547 file name is -  g_60_23.tif
# gen flagged -  43.964012145996094 file name is -  g_60_13.tif
# gen flagged -  37.45526885986328 file name is -  g_60_11.tif
# gen flagged -  39.39045333862305 file name is -  g_60_4.tif
# gen flagged -  40.97821807861328 file name is -  g_60_2.tif
# gen flagged -  36.608070373535156 file name is -  g_60_14.tif
# gen flagged -  38.49476623535156 file name is -  g_60_16.tif
# gen flagged -  38.10616683959961 file name is -  g_60_3.tif
# gen flagged -  55.71320724487305 file name is -  g_60_26.tif
# gen flagged -  36.149749755859375 file name is -  g_60_18.tif
# gen flagged -  38.58367919921875 file name is -  g_60_5.tif
# gen flagged -  46.59117889404297 file name is -  g_60_10.tif
# gen flagged -  50.04431915283203 file name is -  g_60_20.tif
# gen flagged -  47.811737060546875 file name is -  g_60_1.tif
# gen flagged -  38.15572738647461 file name is -  g_60_7.tif
# gen flagged -  40.512184143066406 file name is -  g_60_22.tif
# gen flagged -  39.2115478515625 file name is -  g_60_15.tif
# When k is  11
# gen flagged -  56.19554901123047 file name is -  g_11_13.tif
# gen flagged -  51.42280578613281 file name is -  g_11_4.tif
# gen flagged -  52.83488845825195 file name is -  g_11_7.tif
# gen flagged -  46.623687744140625 file name is -  g_11_24.tif
# gen flagged -  46.5601921081543 file name is -  g_11_3.tif
# gen flagged -  55.574424743652344 file name is -  g_11_21.tif
# gen flagged -  42.89369201660156 file name is -  g_11_6.tif
# gen flagged -  45.065704345703125 file name is -  g_11_27.tif
# gen flagged -  50.06772232055664 file name is -  g_11_10.tif
# gen flagged -  48.310977935791016 file name is -  g_11_23.tif
# gen flagged -  44.237525939941406 file name is -  g_11_14.tif
# gen flagged -  41.72979736328125 file name is -  g_11_2.tif
# gen flagged -  44.986549377441406 file name is -  g_11_22.tif
# gen flagged -  51.81666564941406 file name is -  g_11_11.tif
# gen flagged -  59.53874969482422 file name is -  g_11_25.tif
# gen flagged -  46.59413146972656 file name is -  g_11_26.tif
# gen flagged -  36.91969299316406 file name is -  g_11_20.tif
# gen flagged -  47.369842529296875 file name is -  g_11_12.tif
# gen flagged -  37.12976837158203 file name is -  g_11_16.tif
# gen flagged -  52.8540153503418 file name is -  g_11_1.tif
# gen flagged -  50.54295349121094 file name is -  g_11_5.tif
# gen flagged -  42.79413604736328 file name is -  g_11_18.tif
# gen flagged -  52.073944091796875 file name is -  g_11_9.tif
# gen flagged -  44.616432189941406 file name is -  g_11_15.tif
# gen flagged -  53.62543487548828 file name is -  g_11_8.tif
# When k is  18
# gen flagged -  44.97087097167969 file name is -  g_18_8.tif
# gen flagged -  43.1883659362793 file name is -  g_18_2.tif
# gen flagged -  42.97857666015625 file name is -  g_18_15.tif
# gen flagged -  52.95167541503906 file name is -  g_18_1.tif
# gen flagged -  41.346588134765625 file name is -  g_18_9.tif
# gen flagged -  41.08194351196289 file name is -  g_18_21.tif
# gen flagged -  36.803855895996094 file name is -  g_18_6.tif
# gen flagged -  46.270713806152344 file name is -  g_18_13.tif
# gen flagged -  39.97209930419922 file name is -  g_18_19.tif
# gen flagged -  46.02734375 file name is -  g_18_24.tif
# gen flagged -  47.09731674194336 file name is -  g_18_22.tif
# gen flagged -  42.43214416503906 file name is -  g_18_4.tif
# gen flagged -  45.90325927734375 file name is -  g_18_20.tif
# gen flagged -  39.78966522216797 file name is -  g_18_25.tif
# gen flagged -  48.64314270019531 file name is -  g_18_14.tif
# gen flagged -  37.99690628051758 file name is -  g_18_7.tif
# gen flagged -  48.47496795654297 file name is -  g_18_18.tif
# gen flagged -  48.274452209472656 file name is -  g_18_11.tif
# gen flagged -  41.2995719909668 file name is -  g_18_12.tif
# gen flagged -  39.7477912902832 file name is -  g_18_17.tif
# gen flagged -  42.01911163330078 file name is -  g_18_16.tif
# gen flagged -  47.74730682373047 file name is -  g_18_27.tif
# gen flagged -  40.486473083496094 file name is -  g_18_5.tif
# gen flagged -  47.85564422607422 file name is -  g_18_26.tif
# gen flagged -  52.38471221923828 file name is -  g_18_23.tif
# When k is  83
# gen flagged -  37.08233642578125 file name is -  g_83_16.tif
# gen flagged -  33.37023162841797 file name is -  g_83_13.tif
# gen flagged -  32.33320999145508 file name is -  g_83_14.tif
# gen flagged -  34.183284759521484 file name is -  g_83_7.tif
# gen flagged -  35.728553771972656 file name is -  g_83_5.tif
# gen flagged -  33.729705810546875 file name is -  g_83_8.tif
# gen flagged -  32.58334732055664 file name is -  g_83_18.tif
# gen flagged -  36.98295211791992 file name is -  g_83_12.tif
# gen flagged -  36.133636474609375 file name is -  g_83_6.tif
# gen flagged -  32.57891082763672 file name is -  g_83_22.tif
# gen flagged -  38.94871139526367 file name is -  g_83_21.tif
# gen flagged -  39.61539840698242 file name is -  g_83_24.tif
# gen flagged -  33.37372970581055 file name is -  g_83_10.tif
# gen flagged -  33.30243682861328 file name is -  g_83_2.tif
# gen flagged -  32.30393981933594 file name is -  g_83_17.tif
# gen flagged -  36.628902435302734 file name is -  g_83_1.tif
# gen flagged -  39.319122314453125 file name is -  g_83_19.tif
# gen flagged -  35.888893127441406 file name is -  g_83_9.tif
# gen flagged -  33.35894775390625 file name is -  g_83_4.tif
# gen flagged -  38.90625762939453 file name is -  g_83_23.tif
# gen flagged -  40.635154724121094 file name is -  g_83_3.tif
# gen flagged -  37.32587432861328 file name is -  g_83_15.tif
# gen flagged -  35.478126525878906 file name is -  g_83_11.tif
# gen flagged -  35.75617218017578 file name is -  g_83_26.tif
# When k is  49
# gen flagged -  39.884159088134766 file name is -  g_49_19.tif
# gen flagged -  47.399742126464844 file name is -  g_49_12.tif
# gen flagged -  47.77973175048828 file name is -  g_49_26.tif
# gen flagged -  42.02998733520508 file name is -  g_49_6.tif
# gen flagged -  40.94241714477539 file name is -  g_49_25.tif
# gen flagged -  45.83357238769531 file name is -  g_49_16.tif
# gen flagged -  47.95947265625 file name is -  g_49_15.tif
# gen flagged -  42.394561767578125 file name is -  g_49_11.tif
# gen flagged -  41.33916473388672 file name is -  g_49_4.tif
# gen flagged -  53.69203186035156 file name is -  g_49_24.tif
# gen flagged -  45.81238555908203 file name is -  g_49_17.tif
# gen flagged -  48.759193420410156 file name is -  g_49_2.tif
# gen flagged -  39.309635162353516 file name is -  g_49_14.tif
# gen flagged -  45.04328155517578 file name is -  g_49_3.tif
# gen flagged -  45.57596206665039 file name is -  g_49_13.tif
# gen flagged -  40.09234619140625 file name is -  g_49_21.tif
# gen flagged -  35.50026321411133 file name is -  g_49_7.tif
# gen flagged -  50.991607666015625 file name is -  g_49_18.tif
# gen flagged -  56.100502014160156 file name is -  g_49_23.tif
# gen flagged -  44.11524963378906 file name is -  g_49_1.tif
# gen flagged -  42.40360641479492 file name is -  g_49_10.tif
# gen flagged -  43.6658935546875 file name is -  g_49_5.tif
# gen flagged -  53.30731964111328 file name is -  g_49_8.tif
# gen flagged -  46.23881530761719 file name is -  g_49_22.tif
# gen flagged -  42.93660354614258 file name is -  g_49_20.tif
# When k is  51
# gen flagged -  57.74546813964844 file name is -  g_51_5.tif
# gen flagged -  68.3087158203125 file name is -  g_51_17.tif
# gen flagged -  57.371192932128906 file name is -  g_51_2.tif
# gen flagged -  60.92573547363281 file name is -  g_51_26.tif
# gen flagged -  54.51201629638672 file name is -  g_51_10.tif
# gen flagged -  58.770912170410156 file name is -  g_51_4.tif
# gen flagged -  56.684730529785156 file name is -  g_51_12.tif
# gen flagged -  61.82418441772461 file name is -  g_51_15.tif
# gen flagged -  57.189109802246094 file name is -  g_51_18.tif
# gen flagged -  63.564056396484375 file name is -  g_51_6.tif
# gen flagged -  63.3945198059082 file name is -  g_51_8.tif
# gen flagged -  65.92498016357422 file name is -  g_51_20.tif
# gen flagged -  68.81822967529297 file name is -  g_51_13.tif
# gen flagged -  65.90799713134766 file name is -  g_51_21.tif
# gen flagged -  57.44612121582031 file name is -  g_51_16.tif
# gen flagged -  68.95565795898438 file name is -  g_51_22.tif
# gen flagged -  63.556182861328125 file name is -  g_51_7.tif
# gen flagged -  59.679344177246094 file name is -  g_51_11.tif
# gen flagged -  63.750526428222656 file name is -  g_51_3.tif
# gen flagged -  59.26959228515625 file name is -  g_51_27.tif
# gen flagged -  54.67323303222656 file name is -  g_51_25.tif
# gen flagged -  64.90299987792969 file name is -  g_51_9.tif
# gen flagged -  64.57942962646484 file name is -  g_51_19.tif
# gen flagged -  55.3907470703125 file name is -  g_51_1.tif
# gen flagged -  63.53300857543945 file name is -  g_51_14.tif
# When k is  7
# gen flagged -  42.69968795776367 file name is -  g_7_7.tif
# gen flagged -  47.875587463378906 file name is -  g_7_13.tif
# gen flagged -  42.760162353515625 file name is -  g_7_24.tif
# gen flagged -  45.629554748535156 file name is -  g_7_3.tif
# gen flagged -  47.74943923950195 file name is -  g_7_21.tif
# gen flagged -  44.4691162109375 file name is -  g_7_18.tif
# gen flagged -  46.078399658203125 file name is -  g_7_5.tif
# gen flagged -  47.353294372558594 file name is -  g_7_8.tif
# gen flagged -  42.390052795410156 file name is -  g_7_15.tif
# gen flagged -  43.54050827026367 file name is -  g_7_17.tif
# gen flagged -  44.588623046875 file name is -  g_7_10.tif
# gen flagged -  46.302268981933594 file name is -  g_7_4.tif
# gen flagged -  47.03532409667969 file name is -  g_7_9.tif
# gen flagged -  45.51715850830078 file name is -  g_7_12.tif
# gen flagged -  49.65641784667969 file name is -  g_7_6.tif
# gen flagged -  57.46685028076172 file name is -  g_7_20.tif
# gen flagged -  45.24638366699219 file name is -  g_7_16.tif
# gen flagged -  54.814510345458984 file name is -  g_7_19.tif
# gen flagged -  47.91238021850586 file name is -  g_7_26.tif
# gen flagged -  44.404296875 file name is -  g_7_22.tif
# gen flagged -  40.63700485229492 file name is -  g_7_23.tif
# gen flagged -  48.92308807373047 file name is -  g_7_11.tif
# gen flagged -  47.69978332519531 file name is -  g_7_27.tif
# gen flagged -  41.98298645019531 file name is -  g_7_25.tif
# gen flagged -  44.008365631103516 file name is -  g_7_1.tif
# When k is  33
# gen flagged -  37.52039337158203 file name is -  g_33_22.tif
# gen flagged -  35.630455017089844 file name is -  g_33_27.tif
# gen flagged -  33.88743591308594 file name is -  g_33_1.tif
# gen flagged -  35.38478469848633 file name is -  g_33_7.tif
# gen flagged -  48.07141876220703 file name is -  g_33_12.tif
# gen flagged -  39.58558654785156 file name is -  g_33_24.tif
# gen flagged -  32.30291748046875 file name is -  g_33_21.tif
# gen flagged -  36.58842849731445 file name is -  g_33_25.tif
# gen flagged -  39.108909606933594 file name is -  g_33_18.tif
# gen flagged -  40.89372253417969 file name is -  g_33_16.tif
# gen flagged -  38.746307373046875 file name is -  g_33_11.tif
# gen flagged -  35.513336181640625 file name is -  g_33_15.tif
# gen flagged -  35.33017349243164 file name is -  g_33_8.tif
# gen flagged -  33.635746002197266 file name is -  g_33_3.tif
# gen flagged -  37.94858169555664 file name is -  g_33_4.tif
# gen flagged -  33.752689361572266 file name is -  g_33_20.tif
# gen flagged -  40.37196350097656 file name is -  g_33_14.tif
# gen flagged -  32.92254638671875 file name is -  g_33_2.tif
# gen flagged -  38.40314865112305 file name is -  g_33_17.tif
# gen flagged -  35.535552978515625 file name is -  g_33_5.tif
# gen flagged -  37.29798889160156 file name is -  g_33_19.tif
# gen flagged -  33.94733428955078 file name is -  g_33_9.tif
# gen flagged -  41.66587829589844 file name is -  g_33_10.tif
# gen flagged -  34.45819854736328 file name is -  g_33_6.tif
# When k is  27
# gen flagged -  50.41872787475586 file name is -  g_27_2.tif
# gen flagged -  51.13388442993164 file name is -  g_27_16.tif
# gen flagged -  58.01423263549805 file name is -  g_27_1.tif
# gen flagged -  47.563209533691406 file name is -  g_27_25.tif
# gen flagged -  51.12525939941406 file name is -  g_27_22.tif
# gen flagged -  50.07080841064453 file name is -  g_27_13.tif
# gen flagged -  49.317466735839844 file name is -  g_27_15.tif
# gen flagged -  49.119041442871094 file name is -  g_27_23.tif
# gen flagged -  44.19931411743164 file name is -  g_27_11.tif
# gen flagged -  57.51760482788086 file name is -  g_27_26.tif
# gen flagged -  50.70746994018555 file name is -  g_27_3.tif
# gen flagged -  47.23786163330078 file name is -  g_27_27.tif
# gen flagged -  48.98008728027344 file name is -  g_27_9.tif
# gen flagged -  46.700687408447266 file name is -  g_27_7.tif
# gen flagged -  59.203006744384766 file name is -  g_27_24.tif
# gen flagged -  50.86445617675781 file name is -  g_27_20.tif
# gen flagged -  59.95391082763672 file name is -  g_27_8.tif
# gen flagged -  51.94593048095703 file name is -  g_27_19.tif
# gen flagged -  51.760719299316406 file name is -  g_27_10.tif
# gen flagged -  49.22477722167969 file name is -  g_27_14.tif
# gen flagged -  46.455352783203125 file name is -  g_27_18.tif
# gen flagged -  51.137184143066406 file name is -  g_27_12.tif
# gen flagged -  48.07500457763672 file name is -  g_27_5.tif
# gen flagged -  45.42720031738281 file name is -  g_27_4.tif
# gen flagged -  51.137184143066406 file name is -  g_27_6.tif
# When k is  106
# gen flagged -  37.11092758178711 file name is -  g_106_2.tif
# gen flagged -  52.121360778808594 file name is -  g_106_7.tif
# gen flagged -  49.66172790527344 file name is -  g_106_23.tif
# gen flagged -  43.60302734375 file name is -  g_106_19.tif
# gen flagged -  43.734031677246094 file name is -  g_106_8.tif
# gen flagged -  40.893714904785156 file name is -  g_106_9.tif
# gen flagged -  40.67347717285156 file name is -  g_106_1.tif
# gen flagged -  41.5672492980957 file name is -  g_106_24.tif
# gen flagged -  39.339027404785156 file name is -  g_106_11.tif
# gen flagged -  46.35065460205078 file name is -  g_106_12.tif
# gen flagged -  62.20283508300781 file name is -  g_106_25.tif
# gen flagged -  40.85382843017578 file name is -  g_106_4.tif
# gen flagged -  47.6024169921875 file name is -  g_106_26.tif
# gen flagged -  38.786800384521484 file name is -  g_106_21.tif
# gen flagged -  45.165016174316406 file name is -  g_106_18.tif
# gen flagged -  41.96644592285156 file name is -  g_106_3.tif
# gen flagged -  43.71855163574219 file name is -  g_106_10.tif
# gen flagged -  45.653564453125 file name is -  g_106_17.tif
# gen flagged -  47.51499938964844 file name is -  g_106_6.tif
# gen flagged -  47.9400634765625 file name is -  g_106_16.tif
# gen flagged -  47.99079132080078 file name is -  g_106_27.tif
# gen flagged -  46.23589324951172 file name is -  g_106_15.tif
# gen flagged -  47.274192810058594 file name is -  g_106_5.tif
# gen flagged -  43.75204086303711 file name is -  g_106_14.tif
# gen flagged -  60.45207214355469 file name is -  g_106_20.tif
# When k is  84
# gen flagged -  45.82554244995117 file name is -  g_84_6.tif
# gen flagged -  42.365264892578125 file name is -  g_84_22.tif
# gen flagged -  40.74378967285156 file name is -  g_84_2.tif
# gen flagged -  49.57132339477539 file name is -  g_84_11.tif
# gen flagged -  41.55760955810547 file name is -  g_84_26.tif
# gen flagged -  51.339752197265625 file name is -  g_84_13.tif
# gen flagged -  40.085670471191406 file name is -  g_84_5.tif
# gen flagged -  49.86497497558594 file name is -  g_84_25.tif
# gen flagged -  43.158409118652344 file name is -  g_84_3.tif
# gen flagged -  53.90521240234375 file name is -  g_84_17.tif
# gen flagged -  43.38103103637695 file name is -  g_84_16.tif
# gen flagged -  46.97797775268555 file name is -  g_84_8.tif
# gen flagged -  46.770809173583984 file name is -  g_84_19.tif
# gen flagged -  45.10881805419922 file name is -  g_84_24.tif
# gen flagged -  37.78673553466797 file name is -  g_84_23.tif
# gen flagged -  43.99745178222656 file name is -  g_84_10.tif
# gen flagged -  45.094200134277344 file name is -  g_84_9.tif
# gen flagged -  41.88505554199219 file name is -  g_84_21.tif
# gen flagged -  47.02099609375 file name is -  g_84_15.tif
# gen flagged -  40.866519927978516 file name is -  g_84_14.tif
# gen flagged -  55.257049560546875 file name is -  g_84_18.tif
# gen flagged -  51.92716979980469 file name is -  g_84_1.tif
# gen flagged -  44.433380126953125 file name is -  g_84_27.tif
# gen flagged -  41.890289306640625 file name is -  g_84_7.tif
# gen flagged -  43.024024963378906 file name is -  g_84_12.tif
# When k is  80
# gen flagged -  38.740943908691406 file name is -  g_80_8.tif
# gen flagged -  48.66386032104492 file name is -  g_80_15.tif
# gen flagged -  39.05979537963867 file name is -  g_80_12.tif
# gen flagged -  39.9237174987793 file name is -  g_80_11.tif
# gen flagged -  57.36402130126953 file name is -  g_80_14.tif
# gen flagged -  42.72809600830078 file name is -  g_80_2.tif
# gen flagged -  40.142601013183594 file name is -  g_80_7.tif
# gen flagged -  41.64189910888672 file name is -  g_80_16.tif
# gen flagged -  40.700889587402344 file name is -  g_80_17.tif
# gen flagged -  44.97142028808594 file name is -  g_80_3.tif
# gen flagged -  49.33758544921875 file name is -  g_80_19.tif
# gen flagged -  42.6367301940918 file name is -  g_80_9.tif
# gen flagged -  47.60614776611328 file name is -  g_80_18.tif
# gen flagged -  44.58622360229492 file name is -  g_80_1.tif
# gen flagged -  41.409210205078125 file name is -  g_80_23.tif
# gen flagged -  48.75959014892578 file name is -  g_80_22.tif
# gen flagged -  58.633155822753906 file name is -  g_80_5.tif
# gen flagged -  38.78790283203125 file name is -  g_80_13.tif
# gen flagged -  43.84778594970703 file name is -  g_80_20.tif
# gen flagged -  51.669437408447266 file name is -  g_80_27.tif
# gen flagged -  49.328773498535156 file name is -  g_80_26.tif
# gen flagged -  49.6241455078125 file name is -  g_80_21.tif
# gen flagged -  40.68159103393555 file name is -  g_80_4.tif
# gen flagged -  40.89574432373047 file name is -  g_80_24.tif
# gen flagged -  78.16026306152344 file name is -  g_80_6.tif
# When k is  4
# gen flagged -  38.48707580566406 file name is -  g_4_21.tif
# gen flagged -  46.732749938964844 file name is -  g_4_1.tif
# gen flagged -  36.77623748779297 file name is -  g_4_15.tif
# gen flagged -  41.02630615234375 file name is -  g_4_5.tif
# gen flagged -  37.936859130859375 file name is -  g_4_23.tif
# gen flagged -  39.629642486572266 file name is -  g_4_8.tif
# gen flagged -  36.55757141113281 file name is -  g_4_27.tif
# gen flagged -  36.144771575927734 file name is -  g_4_13.tif
# gen flagged -  35.59217071533203 file name is -  g_4_18.tif
# gen flagged -  40.281005859375 file name is -  g_4_14.tif
# gen flagged -  55.09178161621094 file name is -  g_4_22.tif
# gen flagged -  40.604522705078125 file name is -  g_4_24.tif
# gen flagged -  37.51255416870117 file name is -  g_4_4.tif
# gen flagged -  39.466156005859375 file name is -  g_4_11.tif
# gen flagged -  37.05108642578125 file name is -  g_4_9.tif
# gen flagged -  43.256561279296875 file name is -  g_4_26.tif
# gen flagged -  38.853179931640625 file name is -  g_4_7.tif
# gen flagged -  46.82179260253906 file name is -  g_4_25.tif
# gen flagged -  38.01588821411133 file name is -  g_4_3.tif
# gen flagged -  41.150611877441406 file name is -  g_4_17.tif
# gen flagged -  38.97385025024414 file name is -  g_4_2.tif
# gen flagged -  35.609012603759766 file name is -  g_4_19.tif
# gen flagged -  36.7740592956543 file name is -  g_4_12.tif
# gen flagged -  41.06324768066406 file name is -  g_4_20.tif
# When k is  79
# gen flagged -  36.15187454223633 file name is -  g_79_18.tif
# gen flagged -  38.14326477050781 file name is -  g_79_13.tif
# gen flagged -  47.93924331665039 file name is -  g_79_26.tif
# gen flagged -  38.493865966796875 file name is -  g_79_5.tif
# gen flagged -  33.760772705078125 file name is -  g_79_10.tif
# gen flagged -  40.42395782470703 file name is -  g_79_17.tif
# gen flagged -  38.10059356689453 file name is -  g_79_16.tif
# gen flagged -  36.20233154296875 file name is -  g_79_12.tif
# gen flagged -  37.74855041503906 file name is -  g_79_11.tif
# gen flagged -  32.66685485839844 file name is -  g_79_20.tif
# gen flagged -  38.111083984375 file name is -  g_79_3.tif
# gen flagged -  36.984764099121094 file name is -  g_79_14.tif
# gen flagged -  38.464908599853516 file name is -  g_79_21.tif
# gen flagged -  47.51655197143555 file name is -  g_79_9.tif
# gen flagged -  43.88352966308594 file name is -  g_79_1.tif
# gen flagged -  38.63731384277344 file name is -  g_79_25.tif
# gen flagged -  33.713260650634766 file name is -  g_79_6.tif
# gen flagged -  40.74290084838867 file name is -  g_79_23.tif
# gen flagged -  32.592491149902344 file name is -  g_79_27.tif
# gen flagged -  34.858436584472656 file name is -  g_79_2.tif
# gen flagged -  39.72577667236328 file name is -  g_79_15.tif
# gen flagged -  41.59977722167969 file name is -  g_79_8.tif
# When k is  38
# gen flagged -  34.716331481933594 file name is -  g_38_4.tif
# gen flagged -  39.223724365234375 file name is -  g_38_23.tif
# gen flagged -  33.289398193359375 file name is -  g_38_2.tif
# gen flagged -  39.69504165649414 file name is -  g_38_17.tif
# gen flagged -  45.885986328125 file name is -  g_38_13.tif
# gen flagged -  40.97019577026367 file name is -  g_38_20.tif
# gen flagged -  41.403282165527344 file name is -  g_38_26.tif
# gen flagged -  39.48960876464844 file name is -  g_38_24.tif
# gen flagged -  33.062564849853516 file name is -  g_38_1.tif
# gen flagged -  35.88397216796875 file name is -  g_38_16.tif
# gen flagged -  36.34977722167969 file name is -  g_38_18.tif
# gen flagged -  38.57518005371094 file name is -  g_38_25.tif
# gen flagged -  32.355262756347656 file name is -  g_38_27.tif
# gen flagged -  34.82744598388672 file name is -  g_38_15.tif
# gen flagged -  34.31523895263672 file name is -  g_38_6.tif
# gen flagged -  34.073829650878906 file name is -  g_38_21.tif
# gen flagged -  36.4586181640625 file name is -  g_38_11.tif
# gen flagged -  33.74641799926758 file name is -  g_38_7.tif
# gen flagged -  38.07726287841797 file name is -  g_38_8.tif
# gen flagged -  33.10047149658203 file name is -  g_38_9.tif
# gen flagged -  33.54193878173828 file name is -  g_38_12.tif
# gen flagged -  38.86924743652344 file name is -  g_38_19.tif
# gen flagged -  37.44771957397461 file name is -  g_38_14.tif
# gen flagged -  32.27103805541992 file name is -  g_38_10.tif
# When k is  104
# gen flagged -  43.43159866333008 file name is -  g_104_21.tif
# gen flagged -  45.8447151184082 file name is -  g_104_24.tif
# gen flagged -  43.70077896118164 file name is -  g_104_20.tif
# gen flagged -  47.40455627441406 file name is -  g_104_9.tif
# gen flagged -  40.73332595825195 file name is -  g_104_15.tif
# gen flagged -  40.69132995605469 file name is -  g_104_2.tif
# gen flagged -  39.92998123168945 file name is -  g_104_13.tif
# gen flagged -  42.775794982910156 file name is -  g_104_14.tif
# gen flagged -  48.45672607421875 file name is -  g_104_4.tif
# gen flagged -  44.21073913574219 file name is -  g_104_7.tif
# gen flagged -  44.107704162597656 file name is -  g_104_23.tif
# gen flagged -  45.19306182861328 file name is -  g_104_18.tif
# gen flagged -  50.385902404785156 file name is -  g_104_25.tif
# gen flagged -  39.90984344482422 file name is -  g_104_16.tif
# gen flagged -  44.161808013916016 file name is -  g_104_27.tif
# gen flagged -  44.48088836669922 file name is -  g_104_8.tif
# gen flagged -  49.023651123046875 file name is -  g_104_6.tif
# gen flagged -  39.374229431152344 file name is -  g_104_19.tif
# gen flagged -  42.60660934448242 file name is -  g_104_22.tif
# gen flagged -  40.70155334472656 file name is -  g_104_3.tif
# gen flagged -  43.29841613769531 file name is -  g_104_12.tif
# gen flagged -  35.80970001220703 file name is -  g_104_10.tif
# gen flagged -  44.576194763183594 file name is -  g_104_1.tif
# gen flagged -  42.916988372802734 file name is -  g_104_26.tif
# gen flagged -  43.08570098876953 file name is -  g_104_17.tif
# When k is  70
# gen flagged -  39.14790725708008 file name is -  g_70_15.tif
# gen flagged -  40.532875061035156 file name is -  g_70_3.tif
# gen flagged -  43.95643615722656 file name is -  g_70_11.tif
# gen flagged -  40.041603088378906 file name is -  g_70_17.tif
# gen flagged -  46.09796905517578 file name is -  g_70_26.tif
# gen flagged -  41.654327392578125 file name is -  g_70_2.tif
# gen flagged -  49.415191650390625 file name is -  g_70_9.tif
# gen flagged -  56.230735778808594 file name is -  g_70_7.tif
# gen flagged -  38.58904266357422 file name is -  g_70_23.tif
# gen flagged -  42.177513122558594 file name is -  g_70_5.tif
# gen flagged -  42.22624969482422 file name is -  g_70_14.tif
# gen flagged -  53.372100830078125 file name is -  g_70_18.tif
# gen flagged -  37.62871170043945 file name is -  g_70_21.tif
# gen flagged -  47.326622009277344 file name is -  g_70_25.tif
# gen flagged -  46.45872497558594 file name is -  g_70_4.tif
# gen flagged -  37.74272918701172 file name is -  g_70_1.tif
# gen flagged -  40.307865142822266 file name is -  g_70_12.tif
# gen flagged -  45.927574157714844 file name is -  g_70_8.tif
# gen flagged -  36.07231903076172 file name is -  g_70_27.tif
# gen flagged -  42.53486633300781 file name is -  g_70_24.tif
# gen flagged -  39.68888854980469 file name is -  g_70_10.tif
# gen flagged -  45.183448791503906 file name is -  g_70_16.tif
# gen flagged -  52.17106246948242 file name is -  g_70_20.tif
# gen flagged -  38.34547805786133 file name is -  g_70_22.tif
# gen flagged -  44.72212219238281 file name is -  g_70_6.tif
# base_forg_passed is  0
# base_gen_flagged is  601
# False Acceptance Rate (FAR) =  0.0 %
# False Rejection Rate (FRR) =  92.46153846153847 %
