# %% [markdown]
# <a href="https://colab.research.google.com/github/hchristiaan/TrainCNN4SignatureVerification/blob/master/ProjectCode_Base_seed30.ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Please note that:
#     # - Means comment explaining the code
#     ### - Means things that need to be addressed

# %%
from google.colab import auth
auth.authenticate_user()

import requests
gcloud_token = !gcloud auth print-access-token
gcloud_tokeninfo = requests.get('https://www.googleapis.com/oauth2/v3/tokeninfo?access_token=' + gcloud_token[0]).json()
email = gcloud_tokeninfo['email']
username = email.split('@')[0]
print(username)
# Out:
# hchr147

# %%
# Import all required repositories for the project
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2

import keras
import keras.backend as K
import tensorflow as tf
from keras import applications
from keras.models import Model
from keras.layers import Flatten, Dense, Input,concatenate
from keras.optimizers import Adam
from keras.models import load_model, model_from_json

import random
# Out:
# Using TensorFlow backend.

# %%
# Import the google drive to upload the data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import datetime

now = datetime.datetime.now()
date = now.strftime("%Y%m%d%H%M")

print(date)
# Out:
# 201906020721

# %%
# Unzip the image dataset
# !unzip '/content/drive/Team Drives/inputdataset/UTSig.zip' -d /content
# Out:
# Archive:  /content/drive/Team Drives/inputdataset/UTSig.zip
#    creating: /content/UTSig/Forgery/
#    creating: /content/UTSig/Forgery/Opposite Hand/
#    creating: /content/UTSig/Forgery/Opposite Hand/1/
#   inflating: /content/UTSig/Forgery/Opposite Hand/1/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/1/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/1/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/10/
#   inflating: /content/UTSig/Forgery/Opposite Hand/10/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/10/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/10/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/100/
#   inflating: /content/UTSig/Forgery/Opposite Hand/100/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/100/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/100/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/101/
#   inflating: /content/UTSig/Forgery/Opposite Hand/101/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/101/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/101/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/102/
#   inflating: /content/UTSig/Forgery/Opposite Hand/102/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/102/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/102/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/103/
#   inflating: /content/UTSig/Forgery/Opposite Hand/103/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/103/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/103/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/104/
#   inflating: /content/UTSig/Forgery/Opposite Hand/104/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/104/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/104/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/105/
#   inflating: /content/UTSig/Forgery/Opposite Hand/105/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/105/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/105/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/106/
#   inflating: /content/UTSig/Forgery/Opposite Hand/106/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/106/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/106/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/107/
#   inflating: /content/UTSig/Forgery/Opposite Hand/107/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/107/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/107/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/108/
#   inflating: /content/UTSig/Forgery/Opposite Hand/108/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/108/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/108/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/109/
#   inflating: /content/UTSig/Forgery/Opposite Hand/109/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/109/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/109/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/11/
#   inflating: /content/UTSig/Forgery/Opposite Hand/11/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/11/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/11/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/110/
#   inflating: /content/UTSig/Forgery/Opposite Hand/110/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/110/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/110/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/111/
#   inflating: /content/UTSig/Forgery/Opposite Hand/111/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/111/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/111/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/112/
#   inflating: /content/UTSig/Forgery/Opposite Hand/112/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/112/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/112/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/113/
#   inflating: /content/UTSig/Forgery/Opposite Hand/113/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/113/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/113/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/114/
#   inflating: /content/UTSig/Forgery/Opposite Hand/114/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/114/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/114/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/115/
#   inflating: /content/UTSig/Forgery/Opposite Hand/115/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/115/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/115/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/12/
#   inflating: /content/UTSig/Forgery/Opposite Hand/12/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/12/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/12/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/13/
#   inflating: /content/UTSig/Forgery/Opposite Hand/13/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/13/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/13/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/14/
#   inflating: /content/UTSig/Forgery/Opposite Hand/14/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand
1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/80/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/80/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/81/
#   inflating: /content/UTSig/Forgery/Opposite Hand/81/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/81/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/81/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/82/
#   inflating: /content/UTSig/Forgery/Opposite Hand/82/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/82/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/82/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/83/
#   inflating: /content/UTSig/Forgery/Opposite Hand/83/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/83/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/83/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/84/
#   inflating: /content/UTSig/Forgery/Opposite Hand/84/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/84/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/84/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/85/
#   inflating: /content/UTSig/Forgery/Opposite Hand/85/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/85/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/85/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/86/
#   inflating: /content/UTSig/Forgery/Opposite Hand/86/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/86/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/86/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/87/
#   inflating: /content/UTSig/Forgery/Opposite Hand/87/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/87/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/87/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/88/
#   inflating: /content/UTSig/Forgery/Opposite Hand/88/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/88/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/88/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/89/
#   inflating: /content/UTSig/Forgery/Opposite Hand/89/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/89/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/89/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/9/
#   inflating: /content/UTSig/Forgery/Opposite Hand/9/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/9/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/9/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/90/
#   inflating: /content/UTSig/Forgery/Opposite Hand/90/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/90/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/90/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/91/
#   inflating: /content/UTSig/Forgery/Opposite Hand/91/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/91/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/91/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/92/
#   inflating: /content/UTSig/Forgery/Opposite Hand/92/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/92/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/92/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/93/
#   inflating: /content/UTSig/Forgery/Opposite Hand/93/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/93/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/93/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/94/
#   inflating: /content/UTSig/Forgery/Opposite Hand/94/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/94/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/94/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/95/
#   inflating: /content/UTSig/Forgery/Opposite Hand/95/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/95/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/95/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/96/
#   inflating: /content/UTSig/Forgery/Opposite Hand/96/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/96/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/96/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/97/
#   inflating: /content/UTSig/Forgery/Opposite Hand/97/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/97/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/97/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/98/
#   inflating: /content/UTSig/Forgery/Opposite Hand/98/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/98/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/98/3.tif
#    creating: /content/UTSig/Forgery/Opposite Hand/99/
#   inflating: /content/UTSig/Forgery/Opposite Hand/99/1.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/99/2.tif
#   inflating: /content/UTSig/Forgery/Opposite Hand/99/3.tif
#    creating: /content/UTSig/Forgery/Simple/
#    creating: /content/UTSig/Forgery/Simple/1/
#   inflating: /content/UTSig/Forgery/Simple/1/11.tif
#   inflating: /content/UTSig/Forgery/Simple/1/12.tif
#   inflating: /content/UTSig/Forgery/Simple/1/13.tif
#   inflating: /content/UTSig/Forgery/Simple/1/14.tif
#   inflating: /content/UTSig/Forgery/Simple/1/15.tif
#   inflating: /content/UTSig/Forgery/Simple/1/16.tif
#   inflating: /content/UTSig/Forgery/Simple/1/21.tif
#   inflating: /content/UTSig/Forgery/Simple/1/22.tif
#   inflating: /content/UTSig/Forgery/Simple/1/23.tif
#   inflating: /content/UTSig/Forgery/Simple/1/24.tif
#   inflating: /content/UTSig/Forgery/Simple/1/25.tif
#   inflating: /content/UTSig/Forgery/Simple/1/26.tif
#   inflating: /content/UTSig/Forgery/Simple/1/31.tif
#   inflating: /content/UTSig/Forgery/Simple/1/32.tif
#   inflating: /content/UTSig/Forgery/Simple/1/33.tif
#   inflating: /content/UTSig/Forgery/Simple/1/34.tif
#   inflating: /content/UTSig/Forgery/Simple/1/35.tif
#   inflating: /content/UTSig/Forgery/Simple/1/36.tif
#   inflating: /content/UTSig/Forgery/Simple/1/41.tif
#   inflating: /content/UTSig/Forgery/Simple/1/42.tif
#   inflating: /content/UTSig/Forgery/Simple/1/43.tif
#   inflating: /content/UTSig/Forgery/Simple/1/44.tif
#   inflating: /content/UTSig/Forgery/Simple/1/45.tif
#   inflating: /content/UTSig/Forgery/Simple/1/46.tif
#   inflating: /content/UTSig/Forgery/Simple/1/51.tif
#   inflating: /content/UTSig/Forgery/Simple/1/52.tif
#   inflating: /content/UTSig/Forgery/Simple/1/53.tif
#   inflating: /content/UTSig/Forgery/Simple/1/54.tif
#   inflating: /content/UTSig/Forgery/Simple/1/55.tif
#   inflating: /content/UTSig/Forgery/Simple/1/56.tif
#   inflating: /content/UTSig/Forgery/Simple/1/61.tif
#   inflating: /content/UTSig/Forgery/Simple/1/62.tif
#   inflating: /content/UTSig/Forgery/Simple/1/63.tif
#   inflating: /content/UTSig/Forgery/Simple/1/64.tif
#   inflating: /content/UTSig/Forgery/Simple/1/65.tif
#   inflating: /content/UTSig/Forgery/Simple/1/66.tif
#    creating: /content/UTSig/Forgery/Simple/10/
#   inflating: /content/UTSig/Forgery/Simple/10/11.tif
#   inflating: /content/UTSig/Forgery/Simple/10/12.tif
#   inflating: /content/UTSig/Forgery/Simple/10/13.tif
#   inflating: /content/UTSig/Forgery/Simple/10/14.tif
#   inflating: /content/UTSig/Forgery/Simple/10/15.tif
#   inflating: /content/UTSig/Forgery/Simple/10/16.tif
#   inflating: /content/UTSig/Forgery/Simple/10/21.tif
#   inflating: /content/UTSig/Forgery/Simple/10/22.tif
#   inflating: /content/UTSig/Forgery/Simple/10/23.tif
#   inflating: /content/UTSig/Forgery/Simple/10/24.tif
#   inflating: /content/UTSig/Forgery/Simple/10/25.tif
#   inflating: /content/UTSig/Forgery/Simple/10/26.tif
#   inflating: /content/UTSig/Forgery/Simple/10/31.tif
#   inflating: /content/UTSig/Forgery/Simple/10/32.tif
#   inflating: /content/UTSig/Forgery/Simple/10/33.tif
#   inflating: /content/UTSig/Forgery/Simple/10/34.tif
#   inflating: /content/UTSig/Forgery/Simple/10/35.tif
#   inflating: /content/UTSig/Forgery/Simple/10/36.tif
#   inflating: /content/UTSig/Forgery/Simple/10/41.tif
#   inflating: /content/UTSig/Forgery/Simple/10/42.tif
#   inflating: /content/UTSig/Forgery/Simple/10/43.tif
#   inflating: /content/UTSig/Forgery/Simple/10/44.tif
#   inflating: /content/UTSig/Forgery/Simple/10/45.tif
#   inflating: /content/UTSig/Forgery/Simple/10/46.tif
#   inflating: /content/UTSig/Forgery/Simple/10/51.tif
#   inflating: /content/UTSig/Forgery/Simple/10/52.tif
#   inflating: /content/UTSig/Forgery/Simple/10/53.tif
#   inflating: /content/UTSig/Forgery/Simple/10/54.tif
#   inflating: /content/UTSig/Forgery/Simple/10/55.tif
#   inflating: /content/UTSig/Forgery/Simple/10/56.tif
#   inflating: /content/UTSig/Forgery/Simple/10/61.tif
#   inflating: /content/UTSig/Forgery/Simple/10/62.tif
#   inflating: /content/UTSig/Forgery/Simple/10/63.tif
#   inflating: /content/UTSig/Forgery/Simple/10/64.tif
#   inflating: /content/UTSig/Forgery/Simple/10/65.tif
#   inflating: /content/UTSig/Forgery/Simple/106/64.tif
#   inflating: /content/UTSig/Forgery/Simple/106/65.tif
#   inflating: /content/UTSig/Forgery/Simple/106/66.tif
#    creating: /content/UTSig/Forgery/Simple/107/
#   inflating: /content/UTSig/Forgery/Simple/107/11.tif
#   inflating: /content/UTSig/Forgery/Simple/107/12.tif
#   inflating: /content/UTSig/Forgery/Simple/107/13.tif
#   inflating: /content/UTSig/Forgery/Simple/107/14.tif
#   inflating: /content/UTSig/Forgery/Simple/107/15.tif
#   inflating: /content/UTSig/Forgery/Simple/107/16.tif
#   inflating: /content/UTSig/Forgery/Simple/107/21.tif
#   inflating: /content/UTSig/Forgery/Simple/107/22.tif
#   inflating: /content/UTSig/Forgery/Simple/107/23.tif
#   inflating: /content/UTSig/Forgery/Simple/107/24.tif
#   inflating: /content/UTSig/Forgery/Simple/107/25.tif
#   inflating: /content/UTSig/Forgery/Simple/107/26.tif
#   inflating: /content/UTSig/Forgery/Simple/107/31.tif
#   inflating: /content/UTSig/Forgery/Simple/107/32.tif
#   inflating: /content/UTSig/Forgery/Simple/107/33.tif
#   inflating: /content/UTSig/Forgery/Simple/107/34.tif
#   inflating: /content/UTSig/Forgery/Simple/107/35.tif
#   inflating: /content/UTSig/Forgery/Simple/107/36.tif
#   inflating: /content/UTSig/Forgery/Simple/107/41.tif
#   inflating: /content/UTSig/Forgery/Simple/107/42.tif
#   inflating: /content/UTSig/Forgery/Simple/107/43.tif
#   inflating: /content/UTSig/Forgery/Simple/107/44.tif
#   inflating: /content/UTSig/Forgery/Simple/107/45.tif
#   inflating: /content/UTSig/Forgery/Simple/107/46.tif
#   inflating: /content/UTSig/Forgery/Simple/107/51.tif
#   inflating: /content/UTSig/Forgery/Simple/107/52.tif
#   inflating: /content/UTSig/Forgery/Simple/107/53.tif
#   inflating: /content/UTSig/Forgery/Simple/107/54.tif
#   inflating: /content/UTSig/Forgery/Simple/107/55.tif
#   inflating: /content/UTSig/Forgery/Simple/107/56.tif
#   inflating: /content/UTSig/Forgery/Simple/107/61.tif
#   inflating: /content/UTSig/Forgery/Simple/107/62.tif
#   inflating: /content/UTSig/Forgery/Simple/107/63.tif
#   inflating: /content/UTSig/Forgery/Simple/107/64.tif
#   inflating: /content/UTSig/Forgery/Simple/107/65.tif
# ...
#   inflating: /content/UTSig/Genuine/88/8.tif
#   inflating: /content/UTSig/Genuine/88/9.tif
#    creating: /content/UTSig/Genuine/89/
#   inflating: /content/UTSig/Genuine/89/1.tif
#   inflating: /content/UTSig/Genuine/89/10.tif
#   inflating: /content/UTSig/Genuine/89/11.tif
#   inflating: /content/UTSig/Genuine/89/12.tif
#   inflating: /content/UTSig/Genuine/89/13.tif
#   inflating: /content/UTSig/Genuine/89/14.tif
#   inflating: /content/UTSig/Genuine/89/15.tif
#   inflating: /content/UTSig/Genuine/89/16.tif
#   inflating: /content/UTSig/Genuine/89/17.tif
#   inflating: /content/UTSig/Genuine/89/18.tif
#   inflating: /content/UTSig/Genuine/89/19.tif
#   inflating: /content/UTSig/Genuine/89/2.tif
#   inflating: /content/UTSig/Genuine/89/20.tif
#   inflating: /content/UTSig/Genuine/89/21.tif
#   inflating: /content/UTSig/Genuine/89/22.tif
#   inflating: /content/UTSig/Genuine/89/23.tif
#   inflating: /content/UTSig/Genuine/89/24.tif
#   inflating: /content/UTSig/Genuine/89/25.tif
#   inflating: /content/UTSig/Genuine/89/26.tif
#   inflating: /content/UTSig/Genuine/89/27.tif
#   inflating: /content/UTSig/Genuine/89/3.tif
#   inflating: /content/UTSig/Genuine/89/4.tif
#   inflating: /content/UTSig/Genuine/89/5.tif
#   inflating: /content/UTSig/Genuine/89/6.tif
#   inflating: /content/UTSig/Genuine/89/7.tif
#   inflating: /content/UTSig/Genuine/89/8.tif
#   inflating: /content/UTSig/Genuine/89/9.tif
#    creating: /content/UTSig/Genuine/9/
#   inflating: /content/UTSig/Genuine/9/1.tif
#   inflating: /content/UTSig/Genuine/9/10.tif
#   inflating: /content/UTSig/Genuine/9/11.tif
#   inflating: /content/UTSig/Genuine/9/12.tif
#   inflating: /content/UTSig/Genuine/9/13.tif
#   inflating: /content/UTSig/Genuine/9/14.tif
#   inflating: /content/UTSig/Genuine/9/15.tif
#   inflating: /content/UTSig/Genuine/9/16.tif
#   inflating: /content/UTSig/Genuine/9/17.tif
#   inflating: /content/UTSig/Genuine/9/18.tif
#   inflating: /content/UTSig/Genuine/9/19.tif
#   inflating: /content/UTSig/Genuine/9/2.tif
#   inflating: /content/UTSig/Genuine/9/20.tif
#   inflating: /content/UTSig/Genuine/9/21.tif
#   inflating: /content/UTSig/Genuine/9/22.tif
#   inflating: /content/UTSig/Genuine/9/23.tif
#   inflating: /content/UTSig/Genuine/9/24.tif
#   inflating: /content/UTSig/Genuine/9/25.tif
#   inflating: /content/UTSig/Genuine/9/26.tif
#   inflating: /content/UTSig/Genuine/9/27.tif
#   inflating: /content/UTSig/Genuine/9/3.tif
#   inflating: /content/UTSig/Genuine/9/4.tif
#   inflating: /content/UTSig/Genuine/9/5.tif
#   inflating: /content/UTSig/Genuine/9/6.tif
#   inflating: /content/UTSig/Genuine/9/7.tif
#   inflating: /content/UTSig/Genuine/9/8.tif
#   inflating: /content/UTSig/Genuine/9/9.tif
#    creating: /content/UTSig/Genuine/90/
#   inflating: /content/UTSig/Genuine/90/1.tif
#   inflating: /content/UTSig/Genuine/90/10.tif
#   inflating: /content/UTSig/Genuine/90/11.tif
#   inflating: /content/UTSig/Genuine/90/12.tif
#   inflating: /content/UTSig/Genuine/90/13.tif
#   inflating: /content/UTSig/Genuine/90/14.tif
#   inflating: /content/UTSig/Genuine/90/15.tif
#   inflating: /content/UTSig/Genuine/90/16.tif
#   inflating: /content/UTSig/Genuine/90/17.tif
#   inflating: /content/UTSig/Genuine/90/18.tif
#   inflating: /content/UTSig/Genuine/90/19.tif
#   inflating: /content/UTSig/Genuine/90/2.tif
#   inflating: /content/UTSig/Genuine/90/20.tif
#   inflating: /content/UTSig/Genuine/90/21.tif
#   inflating: /content/UTSig/Genuine/90/22.tif
#   inflating: /content/UTSig/Genuine/90/23.tif
#   inflating: /content/UTSig/Genuine/90/24.tif
#   inflating: /content/UTSig/Genuine/90/25.tif
#   inflating: /content/UTSig/Genuine/90/26.tif
#   inflating: /content/UTSig/Genuine/90/27.tif
#   inflating: /content/UTSig/Genuine/90/3.tif
#   inflating: /content/UTSig/Genuine/90/4.tif
#   inflating: /content/UTSig/Genuine/90/5.tif
#   inflating: /content/UTSig/Genuine/90/6.tif
#   inflating: /content/UTSig/Genuine/90/7.tif
#   inflating: /content/UTSig/Genuine/90/8.tif
#   inflating: /content/UTSig/Genuine/90/9.tif
#    creating: /content/UTSig/Genuine/91/
#   inflating: /content/UTSig/Genuine/91/1.tif
#   inflating: /content/UTSig/Genuine/91/10.tif
#   inflating: /content/UTSig/Genuine/91/11.tif
#   inflating: /content/UTSig/Genuine/91/12.tif
#   inflating: /content/UTSig/Genuine/91/13.tif
#   inflating: /content/UTSig/Genuine/91/14.tif
#   inflating: /content/UTSig/Genuine/91/15.tif
#   inflating: /content/UTSig/Genuine/91/16.tif
#   inflating: /content/UTSig/Genuine/91/17.tif
#   inflating: /content/UTSig/Genuine/91/18.tif
#   inflating: /content/UTSig/Genuine/91/19.tif
#   inflating: /content/UTSig/Genuine/91/2.tif
#   inflating: /content/UTSig/Genuine/91/20.tif
#   inflating: /content/UTSig/Genuine/91/21.tif
#   inflating: /content/UTSig/Genuine/91/22.tif
#   inflating: /content/UTSig/Genuine/91/23.tif
#   inflating: /content/UTSig/Genuine/91/24.tif
#   inflating: /content/UTSig/Genuine/91/25.tif
#   inflating: /content/UTSig/Genuine/91/26.tif
#   inflating: /content/UTSig/Genuine/91/27.tif
#   inflating: /content/UTSig/Genuine/91/3.tif
#   inflating: /content/UTSig/Genuine/91/4.tif
#   inflating: /content/UTSig/Genuine/91/5.tif
#   inflating: /content/UTSig/Genuine/91/6.tif
#   inflating: /content/UTSig/Genuine/91/7.tif
#   inflating: /content/UTSig/Genuine/91/8.tif
#   inflating: /content/UTSig/Genuine/91/9.tif
#    creating: /content/UTSig/Genuine/92/
#   inflating: /content/UTSig/Genuine/92/1.tif
#   inflating: /content/UTSig/Genuine/92/10.tif
#   inflating: /content/UTSig/Genuine/92/11.tif
#   inflating: /content/UTSig/Genuine/92/12.tif
#   inflating: /content/UTSig/Genuine/92/13.tif
#   inflating: /content/UTSig/Genuine/92/14.tif
#   inflating: /content/UTSig/Genuine/92/15.tif
#   inflating: /content/UTSig/Genuine/92/16.tif
#   inflating: /content/UTSig/Genuine/92/17.tif
#   inflating: /content/UTSig/Genuine/92/18.tif
#   inflating: /content/UTSig/Genuine/92/19.tif
#   inflating: /content/UTSig/Genuine/92/2.tif
#   inflating: /content/UTSig/Genuine/92/20.tif
#   inflating: /content/UTSig/Genuine/92/21.tif
#   inflating: /content/UTSig/Genuine/92/22.tif
#   inflating: /content/UTSig/Genuine/92/23.tif
#   inflating: /content/UTSig/Genuine/92/24.tif
#   inflating: /content/UTSig/Genuine/92/25.tif
#   inflating: /content/UTSig/Genuine/92/26.tif
#   inflating: /content/UTSig/Genuine/92/27.tif
#   inflating: /content/UTSig/Genuine/92/3.tif
#   inflating: /content/UTSig/Genuine/92/4.tif
#   inflating: /content/UTSig/Genuine/92/5.tif
#   inflating: /content/UTSig/Genuine/92/6.tif
#   inflating: /content/UTSig/Genuine/92/7.tif
#   inflating: /content/UTSig/Genuine/92/8.tif
#   inflating: /content/UTSig/Genuine/92/9.tif
#    creating: /content/UTSig/Genuine/93/
#   inflating: /content/UTSig/Genuine/93/1.tif
#   inflating: /content/UTSig/Genuine/93/10.tif
#   inflating: /content/UTSig/Genuine/93/11.tif
#   inflating: /content/UTSig/Genuine/93/12.tif
#   inflating: /content/UTSig/Genuine/93/13.tif
#   inflating: /content/UTSig/Genuine/93/14.tif
#   inflating: /content/UTSig/Genuine/93/15.tif
#   inflating: /content/UTSig/Genuine/93/16.tif
#   inflating: /content/UTSig/Genuine/93/17.tif
#   inflating: /content/UTSig/Genuine/93/18.tif
#   inflating: /content/UTSig/Genuine/93/19.tif
#   inflating: /content/UTSig/Genuine/93/2.tif
#   inflating: /content/UTSig/Genuine/93/20.tif
#   inflating: /content/UTSig/Genuine/93/21.tif
#   inflating: /content/UTSig/Genuine/93/22.tif
#   inflating: /content/UTSig/Genuine/93/23.tif
#   inflating: /content/UTSig/Genuine/93/24.tif
#   inflating: /content/UTSig/Genuine/93/25.tif
#   inflating: /content/UTSig/Genuine/93/26.tif
#   inflating: /content/UTSig/Genuine/93/27.tif
#   inflating: /content/UTSig/Genuine/93/3.tif
#   inflating: /content/UTSig/Genuine/93/4.tif
#   inflating: /content/UTSig/Genuine/93/5.tif
#   inflating: /content/UTSig/Genuine/93/6.tif
#   inflating: /content/UTSig/Genuine/93/7.tif
#   inflating: /content/UTSig/Genuine/93/8.tif
#   inflating: /content/UTSig/Genuine/93/9.tif
#    creating: /content/UTSig/Genuine/94/
#   inflating: /content/UTSig/Genuine/94/1.tif
#   inflating: /content/UTSig/Genuine/94/10.tif
#   inflating: /content/UTSig/Genuine/94/11.tif
#   inflating: /content/UTSig/Genuine/94/12.tif
#   inflating: /content/UTSig/Genuine/94/13.tif
#   inflating: /content/UTSig/Genuine/94/14.tif
#   inflating: /content/UTSig/Genuine/94/15.tif
#   inflating: /content/UTSig/Genuine/94/16.tif
#   inflating: /content/UTSig/Genuine/94/17.tif
#   inflating: /content/UTSig/Genuine/94/18.tif
#   inflating: /content/UTSig/Genuine/94/19.tif
#   inflating: /content/UTSig/Genuine/94/2.tif
#   inflating: /content/UTSig/Genuine/94/20.tif
#   inflating: /content/UTSig/Genuine/94/21.tif
#   inflating: /content/UTSig/Genuine/94/22.tif
#   inflating: /content/UTSig/Genuine/94/23.tif
#   inflating: /content/UTSig/Genuine/94/24.tif
#   inflating: /content/UTSig/Genuine/94/25.tif
#   inflating: /content/UTSig/Genuine/94/26.tif
#   inflating: /content/UTSig/Genuine/94/27.tif
#   inflating: /content/UTSig/Genuine/94/3.tif
#   inflating: /content/UTSig/Genuine/94/4.tif
#   inflating: /content/UTSig/Genuine/94/5.tif
#   inflating: /content/UTSig/Genuine/94/6.tif
#   inflating: /content/UTSig/Genuine/94/7.tif
#   inflating: /content/UTSig/Genuine/94/8.tif
#   inflating: /content/UTSig/Genuine/94/9.tif
#    creating: /content/UTSig/Genuine/95/
#   inflating: /content/UTSig/Genuine/95/1.tif
#   inflating: /content/UTSig/Genuine/95/10.tif
#   inflating: /content/UTSig/Genuine/95/11.tif
#   inflating: /content/UTSig/Genuine/95/12.tif
#   inflating: /content/UTSig/Genuine/95/13.tif
#   inflating: /content/UTSig/Genuine/95/14.tif
#   inflating: /content/UTSig/Genuine/95/15.tif
#   inflating: /content/UTSig/Genuine/95/16.tif
#   inflating: /content/UTSig/Genuine/95/17.tif
#   inflating: /content/UTSig/Genuine/95/18.tif
#   inflating: /content/UTSig/Genuine/95/19.tif
#   inflating: /content/UTSig/Genuine/95/2.tif
#   inflating: /content/UTSig/Genuine/95/20.tif
#   inflating: /content/UTSig/Genuine/95/21.tif
#   inflating: /content/UTSig/Genuine/95/22.tif
#   inflating: /content/UTSig/Genuine/95/23.tif
#   inflating: /content/UTSig/Genuine/95/24.tif
#   inflating: /content/UTSig/Genuine/95/25.tif
#   inflating: /content/UTSig/Genuine/95/26.tif
#   inflating: /content/UTSig/Genuine/95/27.tif
#   inflating: /content/UTSig/Genuine/95/3.tif
#   inflating: /content/UTSig/Genuine/95/4.tif
#   inflating: /content/UTSig/Genuine/95/5.tif
#   inflating: /content/UTSig/Genuine/95/6.tif
#   inflating: /content/UTSig/Genuine/95/7.tif
#   inflating: /content/UTSig/Genuine/95/8.tif
#   inflating: /content/UTSig/Genuine/95/9.tif
#    creating: /content/UTSig/Genuine/96/
#   inflating: /content/UTSig/Genuine/96/1.tif
#   inflating: /content/UTSig/Genuine/96/10.tif
#   inflating: /content/UTSig/Genuine/96/11.tif
#   inflating: /content/UTSig/Genuine/96/12.tif
#   inflating: /content/UTSig/Genuine/96/13.tif
#   inflating: /content/UTSig/Genuine/96/14.tif
#   inflating: /content/UTSig/Genuine/96/15.tif
#   inflating: /content/UTSig/Genuine/96/16.tif
#   inflating: /content/UTSig/Genuine/96/17.tif
#   inflating: /content/UTSig/Genuine/96/18.tif
#   inflating: /content/UTSig/Genuine/96/19.tif
#   inflating: /content/UTSig/Genuine/96/2.tif
#   inflating: /content/UTSig/Genuine/96/20.tif
#   inflating: /content/UTSig/Genuine/96/21.tif
#   inflating: /content/UTSig/Genuine/96/22.tif
#   inflating: /content/UTSig/Genuine/96/23.tif
#   inflating: /content/UTSig/Genuine/96/24.tif
#   inflating: /content/UTSig/Genuine/96/25.tif
#   inflating: /content/UTSig/Genuine/96/26.tif
#   inflating: /content/UTSig/Genuine/96/27.tif
#   inflating: /content/UTSig/Genuine/96/3.tif
#   inflating: /content/UTSig/Genuine/96/4.tif
#   inflating: /content/UTSig/Genuine/96/5.tif
#   inflating: /content/UTSig/Genuine/96/6.tif
#   inflating: /content/UTSig/Genuine/96/7.tif
#   inflating: /content/UTSig/Genuine/99/10.tif
#   inflating: /content/UTSig/Genuine/99/11.tif
#   inflating: /content/UTSig/Genuine/99/12.tif
#   inflating: /content/UTSig/Genuine/99/13.tif
#   inflating: /content/UTSig/Genuine/99/14.tif
#   inflating: /content/UTSig/Genuine/99/15.tif
#   inflating: /content/UTSig/Genuine/99/16.tif
#   inflating: /content/UTSig/Genuine/99/17.tif
#   inflating: /content/UTSig/Genuine/99/18.tif
#   inflating: /content/UTSig/Genuine/99/19.tif
#   inflating: /content/UTSig/Genuine/99/2.tif
#   inflating: /content/UTSig/Genuine/99/20.tif
#   inflating: /content/UTSig/Genuine/99/21.tif
#   inflating: /content/UTSig/Genuine/99/22.tif
#   inflating: /content/UTSig/Genuine/99/23.tif
#   inflating: /content/UTSig/Genuine/99/24.tif
#   inflating: /content/UTSig/Genuine/99/25.tif
#   inflating: /content/UTSig/Genuine/99/26.tif
#   inflating: /content/UTSig/Genuine/99/27.tif
#   inflating: /content/UTSig/Genuine/99/3.tif
#   inflating: /content/UTSig/Genuine/99/4.tif
#   inflating: /content/UTSig/Genuine/99/5.tif
#   inflating: /content/UTSig/Genuine/99/6.tif
#   inflating: /content/UTSig/Genuine/99/7.tif
#   inflating: /content/UTSig/Genuine/99/8.tif
#   inflating: /content/UTSig/Genuine/99/9.tif

# %%
# Proposed file restructing to fit this code
import os, shutil

filePath = '/content/UTSig'

filePathGen = filePath + '/Genuine'
filePathFor = filePath + '/Forgery'
filePathForSk = filePath + '/Forgery/Skilled' 
filePathForOh = filePath + '/Forgery/Opposite Hand' 
filePathForSi = filePath + '/Forgery/Simple' 

if "Simple" in os.listdir(filePathFor):
  if "1" in os.listdir(filePathGen):
      for i in os.listdir(filePathGen):
          author = i
          for j in os.listdir(filePathGen + '/' + author):
              os.rename(filePathGen + '/' + author + "/" + j, filePathGen + "/" + "g_" + author + "_" + j)
          os.removedirs(filePathGen + "/" + author)

  if "Skilled" in os.listdir(filePathFor):
      for i in os.listdir(filePathForSk):
          author = i
          for j in os.listdir(filePathForSk + '/' + author):
              os.rename(filePathForSk + '/' + author + "/" + j, filePathFor + "/" + "fSk_" + author + "_" + j)
          os.removedirs(filePathForSk + "/" + author)

  if "Opposite Hand" in os.listdir(filePathFor):
      for i in os.listdir(filePathForOh):
          author = i
          for j in os.listdir(filePathForOh + '/' + author):
              os.rename(filePathForOh + '/' + author + "/" + j, filePathFor + "/" + "fOh_" + author + "_" + j)
          os.removedirs(filePathForOh + "/" + author)

  #if "Simple" in os.listdir(filePathFor):
   #   shutil.rmtree(filePathForSi)
      
  if "Simple" in os.listdir(filePathFor):
    for i in os.listdir(filePathForSi):
        author = i
        count = 1
        for j in os.listdir(filePathForSi + '/' + author):
            os.rename(filePathForSi + '/' + author + "/" + j, filePathFor + "/" + "fSi_" + author + "_" + str(count) + ".tif")
            count = count + 1
        os.removedirs(filePathForSi + "/" + author)

# %%
### Need code for altering .tif files into .png? or can we go ahead and just work with .tif? ###

# %%
# File paths of the image data used later in the project
### Need to discuss how we will seperate our data. 80% 20% rule? ###
gentr="/content/UTSig/Genuine"
forgtr="/content/UTSig/Forgery"

gent="/content/UTSig/Genuine"
forgt="/content/UTSig/Forgery"

# %%
# Code block for working with the image files (resizing, retreiving files, etc.)

# Standard height weight for images
img_width, img_height, channels = 224, 224, 3

dim = (img_width, img_height)

# Converts the images to rgb which is what VGG-16 takes as input
def to_rgb(img):
    img = cv2.resize(img, dim, interpolation = cv2.INTER_AREA) 
    img_rgb = np.asarray(np.dstack((img, img, img)), dtype=np.uint8)
    return img_rgb


# Takes in file path and image name and returns resized image
def returnimages(path,img):
    image=cv2.imread(path+"/"+ img)                  #bringing the image
    image=cv2.resize(image, (img_width, img_height))
    image=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image=to_rgb(image).reshape(1,img_width, img_height,3)/255.0       #resizing and normalizing    
    return image     

# Takes in number of author, path for genuine and forged signatures
# Returns one image name (m.pop()), and two arrays of file names n = forgary, m = genuine
# Used for generator()
def getfiles(num,gen,forg):
    genList=os.listdir(gen)
    forgList=os.listdir(forg)
    author=str(num)
    print(author)
           
    forgArr,genArr=[],[]
    for i in forgList:
        if ("_" + author + "_") in i:
            forgArr = forgArr + [i]
            
    for i in genList:
        if ("_" + author + "_") in i:
            genArr = genArr + [i]
     
    return genArr.pop(), forgArr, genArr
######################################

# Same as getfiles but returns two files
def getfilest(num,gen,forg):
    genList=os.listdir(gen)
    forgList=os.listdir(forg)
    author=str(num)
           
    forgArr,genArr=[],[]
    for i in forgList:
        if ("_" + author + "_") in i:
            forgArr = forgArr + [i]
            
    for i in genList:
        if ("_" + author + "_") in i:
            genArr = genArr + [i]

    return genArr.pop(), genArr.pop(), forgArr, genArr

# %%
# creating 3 fold cross-validations

#print(validation_set)
random.seed(30)

sigIndex = list(range(1,116))
random.shuffle(sigIndex)

folds = [sigIndex[0:30],sigIndex[30:60],sigIndex[60:90]]
test =sigIndex[90:116]
train1 = list(set(folds[0]+folds[1]))
train2 = list(set(folds[1]+folds[2]))
train3 = list(set(folds[0]+folds[2]))
train = [train1,train2,train3]
valid = [folds[2],folds[0], folds[1]]

# %%
# Function for defining loss variable in model, leave for now, look into altering?
### Unsure what y_pred is doing, or how this works....
def triplet_loss(y_true, y_pred):
    alpha = 0.5
    anchor, positive, negative =y_pred[0,0:512], y_pred[0,512:1024], y_pred[0,1024:1536]
    print(str(anchor), str(positive), str(negative))
    print(str(y_true), str(y_pred))
    
    positive_distance = K.mean(K.square(anchor - positive),axis=-1)
    negative_distance = K.mean(K.square(anchor - negative),axis=-1)
    return K.mean(K.maximum(0.0, positive_distance - negative_distance + alpha))

# %%
# Defining the architecture. chose to go with 16 as it is smaller...
#model = applications.vgg16.VGG16(weights='imagenet', include_top=False, pooling='max')

### Imput baseline model ### Unsure how this is done, commenting for now
baseModel = applications.vgg16.VGG16(weights=None, include_top=False, pooling='max')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# For layers from 1 to 15 freeze the weights

### We will need to do a test for each layer to find the optimal transfer* ###
### For now just copying over the code from example
#for layer in model.layers[:5]:
#    layer.trainable = False
baseModel.trainable = True

# %%
# all "in" variables are defining the input "shape" for the model
# Input is a function in Keras
# Positive represents genuine / Negative represents Forgary 
anchor_in = Input(shape=(img_width, img_height, channels))
pos_in = Input(shape=(img_width, img_height, channels))
neg_in = Input(shape=(img_width, img_height, channels))

# Defining output of model
anchor_out = baseModel(anchor_in)
pos_out = baseModel(pos_in)
neg_out = baseModel(neg_in)
merged_vector = concatenate([anchor_out, pos_out, neg_out],axis=1)

# %%
# Setting inputs and outputs of the model
# Model function - potentially overwrites the input and output layers
### Unsure what the output is... Need to research ###
# Input is 3 images: image in question (anchor), postitive image, negative image (same authors)

#model = Model(inputs=[anchor_in, pos_in, neg_in], outputs=merged_vector)
baseModel = Model(inputs=[anchor_in, pos_in, neg_in], outputs=merged_vector)

# %%
# Compiling the model
# loss function set to function defined earlier
# Optimizer is for learning rate of the function
### unsure what Adam function does

#model.compile(optimizer=Adam(lr=0.000005),loss=triplet_loss)
baseModel.compile(optimizer=Adam(lr=0.00001),loss=triplet_loss) #,metrics=['accuracy'])
# Out:
# Tensor("loss/concatenate_1_loss/strided_slice:0", shape=(512,), dtype=float32) Tensor("loss/concatenate_1_loss/strided_slice_1:0", shape=(512,), dtype=float32) Tensor("loss/concatenate_1_loss/strided_slice_2:0", shape=(512,), dtype=float32)
# Tensor("concatenate_1_target:0", shape=(?, ?), dtype=float32) Tensor("concatenate_1/concat:0", shape=(?, 1536), dtype=float32)

# %%
baseModel.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# vgg16 (Model)                   (None, 512)          14714688    input_2[0][0]
#                                                                  input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 1536)         0           vgg16[1][0]
#                                                                  vgg16[2][0]
#                                                                  vgg16[3][0]
# ==================================================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#len(baseModel.trainable_variables)
path = "/content/drive/Team Drives/results/" + username + "/" + date + "/"
os.mkdir(path)
baseModel.save_weights(path + 'initial_weights.h5')

# %%
# Generator - Goes through every author (in test) and returns an anchor (last image) and an array of file names (negative=forged) (positive=genuine) 
def generator(x):
  #  for i in range(1,96):
    print("Training " + str(x))
    for i in x:
      # Returns last genuine image, array of pos/genuine files, array of neg/forgary files
        anc,neg,pos=getfiles(i,gentr,forgtr)
        
#When we have the list of images/arrays for that author, we then loop through for the length of the negative list (total number of forged)
  #For each negative image, we are going to loop through the length of the positive list
    #For each positive image we resize the anchor, first
    
        for i in range(len(neg)):           
            for j in range(len(pos)):        
                anchor=returnimages(gentr,anc)
                positive=returnimages(gentr,pos[j])
                negative=returnimages(forgtr,neg[i])
               # yield ([anc,pos[j],neg[i]],[0])
                yield ([anchor,positive,negative],[0])

# %%
# Generator - Goes through every author (in test) and returns an anchor (last image) and an array of file names (negative=forged) (positive=genuine) 
def generator_validator(x):
    print("Validation " + str(x))
    for i in x:
      # Returns last genuine image, array of pos/genuine files, array of neg/forgary files
        anc,neg,pos=getfiles(i,gentr,forgtr)
        
#When we have the list of images/arrays for that author, we then loop through for the length of the negative list (total number of forged)
  #For each negative image, we are going to loop through the length of the positive list
    #For each positive image we resize the anchor, first
    
        for i in range(len(neg)):           
            for j in range(len(pos)):        
                anchor=returnimages(gentr,anc)
                positive=returnimages(gentr,pos[j])
                negative=returnimages(forgtr,neg[i])
               # yield ([anc,pos[j],neg[i]],[0])
                yield ([anchor,positive,negative],[0])

# %%
### These values were taken from example, need to decide on what they should be
#print("Starting our model:")
#for x in range(2):
   # print("Iteration: " + str(x))
   #model.fit_generator(generator(),steps_per_epoch=200,epochs=3)
    
logs = ["training1.log", "training2.log", "training3.log"]
weights = ["model_weights_1.h5", "model_weights_2.h5", "model_weights_3.h5"]

print("Starting the base model:")
#for i in range(3):
i = 0
print("Iteration: " + str(i))
#initial_weights = path + "initial_weights.h5"
  #baseModel.load_weights(initial_weights)
  #baseModel.trainable = True
weight = path + weights[i]
log = path + logs[i]
csv = keras.callbacks.CSVLogger(log)
es = keras.callbacks.EarlyStopping(monitor='val_loss', patience=50, verbose=1, mode='auto', baseline=.48, restore_best_weights=True)
  #es_list = [es, csv]
cb_list = [es, csv]
#history = baseModel.fit_generator(generator(),steps_per_epoch=200,epochs=10,callbacks= es_list,validation_data=generator_validator(),validation_steps=5)
history = baseModel.fit_generator(generator(train[i]),steps_per_epoch=200,epochs=90,callbacks = cb_list, validation_data=generator_validator(valid[i]),validation_steps=100)
baseModel.save_weights(weight)
# Out:
# Starting the base model:
# Iteration: 0
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Epoch 1/90
# Training [3, 5, 6, 12, 14, 16, 19, 20, 22, 23, 24, 25, 26, 28, 29, 30, 31, 34, 35, 37, 39, 42, 43, 44, 46, 47, 48, 53, 54, 56, 57, 58, 59, 61, 62, 63, 66, 74, 75, 76, 78, 85, 86, 87, 88, 89, 91, 92, 93, 94, 97, 98, 99, 103, 105, 107, 110, 113, 114, 115]Validation [2, 50, 8, 41, 102, 101, 100, 65, 108, 71, 112, 17, 40, 64, 15, 72, 81, 13, 82, 55, 36, 73, 96, 95, 90, 9, 69, 45, 109, 52]
#
# 2
# 3
# 200/200 [==============================] - 29s 143ms/step - loss: 0.5000 - val_loss: 0.5000
# Epoch 2/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.3803 - val_loss: 0.6478
# Epoch 3/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0099 - val_loss: 0.8941
# Epoch 4/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0176 - val_loss: 0.6729
# Epoch 5/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0000e+00 - val_loss: 0.7593
# Epoch 6/90
# 159/200 [======================>.......] - ETA: 4s - loss: 0.0000e+005
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0200 - val_loss: 0.8010
# Epoch 7/90
# 200/200 [==============================] - 23s 113ms/step - loss: 0.0842 - val_loss: 0.5831
# Epoch 8/90
# 200/200 [==============================] - 23s 113ms/step - loss: 0.0427 - val_loss: 0.1157
# Epoch 9/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0711 - val_loss: 0.2973
# Epoch 10/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0189 - val_loss: 0.4156
# Epoch 11/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0628 - val_loss: 0.4440
# Epoch 12/90
# 129/200 [==================>...........] - ETA: 7s - loss: 0.22426
# 199/200 [============================>.] - ETA: 0s - loss: 0.205150
# 200/200 [==============================] - 23s 113ms/step - loss: 0.2040 - val_loss: 0.6856
# Epoch 13/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0505 - val_loss: 1.2630
# Epoch 14/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0208 - val_loss: 1.1960
# Epoch 15/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0093 - val_loss: 1.4959
# Epoch 16/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0000e+00 - val_loss: 2.1876
# Epoch 17/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0430 - val_loss: 1.0217
# Epoch 18/90
#  99/200 [=============>................] - ETA: 9s - loss: 0.013912
# 200/200 [==============================] - 23s 113ms/step - loss: 0.1971 - val_loss: 0.3282
# Epoch 19/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.1301 - val_loss: 3.2920
# Epoch 20/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0718 - val_loss: 1.7008
# Epoch 21/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0153 - val_loss: 5.6879
# Epoch 22/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0729 - val_loss: 0.6032
# Epoch 23/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0932 - val_loss: 0.5667
# Epoch 24/90
#  69/200 [=========>....................] - ETA: 12s - loss: 0.086714
# 199/200 [============================>.] - ETA: 0s - loss: 0.07488
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0744 - val_loss: 0.3655
# Epoch 25/90
# 200/200 [==============================] - 23s 113ms/step - loss: 0.1405 - val_loss: 0.2442
# Epoch 26/90
# 200/200 [==============================] - 23s 113ms/step - loss: 0.1349 - val_loss: 0.3737
# Epoch 27/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0336 - val_loss: 0.2971
# Epoch 28/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0306 - val_loss: 0.5461
# Epoch 29/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0182 - val_loss: 1.1449
# Epoch 30/90
#  39/200 [====>.........................] - ETA: 15s - loss: 0.003216
# 200/200 [==============================] - 23s 113ms/step - loss: 0.3791 - val_loss: 0.4458
# Epoch 31/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0750 - val_loss: 0.7281
# Epoch 32/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0078 - val_loss: 0.7429
# Epoch 33/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0230 - val_loss: 0.3835
# Epoch 34/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0000e+00 - val_loss: 0.5723
# Epoch 35/90
# 199/200 [============================>.] - ETA: 0s - loss: 2.6928e-0441
# 200/200 [==============================] - 22s 112ms/step - loss: 2.6794e-04 - val_loss: 0.6487
# Epoch 36/90
#   9/200 [>.............................] - ETA: 18s - loss: 0.0000e+0019
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0384 - val_loss: 0.3055
# Epoch 37/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0650 - val_loss: 0.3228
# Epoch 38/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0094 - val_loss: 0.1908
# Epoch 39/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0056 - val_loss: 0.0871
# Epoch 40/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0000e+00 - val_loss: 0.5161
# Epoch 41/90
# 179/200 [=========================>....] - ETA: 2s - loss: 0.007620
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0289 - val_loss: 0.0357
# Epoch 42/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0766 - val_loss: 0.3856
# Epoch 43/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0568 - val_loss: 0.2821
# Epoch 44/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0353 - val_loss: 0.6699
# Epoch 45/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0159 - val_loss: 0.5838
# Epoch 46/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0091 - val_loss: 0.5793
# Epoch 47/90
# 149/200 [=====================>........] - ETA: 5s - loss: 0.017722
# 199/200 [============================>.] - ETA: 0s - loss: 0.0880102
# 200/200 [==============================] - 23s 113ms/step - loss: 0.0876 - val_loss: 0.4561
# Epoch 48/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.1057 - val_loss: 0.5161
# Epoch 49/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0047 - val_loss: 0.1372
# Epoch 50/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0112 - val_loss: 0.3534
# Epoch 51/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0021 - val_loss: 0.2479
# Epoch 52/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0139 - val_loss: 1.6515
# Epoch 53/90
# 119/200 [================>.............] - ETA: 7s - loss: 0.035823
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0380 - val_loss: 1.1271
# Epoch 54/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0180 - val_loss: 0.7525
# Epoch 55/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0275 - val_loss: 0.3985
# Epoch 56/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0664 - val_loss: 0.9288
# Epoch 57/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0291 - val_loss: 0.5822
# Epoch 58/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0372 - val_loss: 0.7226
# Epoch 59/90
#  89/200 [============>.................] - ETA: 10s - loss: 0.271624
# 199/200 [============================>.] - ETA: 0s - loss: 0.1849101
# 200/200 [==============================] - 22s 112ms/step - loss: 0.1840 - val_loss: 0.3943
# Epoch 60/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0755 - val_loss: 2.0573
# Epoch 61/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0283 - val_loss: 3.1725
# Epoch 62/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0178 - val_loss: 1.1344
# Epoch 63/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0312 - val_loss: 1.0945
# Epoch 64/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0062 - val_loss: 1.2386
# Epoch 65/90
#  59/200 [=======>......................] - ETA: 13s - loss: 0.023625
# 200/200 [==============================] - 22s 112ms/step - loss: 0.1312 - val_loss: 1.3936
# Epoch 66/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0393 - val_loss: 1.7935
# Epoch 67/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0327 - val_loss: 2.0158
# Epoch 68/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0058 - val_loss: 1.7276
# Epoch 69/90
# 200/200 [==============================] - 22s 111ms/step - loss: 0.0403 - val_loss: 3.1074
# Epoch 70/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0091 - val_loss: 0.6949
# Epoch 71/90
#  29/200 [===>..........................] - ETA: 16s - loss: 0.0000e+0026
# 199/200 [============================>.] - ETA: 0s - loss: 0.1401100
# 200/200 [==============================] - 22s 112ms/step - loss: 0.1394 - val_loss: 1.1239
# Epoch 72/90
# 200/200 [==============================] - 22s 112ms/step - loss: 0.0375 - val_loss: 0.1610
# Epoch 73/90
# 199/200 [============================>.] - ETA: 0s - loss: 0.0000e+00

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.ylim([0,max(plt.ylim())])
plt.title('Training and Validation Loss')
plt.show()

# %%
#history = baseModel.fit_generator(generator(),steps_per_epoch=200,epochs=110)

# %%
#history = baseModel.fit_generator(generator(),steps_per_epoch=200,epochs=110)

# %%
### Unsure purpose of this part ###

# used for validation

tneg,tpos = 0, 0
# Uses values not used in generator 2 to validate
x= range(93,116)
print(test)

for k in test: #the id of signatures you want to check
    #print("When k is ", k)
    anc,neg,pos=getfiles(k,gent,forgt)
    tneg=tneg+len(neg)
    tpos=tpos+len(pos)
print("Forgary Image Total: " + str(tneg),"Genuine Image Total: " + str(tpos))
# Out:
# [68, 77, 21, 10, 111, 32, 67, 1, 60, 11, 18, 83, 49, 51, 7, 33, 27, 106, 84, 80, 4, 79, 38, 104, 70]
# 68
# 77
# 21
# 10
# 111
# 32
# 67
# 1
# 60
# 11
# 18
# 83
# 49
# 51
# 7
# 33
# 27
# 106
# 84
# 80
# 4
# 79
# 38
# 104
# 70
# Forgary Image Total: 1125 Genuine Image Total: 650

# %%
#os.listdir('/content')

# %%
### Code for base model - duplicated with variables changed ###
#for i in range(3):
i = 0
print("Iteration: " + str(i))
#weight = path + weights[i]
#baseModel.load_weights(weight)
  
forg_passed=0
gen_flagged=0

for k in test: #the id of signatures you want to check
    print("When k is ", k)
    anc,neg,pos=getfiles(k,gent,forgt)
    
    anchor=returnimages(gent,anc)
    for i in range(len(pos)): #pos
        positive=returnimages(gent,pos[i])
        x=baseModel.predict([anchor,positive,anchor])
        a, p, useless = x[0,0:512], x[0,512:1024], x[0,1024:1536]
        #dist=sum(a-p)
        dist=np.linalg.norm(a-p)
        #print("positive distance is ",dist)
        if(dist>32):
        #  print("0")
            gen_flagged=gen_flagged+1
            print("gen flagged - ",dist, "file name is - ", pos[i])
            
        else:
            gen_flagged=gen_flagged
        #   print("1")
        
    for j in range(len(neg)): #neg
        negative=returnimages(forgt,neg[j])
        x=baseModel.predict([anchor,negative,anchor])
        a, n, useless = x[0,0:512], x[0,512:1024], x[0,1024:1536]
        #dist=sum(a-n)
        dist=np.linalg.norm(a-n)
        #print("negative distance is ",dist)
        if(dist>32):
            forg_passed=forg_passed
          #  print("0")
        else:
            forg_passed=forg_passed+1
            print("forg passed - ",dist, "file name is - ", neg[j])
          #  print("1")

print("base_forg_passed is ",forg_passed)
print("base_gen_flagged is ",gen_flagged)
print("False Acceptance Rate (FAR) = ", str(100*forg_passed/tneg), "%")
print("False Rejection Rate (FRR) = ", str(100*gen_flagged/tpos), "%")
# Out:
# Iteration: 0
# When k is  68
# 68
# gen flagged -  32.31163 file name is -  g_68_23.tif
# forg passed -  9.882348 file name is -  fSi_68_26.tif
# forg passed -  10.962776 file name is -  fSi_68_19.tif
# forg passed -  9.853819 file name is -  fSi_68_27.tif
# forg passed -  15.033149 file name is -  fSi_68_34.tif
# forg passed -  15.770829 file name is -  fSi_68_22.tif
# forg passed -  10.715668 file name is -  fSi_68_11.tif
# forg passed -  21.72974 file name is -  fSi_68_36.tif
# forg passed -  15.49114 file name is -  fSi_68_31.tif
# forg passed -  27.816442 file name is -  fSk_68_6.tif
# forg passed -  20.746487 file name is -  fSi_68_14.tif
# forg passed -  24.530409 file name is -  fSi_68_30.tif
# forg passed -  19.362957 file name is -  fSi_68_8.tif
# forg passed -  10.117555 file name is -  fSi_68_20.tif
# forg passed -  16.036453 file name is -  fSi_68_25.tif
# forg passed -  17.41669 file name is -  fOh_68_2.tif
# forg passed -  7.1819096 file name is -  fSi_68_17.tif
# forg passed -  15.086301 file name is -  fSi_68_4.tif
# forg passed -  26.6488 file name is -  fSi_68_24.tif
# forg passed -  29.130352 file name is -  fSk_68_2.tif
# forg passed -  13.598419 file name is -  fSi_68_1.tif
# forg passed -  11.160358 file name is -  fSi_68_29.tif
# forg passed -  17.675516 file name is -  fSi_68_15.tif
# forg passed -  13.660792 file name is -  fSi_68_5.tif
# forg passed -  8.75564 file name is -  fSi_68_18.tif
# forg passed -  22.506985 file name is -  fSi_68_10.tif
# forg passed -  14.496859 file name is -  fSi_68_33.tif
# forg passed -  16.505993 file name is -  fSi_68_16.tif
# forg passed -  17.263876 file name is -  fSk_68_1.tif
# forg passed -  7.4505525 file name is -  fSi_68_23.tif
# forg passed -  20.655355 file name is -  fOh_68_1.tif
# forg passed -  19.174057 file name is -  fSi_68_35.tif
# forg passed -  14.307623 file name is -  fSi_68_21.tif
# forg passed -  15.288048 file name is -  fSi_68_28.tif
# forg passed -  19.451118 file name is -  fSi_68_3.tif
# forg passed -  20.595335 file name is -  fSi_68_9.tif
# forg passed -  26.858389 file name is -  fSk_68_3.tif
# forg passed -  22.469484 file name is -  fSi_68_6.tif
# forg passed -  21.557903 file name is -  fSi_68_12.tif
# forg passed -  22.258413 file name is -  fSi_68_13.tif
# forg passed -  21.190792 file name is -  fSk_68_5.tif
# forg passed -  19.796389 file name is -  fSi_68_7.tif
# When k is  77
# 77
# forg passed -  30.740973 file name is -  fSi_77_34.tif
# forg passed -  18.745302 file name is -  fSi_77_2.tif
# forg passed -  24.885103 file name is -  fSi_77_31.tif
# forg passed -  24.58095 file name is -  fSi_77_4.tif
# forg passed -  21.43412 file name is -  fSi_21_1.tif
# forg passed -  20.75357 file name is -  fSi_21_13.tif
# forg passed -  17.745134 file name is -  fSi_21_34.tif
# forg passed -  16.03564 file name is -  fSi_21_2.tif
# forg passed -  15.338788 file name is -  fSi_21_24.tif
# forg passed -  18.019173 file name is -  fSk_21_4.tif
# forg passed -  19.973818 file name is -  fOh_21_3.tif
# forg passed -  9.911075 file name is -  fSi_21_31.tif
# forg passed -  14.906793 file name is -  fSi_21_10.tif
# forg passed -  17.10958 file name is -  fSi_21_21.tif
# forg passed -  13.129797 file name is -  fSi_21_25.tif
# forg passed -  24.343609 file name is -  fSk_21_5.tif
# forg passed -  8.671298 file name is -  fSi_21_35.tif
# forg passed -  5.463929 file name is -  fSi_21_19.tif
# When k is  10
# 10
# gen flagged -  34.855827 file name is -  g_10_8.tif
# gen flagged -  33.175793 file name is -  g_10_15.tif
# gen flagged -  35.16207 file name is -  g_10_9.tif
# gen flagged -  45.681736 file name is -  g_10_1.tif
# gen flagged -  38.668095 file name is -  g_10_27.tif
# gen flagged -  35.973175 file name is -  g_10_25.tif
# forg passed -  30.873625 file name is -  fSi_10_29.tif
# forg passed -  27.140194 file name is -  fSi_10_10.tif
# forg passed -  26.768528 file name is -  fSi_10_21.tif
# forg passed -  25.538702 file name is -  fSi_10_30.tif
# forg passed -  30.397163 file name is -  fSi_10_31.tif
# forg passed -  28.039703 file name is -  fSi_10_23.tif
# forg passed -  27.914785 file name is -  fSi_10_11.tif
# When k is  111
# 111
# gen flagged -  39.15084 file name is -  g_111_7.tif
# gen flagged -  38.151276 file name is -  g_111_1.tif
# gen flagged -  35.0868 file name is -  g_111_10.tif
# gen flagged -  44.809803 file name is -  g_111_4.tif
# gen flagged -  39.299088 file name is -  g_111_6.tif
# gen flagged -  38.48186 file name is -  g_111_5.tif
# gen flagged -  32.995655 file name is -  g_111_26.tif
# gen flagged -  34.49326 file name is -  g_111_24.tif
# forg passed -  23.04727 file name is -  fSi_111_7.tif
# forg passed -  31.069057 file name is -  fSk_111_3.tif
# forg passed -  31.548903 file name is -  fSi_111_13.tif
# forg passed -  20.690989 file name is -  fSi_111_8.tif
# forg passed -  21.310867 file name is -  fSk_111_4.tif
# forg passed -  25.578238 file name is -  fSi_111_3.tif
# forg passed -  25.840666 file name is -  fSi_111_4.tif
# forg passed -  31.092701 file name is -  fSk_111_5.tif
# forg passed -  23.709751 file name is -  fSi_111_14.tif
# forg passed -  29.788628 file name is -  fSk_111_1.tif
# When k is  32
# 32
# gen flagged -  39.43257 file name is -  g_32_19.tif
# gen flagged -  33.992085 file name is -  g_32_15.tif
# forg passed -  21.143661 file name is -  fSi_32_21.tif
# forg passed -  30.09515 file name is -  fSi_32_22.tif
# forg passed -  18.393225 file name is -  fSk_32_3.tif
# forg passed -  29.452358 file name is -  fSi_32_16.tif
# forg passed -  25.507845 file name is -  fSk_32_6.tif
# forg passed -  11.492319 file name is -  fSi_32_10.tif
# forg passed -  29.784615 file name is -  fSi_32_30.tif
# forg passed -  28.872953 file name is -  fSi_32_1.tif
# forg passed -  11.179914 file name is -  fSi_32_24.tif
# forg passed -  22.481716 file name is -  fSi_32_27.tif
# forg passed -  21.088305 file name is -  fSi_32_26.tif
# forg passed -  30.992783 file name is -  fSi_32_19.tif
# forg passed -  22.665873 file name is -  fSk_32_2.tif
# forg passed -  26.476372 file name is -  fSk_32_4.tif
# forg passed -  28.896051 file name is -  fSi_32_29.tif
# When k is  67
# 67
# gen flagged -  35.11363 file name is -  g_67_10.tif
# forg passed -  23.360353 file name is -  fSi_67_5.tif
# forg passed -  17.278345 file name is -  fSi_67_18.tif
# forg passed -  28.664055 file name is -  fSk_67_2.tif
# forg passed -  17.34165 file name is -  fSi_67_13.tif
# forg passed -  13.594473 file name is -  fSi_67_14.tif
# forg passed -  14.619991 file name is -  fSi_67_8.tif
# forg passed -  8.476341 file name is -  fSi_67_31.tif
# forg passed -  30.495758 file name is -  fSi_67_22.tif
# forg passed -  25.537703 file name is -  fOh_67_3.tif
# forg passed -  14.56199 file name is -  fSi_67_17.tif
# forg passed -  16.235868 file name is -  fSk_67_5.tif
# forg passed -  27.061926 file name is -  fSi_67_26.tif
# forg passed -  17.527145 file name is -  fSi_67_9.tif
# forg passed -  12.957457 file name is -  fSi_67_3.tif
# forg passed -  29.01751 file name is -  fSi_67_30.tif
# forg passed -  12.613808 file name is -  fSk_67_6.tif
# forg passed -  28.38572 file name is -  fSi_67_32.tif
# forg passed -  18.326044 file name is -  fSi_67_16.tif
# forg passed -  10.473681 file name is -  fOh_67_2.tif
# forg passed -  15.688607 file name is -  fSk_67_1.tif
# forg passed -  16.659594 file name is -  fSi_67_2.tif
# forg passed -  22.399002 file name is -  fSi_67_35.tif
# forg passed -  29.519087 file name is -  fSi_67_36.tif
# forg passed -  30.134014 file name is -  fSi_67_24.tif
# forg passed -  18.606411 file name is -  fSi_67_1.tif
# forg passed -  22.718699 file name is -  fSi_67_21.tif
# forg passed -  21.052803 file name is -  fSi_67_4.tif
# forg passed -  9.745244 file name is -  fSi_67_7.tif
# forg passed -  17.76434 file name is -  fSi_67_10.tif
# forg passed -  18.027195 file name is -  fSi_67_34.tif
# forg passed -  16.271013 file name is -  fSi_67_11.tif
# forg passed -  24.657213 file name is -  fSi_67_25.tif
# forg passed -  12.353541 file name is -  fSk_67_4.tif
# forg passed -  16.866732 file name is -  fSk_67_3.tif
# forg passed -  26.949415 file name is -  fSi_67_23.tif
# forg passed -  19.996132 file name is -  fSi_67_33.tif
# forg passed -  22.704695 file name is -  fSi_67_29.tif
# forg passed -  31.753487 file name is -  fSi_67_20.tif
# forg passed -  13.090204 file name is -  fSi_67_19.tif
# forg passed -  19.777555 file name is -  fOh_67_1.tif
# forg passed -  21.522053 file name is -  fSi_67_28.tif
# When k is  1
# 1
# forg passed -  27.431065 file name is -  fSi_1_4.tif
# forg passed -  22.05385 file name is -  fSi_1_13.tif
# forg passed -  17.44523 file name is -  fSk_1_4.tif
# forg passed -  13.259413 file name is -  fSi_1_3.tif
# forg passed -  19.574965 file name is -  fOh_1_2.tif
# forg passed -  25.90593 file name is -  fSi_1_14.tif
# forg passed -  16.25032 file name is -  fSi_1_27.tif
# forg passed -  8.453339 file name is -  fSi_1_10.tif
# forg passed -  23.995602 file name is -  fSi_1_8.tif
# forg passed -  16.528238 file name is -  fSi_1_17.tif
# forg passed -  31.60821 file name is -  fSi_1_22.tif
# forg passed -  6.528867 file name is -  fSi_1_11.tif
# forg passed -  14.1326065 file name is -  fSi_1_19.tif
# forg passed -  18.627079 file name is -  fSk_1_3.tif
# forg passed -  14.279197 file name is -  fSi_1_20.tif
# forg passed -  18.043116 file name is -  fSi_1_5.tif
# forg passed -  13.168089 file name is -  fSi_1_33.tif
# forg passed -  14.735464 file name is -  fOh_1_1.tif
# forg passed -  28.573492 file name is -  fSi_1_31.tif
# forg passed -  14.290726 file name is -  fSi_1_34.tif
# forg passed -  23.091286 file name is -  fSi_1_2.tif
# forg passed -  22.190147 file name is -  fSk_1_5.tif
# forg passed -  26.804567 file name is -  fOh_1_3.tif
# forg passed -  13.113346 file name is -  fSi_1_28.tif
# forg passed -  12.564287 file name is -  fSi_1_29.tif
# forg passed -  14.0324745 file name is -  fSi_1_21.tif
# forg passed -  9.179885 file name is -  fSi_1_18.tif
# forg passed -  13.074359 file name is -  fSi_1_9.tif
# forg passed -  12.590504 file name is -  fSk_1_1.tif
# forg passed -  26.005627 file name is -  fSi_1_7.tif
# forg passed -  10.190052 file name is -  fSi_1_1.tif
# forg passed -  13.502974 file name is -  fSi_1_30.tif
# forg passed -  16.070496 file name is -  fSk_1_2.tif
# forg passed -  16.83597 file name is -  fSi_1_16.tif
# forg passed -  11.130263 file name is -  fSi_1_25.tif
# forg passed -  8.512776 file name is -  fSi_1_26.tif
# forg passed -  29.330973 file name is -  fSi_1_23.tif
# forg passed -  10.810448 file name is -  fSi_1_24.tif
# forg passed -  15.43801 file name is -  fSk_1_6.tif
# When k is  60
# 60
# gen flagged -  36.203022 file name is -  g_60_27.tif
# gen flagged -  40.873463 file name is -  g_60_13.tif
# gen flagged -  34.64333 file name is -  g_60_2.tif
# gen flagged -  32.297966 file name is -  g_60_8.tif
# forg passed -  28.967682 file name is -  fSi_60_33.tif
# forg passed -  25.145206 file name is -  fSi_60_19.tif
# forg passed -  26.205523 file name is -  fSi_60_8.tif
# forg passed -  29.790985 file name is -  fSi_60_9.tif
# forg passed -  19.826115 file name is -  fSi_60_35.tif
# forg passed -  20.423672 file name is -  fSk_60_4.tif
# forg passed -  31.758867 file name is -  fSi_60_34.tif
# forg passed -  31.622803 file name is -  fSk_60_5.tif
# forg passed -  21.781599 file name is -  fSi_60_17.tif
# forg passed -  22.632177 file name is -  fSk_60_2.tif
# forg passed -  22.289188 file name is -  fSk_60_6.tif
# forg passed -  17.266027 file name is -  fSi_60_6.tif
# forg passed -  18.708294 file name is -  fSi_60_21.tif
# forg passed -  17.348368 file name is -  fSi_60_30.tif
# forg passed -  29.825356 file name is -  fSi_60_11.tif
# forg passed -  22.57372 file name is -  fSi_60_23.tif
# forg passed -  28.079 file name is -  fSi_60_10.tif
# forg passed -  25.748592 file name is -  fSi_60_15.tif
# forg passed -  21.521366 file name is -  fSi_60_20.tif
# forg passed -  29.657772 file name is -  fSi_60_24.tif
# forg passed -  23.147253 file name is -  fSi_60_26.tif
# forg passed -  25.18311 file name is -  fSi_60_7.tif
# forg passed -  27.485958 file name is -  fSk_60_1.tif
# forg passed -  27.278315 file name is -  fSi_60_12.tif
# forg passed -  13.594895 file name is -  fSi_60_25.tif
# forg passed -  28.307947 file name is -  fSi_60_27.tif
# forg passed -  30.374557 file name is -  fSk_60_3.tif
# forg passed -  25.61412 file name is -  fSi_60_29.tif
# forg passed -  29.335129 file name is -  fSi_60_28.tif
# When k is  11
# 11
# forg passed -  9.858585 file name is -  fSk_11_3.tif
# forg passed -  27.602983 file name is -  fSi_11_30.tif
# forg passed -  18.978905 file name is -  fSi_11_16.tif
# forg passed -  9.12442 file name is -  fSk_11_6.tif
# forg passed -  13.708148 file name is -  fSi_11_22.tif
# forg passed -  6.571704 file name is -  fSi_11_17.tif
# forg passed -  12.41004 file name is -  fSi_11_23.tif
# forg passed -  23.240576 file name is -  fSi_11_1.tif
# forg passed -  7.1018476 file name is -  fSi_11_29.tif
# forg passed -  20.292397 file name is -  fSi_11_5.tif
# forg passed -  15.953043 file name is -  fSi_11_4.tif
# forg passed -  29.780607 file name is -  fSi_11_24.tif
# forg passed -  23.869543 file name is -  fSi_11_13.tif
# forg passed -  23.17323 file name is -  fSi_11_27.tif
# forg passed -  11.983031 file name is -  fSi_11_18.tif
# forg passed -  14.351121 file name is -  fSi_11_32.tif
# forg passed -  11.388544 file name is -  fSi_11_36.tif
# forg passed -  27.842339 file name is -  fSi_11_35.tif
# forg passed -  9.86999 file name is -  fSi_11_20.tif
# forg passed -  17.97944 file name is -  fOh_11_2.tif
# forg passed -  9.400784 file name is -  fSk_11_4.tif
# forg passed -  16.077612 file name is -  fSi_11_8.tif
# forg passed -  12.660257 file name is -  fSi_11_33.tif
# forg passed -  18.62093 file name is -  fSi_11_9.tif
# forg passed -  11.8843775 file name is -  fSi_11_12.tif
# forg passed -  19.239033 file name is -  fSi_11_15.tif
# forg passed -  15.148664 file name is -  fSi_11_14.tif
# forg passed -  31.42351 file name is -  fSi_11_7.tif
# forg passed -  8.296121 file name is -  fSi_11_25.tif
# forg passed -  14.943113 file name is -  fSi_11_34.tif
# forg passed -  11.307413 file name is -  fSk_11_5.tif
# forg passed -  26.498611 file name is -  fOh_11_1.tif
# forg passed -  13.547225 file name is -  fSi_11_26.tif
# forg passed -  28.726921 file name is -  fSi_11_10.tif
# forg passed -  8.7586975 file name is -  fSi_11_31.tif
# forg passed -  8.268524 file name is -  fSi_11_11.tif
# forg passed -  10.543434 file name is -  fSk_11_2.tif
# forg passed -  14.717198 file name is -  fSi_11_3.tif
# forg passed -  12.2008915 file name is -  fSi_11_28.tif
# forg passed -  22.476252 file name is -  fOh_11_3.tif
# forg passed -  9.426965 file name is -  fSi_11_6.tif
# forg passed -  21.18065 file name is -  fSi_49_12.tif
# forg passed -  17.437004 file name is -  fSi_49_22.tif
# forg passed -  20.557774 file name is -  fSi_49_24.tif
# forg passed -  15.098472 file name is -  fSi_49_3.tif
# forg passed -  17.390951 file name is -  fSi_49_9.tif
# forg passed -  20.663725 file name is -  fSi_49_30.tif
# forg passed -  21.017164 file name is -  fSi_49_25.tif
# forg passed -  10.468632 file name is -  fSk_49_5.tif
# forg passed -  21.411943 file name is -  fOh_49_3.tif
# forg passed -  12.252852 file name is -  fSk_49_2.tif
# When k is  51
# 51
# gen flagged -  35.008343 file name is -  g_51_9.tif
# gen flagged -  39.14605 file name is -  g_51_6.tif
# gen flagged -  40.165367 file name is -  g_51_3.tif
# forg passed -  26.289812 file name is -  fOh_51_2.tif
# forg passed -  26.742405 file name is -  fSi_51_8.tif
# forg passed -  19.339695 file name is -  fSk_51_4.tif
# forg passed -  16.413828 file name is -  fSi_51_28.tif
# forg passed -  21.735752 file name is -  fSi_51_23.tif
# forg passed -  21.323463 file name is -  fSk_51_6.tif
# forg passed -  14.717366 file name is -  fSk_51_3.tif
# forg passed -  14.868209 file name is -  fSi_51_3.tif
# forg passed -  14.194706 file name is -  fSi_51_29.tif
# forg passed -  16.62487 file name is -  fSk_51_1.tif
# forg passed -  17.429083 file name is -  fSi_51_18.tif
# forg passed -  23.259783 file name is -  fSi_51_7.tif
# forg passed -  26.67698 file name is -  fSi_51_15.tif
# forg passed -  21.393581 file name is -  fOh_51_3.tif
# forg passed -  26.90636 file name is -  fOh_51_1.tif
# forg passed -  22.56957 file name is -  fSi_51_30.tif
# forg passed -  21.6515 file name is -  fSi_51_31.tif
# forg passed -  22.52221 file name is -  fSi_51_9.tif
# forg passed -  29.790575 file name is -  fSi_51_19.tif
# forg passed -  17.323452 file name is -  fSi_51_4.tif
# forg passed -  23.977535 file name is -  fSi_51_13.tif
# forg passed -  20.065533 file name is -  fSi_51_17.tif
# forg passed -  23.796925 file name is -  fSi_51_5.tif
# forg passed -  28.4319 file name is -  fSi_51_32.tif
# forg passed -  26.926945 file name is -  fSi_51_22.tif
# forg passed -  23.39547 file name is -  fSi_51_35.tif
# forg passed -  29.113974 file name is -  fSi_51_12.tif
# forg passed -  23.014032 file name is -  fSi_51_14.tif
# forg passed -  22.406525 file name is -  fSi_51_21.tif
# forg passed -  27.442297 file name is -  fSi_51_6.tif
# forg passed -  16.58723 file name is -  fSk_51_5.tif
# forg passed -  14.154948 file name is -  fSk_51_2.tif
# forg passed -  24.273731 file name is -  fSi_51_10.tif
# forg passed -  30.422493 file name is -  fSi_51_27.tif
# forg passed -  31.47766 file name is -  fSi_51_25.tif
# forg passed -  18.66884 file name is -  fSi_51_2.tif
# forg passed -  21.576498 file name is -  fSi_51_20.tif
# When k is  7
# 7
# gen flagged -  47.03886 file name is -  g_7_4.tif
# gen flagged -  34.94051 file name is -  g_7_25.tif
# gen flagged -  36.58608 file name is -  g_7_16.tif
# gen flagged -  41.57463 file name is -  g_7_13.tif
# forg passed -  29.539404 file name is -  fSk_84_6.tif
# forg passed -  18.819962 file name is -  fOh_84_1.tif
# forg passed -  24.427975 file name is -  fSk_84_2.tif
# forg passed -  24.323853 file name is -  fOh_84_3.tif
# When k is  80
# 80
# gen flagged -  32.43983 file name is -  g_80_19.tif
# gen flagged -  36.35165 file name is -  g_80_16.tif
# gen flagged -  42.221046 file name is -  g_80_27.tif
# gen flagged -  35.05881 file name is -  g_80_9.tif
# gen flagged -  35.257896 file name is -  g_80_13.tif
# gen flagged -  42.00312 file name is -  g_80_1.tif
# forg passed -  25.901728 file name is -  fSk_80_3.tif
# forg passed -  26.09691 file name is -  fSi_80_32.tif
# forg passed -  16.228773 file name is -  fOh_80_1.tif
# forg passed -  27.063417 file name is -  fSi_80_29.tif
# forg passed -  26.900455 file name is -  fSk_80_6.tif
# forg passed -  28.601402 file name is -  fSi_80_36.tif
# forg passed -  19.874306 file name is -  fSi_80_6.tif
# forg passed -  22.375383 file name is -  fSi_80_25.tif
# forg passed -  28.000504 file name is -  fSi_80_8.tif
# forg passed -  23.050062 file name is -  fOh_80_2.tif
# forg passed -  20.07987 file name is -  fSk_80_1.tif
# forg passed -  18.774693 file name is -  fSi_80_23.tif
# forg passed -  27.23263 file name is -  fSi_80_12.tif
# forg passed -  20.072107 file name is -  fSk_80_2.tif
# forg passed -  22.578222 file name is -  fSi_80_15.tif
# forg passed -  26.748755 file name is -  fSi_80_16.tif
# forg passed -  19.388264 file name is -  fSk_80_4.tif
# forg passed -  29.20428 file name is -  fSi_80_1.tif
# forg passed -  21.934229 file name is -  fSi_80_33.tif
# forg passed -  27.135994 file name is -  fSi_80_35.tif
# forg passed -  26.150364 file name is -  fSi_80_28.tif
# forg passed -  24.370121 file name is -  fSi_80_22.tif
# forg passed -  26.16591 file name is -  fSk_80_5.tif
# forg passed -  31.680597 file name is -  fSi_80_11.tif
# When k is  4
# 4
# forg passed -  24.87409 file name is -  fSi_4_2.tif
# forg passed -  30.039167 file name is -  fSi_4_21.tif
# forg passed -  26.638336 file name is -  fSk_4_4.tif
# forg passed -  12.22033 file name is -  fSi_4_35.tif
# forg passed -  23.858192 file name is -  fSk_4_1.tif
# forg passed -  17.010866 file name is -  fSi_4_14.tif
# forg passed -  28.954403 file name is -  fOh_4_3.tif
# forg passed -  13.825383 file name is -  fSi_4_11.tif
# forg passed -  26.210194 file name is -  fSi_4_7.tif
# forg passed -  26.123358 file name is -  fSi_4_17.tif
# forg passed -  26.927803 file name is -  fSi_4_10.tif
# forg passed -  26.56658 file name is -  fSi_4_18.tif
# forg passed -  23.049189 file name is -  fSi_4_5.tif
# forg passed -  15.081868 file name is -  fSi_4_26.tif
# forg passed -  22.013245 file name is -  fSi_4_27.tif
# forg passed -  15.19251 file name is -  fSi_4_23.tif
# forg passed -  19.22109 file name is -  fSi_4_9.tif
# forg passed -  14.218517 file name is -  fSi_4_20.tif
# forg passed -  14.823593 file name is -  fSi_4_32.tif
# forg passed -  17.834248 file name is -  fSi_4_34.tif
# forg passed -  24.017246 file name is -  fSi_4_1.tif
# forg passed -  29.289207 file name is -  fSk_4_5.tif
# forg passed -  24.13363 file name is -  fSi_4_19.tif
# forg passed -  13.933363 file name is -  fSi_4_6.tif
# forg passed -  13.148908 file name is -  fSi_4_33.tif
# forg passed -  19.88005 file name is -  fSi_4_13.tif
# forg passed -  14.225576 file name is -  fSi_4_24.tif
# forg passed -  18.045265 file name is -  fSi_4_15.tif
# forg passed -  22.901768 file name is -  fOh_4_1.tif
# forg passed -  11.787322 file name is -  fSi_4_12.tif
# forg passed -  15.073418 file name is -  fOh_4_2.tif
# forg passed -  22.974453 file name is -  fSk_4_6.tif
# forg passed -  15.63707 file name is -  fSi_4_25.tif
# forg passed -  16.42208 file name is -  fSi_4_16.tif
# forg passed -  17.920902 file name is -  fSi_4_3.tif
# forg passed -  26.233143 file name is -  fSi_4_31.tif
# forg passed -  15.709826 file name is -  fSi_4_29.tif
# forg passed -  11.512074 file name is -  fSi_4_28.tif
# forg passed -  28.284658 file name is -  fSi_4_30.tif
# forg passed -  26.632715 file name is -  fSi_4_4.tif
# forg passed -  19.299177 file name is -  fSi_4_36.tif
# forg passed -  19.985447 file name is -  fSi_4_8.tif
# forg passed -  17.873283 file name is -  fSi_4_22.tif
# forg passed -  23.12859 file name is -  fSk_4_2.tif
# When k is  79
# 79
# forg passed -  11.761638 file name is -  fSi_79_21.tif
# forg passed -  17.03837 file name is -  fSi_79_5.tif
# forg passed -  21.48888 file name is -  fSk_79_1.tif
# forg passed -  12.763914 file name is -  fSi_79_2.tif
# forg passed -  15.26891 file name is -  fSi_79_26.tif
# forg passed -  21.04911 file name is -  fSk_79_3.tif
# forg passed -  27.0835 file name is -  fSi_79_18.tif
# forg passed -  10.1634 file name is -  fSi_79_10.tif
# forg passed -  22.499788 file name is -  fSi_79_29.tif
# forg passed -  16.425116 file name is -  fSi_79_35.tif
# forg passed -  18.230495 file name is -  fSi_79_8.tif
# forg passed -  15.343945 file name is -  fOh_79_1.tif
# forg passed -  18.647196 file name is -  fSi_79_32.tif
# forg passed -  22.9843 file name is -  fSi_79_7.tif
# forg passed -  17.810814 file name is -  fSi_79_19.tif
# forg passed -  15.400094 file name is -  fSi_79_15.tif
# forg passed -  18.910812 file name is -  fSi_79_9.tif
# forg passed -  13.41391 file name is -  fSk_79_6.tif
# forg passed -  21.891663 file name is -  fSi_79_13.tif
# forg passed -  21.594149 file name is -  fSi_79_30.tif
# forg passed -  14.373864 file name is -  fSi_79_24.tif
# forg passed -  23.535566 file name is -  fSi_79_20.tif
# forg passed -  25.402565 file name is -  fSi_79_12.tif
# forg passed -  14.963339 file name is -  fSi_79_4.tif
# forg passed -  19.977055 file name is -  fSi_79_36.tif
# forg passed -  22.981724 file name is -  fSk_79_4.tif
# forg passed -  20.839622 file name is -  fSi_79_1.tif
# forg passed -  18.513186 file name is -  fSi_79_22.tif
# forg passed -  25.15434 file name is -  fSi_79_14.tif
# forg passed -  16.469807 file name is -  fSi_79_34.tif
# forg passed -  23.058702 file name is -  fSi_79_11.tif
# forg passed -  31.877398 file name is -  fSk_79_2.tif
# forg passed -  17.921062 file name is -  fSi_79_23.tif
# forg passed -  22.757124 file name is -  fSi_79_3.tif
# forg passed -  13.325774 file name is -  fSi_79_17.tif
# forg passed -  18.617498 file name is -  fSi_79_16.tif
# forg passed -  16.098915 file name is -  fSi_79_25.tif
# forg passed -  26.203367 file name is -  fSi_79_33.tif
# forg passed -  23.619333 file name is -  fOh_79_2.tif
# forg passed -  17.879541 file name is -  fSi_79_6.tif
# forg passed -  21.8607 file name is -  fSk_79_5.tif
# forg passed -  11.512461 file name is -  fSi_79_27.tif
# forg passed -  23.920177 file name is -  fSi_79_28.tif
# When k is  38
# 38
# gen flagged -  43.471928 file name is -  g_38_24.tif
# gen flagged -  42.531315 file name is -  g_38_14.tif
# gen flagged -  36.683964 file name is -  g_38_13.tif
# gen flagged -  35.0148 file name is -  g_38_27.tif
# gen flagged -  42.878414 file name is -  g_38_22.tif
# gen flagged -  41.50729 file name is -  g_38_20.tif
# gen flagged -  51.204197 file name is -  g_38_17.tif
# gen flagged -  38.174786 file name is -  g_38_19.tif
# gen flagged -  42.65374 file name is -  g_38_23.tif
# gen flagged -  42.256382 file name is -  g_38_26.tif
# gen flagged -  45.04699 file name is -  g_38_15.tif
# gen flagged -  38.53425 file name is -  g_38_11.tif
# forg passed -  17.04652 file name is -  fSi_38_32.tif
# forg passed -  25.840303 file name is -  fSi_38_6.tif
# forg passed -  29.866596 file name is -  fSk_38_4.tif
# forg passed -  22.170942 file name is -  fSk_38_1.tif
# forg passed -  22.810312 file name is -  fSi_38_22.tif
# forg passed -  15.601504 file name is -  fSk_38_5.tif
# forg passed -  27.246761 file name is -  fOh_38_2.tif
# forg passed -  17.74541 file name is -  fSk_38_3.tif
# forg passed -  21.11815 file name is -  fSi_38_36.tif
# forg passed -  16.76239 file name is -  fOh_38_3.tif
# forg passed -  23.35937 file name is -  fOh_38_1.tif
# forg passed -  27.647005 file name is -  fSi_38_15.tif
# forg passed -  12.682505 file name is -  fSk_38_2.tif
# When k is  104
# 104
# forg passed -  22.89004 file name is -  fSk_104_3.tif
# forg passed -  13.290419 file name is -  fSi_104_25.tif
# forg passed -  15.860854 file name is -  fSk_104_5.tif
# forg passed -  28.207674 file name is -  fSi_104_13.tif
# forg passed -  11.776146 file name is -  fSi_104_20.tif
# forg passed -  20.996958 file name is -  fSi_104_10.tif
# forg passed -  6.3815813 file name is -  fSi_104_28.tif
# forg passed -  21.531479 file name is -  fSi_104_9.tif
# forg passed -  29.661396 file name is -  fSi_104_22.tif
# forg passed -  9.27708 file name is -  fOh_104_1.tif
# forg passed -  15.047698 file name is -  fSi_104_2.tif
# forg passed -  30.013758 file name is -  fSk_104_1.tif
# forg passed -  26.293625 file name is -  fSi_104_30.tif
# forg passed -  8.558682 file name is -  fSi_104_11.tif
# forg passed -  24.31484 file name is -  fSi_104_3.tif
# forg passed -  15.534514 file name is -  fSi_104_4.tif
# forg passed -  12.765557 file name is -  fSi_104_26.tif
# forg passed -  12.960177 file name is -  fSk_70_2.tif
# forg passed -  25.368368 file name is -  fSi_70_16.tif
# forg passed -  22.536167 file name is -  fOh_70_3.tif
# forg passed -  10.276414 file name is -  fSi_70_3.tif
# forg passed -  10.333334 file name is -  fSk_70_4.tif
# forg passed -  15.211489 file name is -  fSi_70_4.tif
# forg passed -  20.196297 file name is -  fSi_70_18.tif
# forg passed -  9.233691 file name is -  fSk_70_6.tif
# forg passed -  7.524501 file name is -  fSi_70_8.tif
# forg passed -  10.020266 file name is -  fSk_70_3.tif
# forg passed -  25.136402 file name is -  fSi_70_11.tif
# forg passed -  21.722034 file name is -  fSi_70_34.tif
# forg passed -  25.305765 file name is -  fSi_70_31.tif
# forg passed -  15.124035 file name is -  fSi_70_14.tif
# base_forg_passed is  761
# base_gen_flagged is  58
# False Acceptance Rate (FAR) =  67.64444444444445 %
# False Rejection Rate (FRR) =  8.923076923076923 %

# %%
### This is the code for the base model - duplicated with variables changed ###
#for i in range(3):
  i = 0
  print("Iteration: " + str(i))
  #weight = path + weights[i]
  #baseModel.load_weights(weight)
  
  forg_passed=0
  gen_flagged=0

  for k in test: #the id of signatures you want to check
    print("When k is ", k)
    anc1,anc2,neg,pos=getfilest(k,gent,forgt)
    
    anchor1=returnimages(gent,anc1)
    anchor2=returnimages(gent,anc2)
    for i in range(len(pos)): #pos
        positive=returnimages(gent,pos[i])
        x=baseModel.predict([anchor1,positive,anchor2])
        a1, p, a2 = x[0,0:512], x[0,512:1024], x[0,1024:1536]
        #dist=sum(a-p)
        
        #Taking two distances (two anchor images), and taking average between the two
        dist1=np.linalg.norm(a1-p)
        dist2=np.linalg.norm(a2-p)
        dist=(dist1+dist2)/2
        #print("positive distance is ",dist)
        if(dist>32):
        #  print("0")
            gen_flagged=gen_flagged+1
            print("gen flagged - ",dist, "file name is - ", pos[i])
            
        else:
            gen_flagged=gen_flagged
        #   print("1")
        
    for j in range(len(neg)): #neg
        negative=returnimages(forgt,neg[j])
        x=baseModel.predict([anchor1,negative,anchor2])
        a1, n, a2 = x[0,0:512], x[0,512:1024], x[0,1024:1536]
        #dist=sum(a-n)
        dist1=np.linalg.norm(a1-n)
        dist2=np.linalg.norm(a2-n)
        #print("negative distance is ",dist)
        dist=(dist1+dist2)/2
        if(dist>32):
            forg_passed=forg_passed
          #  print("0")
        else:
            forg_passed=forg_passed+1
            print("forg passed - ",dist, "file name is - ", neg[j])
          #  print("1")

  print("base_forg_passed is ",forg_passed)
  print("base_gen_flagged is ",gen_flagged)
  print("False Acceptance Rate (FAR) = ", str(100*forg_passed/tneg), "%")
  print("False Rejection Rate (FRR) = ", str(100*gen_flagged/tpos), "%")
# Out:
# Iteration: 0
# When k is  68
# forg passed -  29.1103515625 file name is -  fSi_68_2.tif
# forg passed -  13.223434448242188 file name is -  fSi_68_26.tif
# forg passed -  17.15555763244629 file name is -  fSi_68_19.tif
# forg passed -  11.434042930603027 file name is -  fSi_68_27.tif
# forg passed -  20.063549041748047 file name is -  fSi_68_34.tif
# forg passed -  16.937297821044922 file name is -  fSi_68_22.tif
# gen flagged -  36.84518051147461 file name is -  g_111_1.tif
# gen flagged -  32.355201721191406 file name is -  g_111_10.tif
# gen flagged -  40.842811584472656 file name is -  g_111_4.tif
# gen flagged -  35.44403076171875 file name is -  g_111_6.tif
# gen flagged -  34.77835464477539 file name is -  g_111_5.tif
# forg passed -  20.41250228881836 file name is -  fSi_111_7.tif
# forg passed -  30.236783981323242 file name is -  fSi_111_19.tif
# forg passed -  27.283931732177734 file name is -  fSk_111_3.tif
# forg passed -  30.433481216430664 file name is -  fSi_111_13.tif
# forg passed -  19.003223419189453 file name is -  fSi_111_8.tif
# forg passed -  20.331832885742188 file name is -  fSk_111_4.tif
# forg passed -  28.460039138793945 file name is -  fSi_111_23.tif
# forg passed -  23.753421783447266 file name is -  fSi_111_3.tif
# forg passed -  21.811983108520508 file name is -  fSi_111_4.tif
# forg passed -  25.278169631958008 file name is -  fSk_111_5.tif
# forg passed -  31.17368507385254 file name is -  fSi_111_29.tif
# forg passed -  29.326061248779297 file name is -  fSi_111_20.tif
# forg passed -  20.775775909423828 file name is -  fSi_111_14.tif
# forg passed -  25.304340362548828 file name is -  fSk_111_1.tif
# forg passed -  30.323205947875977 file name is -  fOh_111_2.tif
# When k is  32
# gen flagged -  33.160640716552734 file name is -  g_32_19.tif
# forg passed -  21.512611389160156 file name is -  fSi_32_21.tif
# forg passed -  29.84337615966797 file name is -  fSi_32_22.tif
# forg passed -  18.665903091430664 file name is -  fSk_32_3.tif
# forg passed -  26.29193878173828 file name is -  fSi_32_16.tif
# forg passed -  28.576553344726562 file name is -  fSk_32_6.tif
# forg passed -  16.67886734008789 file name is -  fSi_32_10.tif
# forg passed -  27.223644256591797 file name is -  fSi_32_30.tif
# forg passed -  25.93368148803711 file name is -  fSi_32_1.tif
# forg passed -  12.256729125976562 file name is -  fSi_32_24.tif
# forg passed -  21.127763748168945 file name is -  fSi_32_27.tif
# forg passed -  23.10915184020996 file name is -  fSi_32_26.tif
# forg passed -  28.01473617553711 file name is -  fSi_32_19.tif
# forg passed -  23.712825775146484 file name is -  fSk_32_2.tif
# forg passed -  24.372791290283203 file name is -  fSk_32_4.tif
# forg passed -  27.88811492919922 file name is -  fSi_32_29.tif
# When k is  67
# forg passed -  20.554967880249023 file name is -  fSi_67_5.tif
# forg passed -  24.38344383239746 file name is -  fSi_67_6.tif
# forg passed -  21.08942413330078 file name is -  fSi_67_18.tif
# forg passed -  27.969268798828125 file name is -  fSi_67_13.tif
# forg passed -  21.08722686767578 file name is -  fSi_67_14.tif
# forg passed -  25.856290817260742 file name is -  fSi_67_8.tif
# forg passed -  16.726001739501953 file name is -  fSi_67_31.tif
# forg passed -  24.551647186279297 file name is -  fSi_67_22.tif
# forg passed -  15.785493850708008 file name is -  fSi_67_17.tif
# forg passed -  26.88980484008789 file name is -  fSk_67_5.tif
# forg passed -  20.168962478637695 file name is -  fSi_67_26.tif
# forg passed -  24.804363250732422 file name is -  fSi_67_9.tif
# forg passed -  21.464452743530273 file name is -  fSi_67_3.tif
# forg passed -  28.274124145507812 file name is -  fSi_67_12.tif
# forg passed -  19.460664749145508 file name is -  fSi_67_30.tif
# forg passed -  17.354591369628906 file name is -  fSk_67_6.tif
# forg passed -  19.50957489013672 file name is -  fSi_67_32.tif
# forg passed -  22.686220169067383 file name is -  fSi_67_16.tif
# forg passed -  18.273738861083984 file name is -  fOh_67_2.tif
# forg passed -  23.28634262084961 file name is -  fSk_67_1.tif
# forg passed -  19.37311553955078 file name is -  fSi_67_2.tif
# forg passed -  23.96840476989746 file name is -  fSi_67_35.tif
# forg passed -  20.10327911376953 file name is -  fSi_67_36.tif
# forg passed -  19.394832611083984 file name is -  fSi_67_24.tif
# forg passed -  18.194217681884766 file name is -  fSi_67_1.tif
# forg passed -  15.440437316894531 file name is -  fSi_67_21.tif
# forg passed -  18.4731388092041 file name is -  fSi_67_4.tif
# forg passed -  18.435617446899414 file name is -  fSi_67_7.tif
# forg passed -  15.540626525878906 file name is -  fSi_67_10.tif
# forg passed -  20.772510528564453 file name is -  fSi_67_34.tif
# forg passed -  19.597007751464844 file name is -  fSi_67_11.tif
# forg passed -  31.007614135742188 file name is -  fSi_67_25.tif
# forg passed -  18.13490867614746 file name is -  fSk_67_4.tif
# forg passed -  27.562206268310547 file name is -  fSk_67_3.tif
# forg passed -  20.644542694091797 file name is -  fSi_67_23.tif
# forg passed -  19.400470733642578 file name is -  fSi_67_33.tif
# forg passed -  25.488208770751953 file name is -  fSi_67_29.tif
# forg passed -  28.805648803710938 file name is -  fSi_67_27.tif
# forg passed -  22.698036193847656 file name is -  fSi_67_20.tif
# forg passed -  16.557899475097656 file name is -  fSi_67_19.tif
# forg passed -  20.073078155517578 file name is -  fOh_67_1.tif
# forg passed -  22.349990844726562 file name is -  fSi_67_28.tif
# When k is  1
# forg passed -  24.91364860534668 file name is -  fSi_1_13.tif
# forg passed -  18.90087127685547 file name is -  fSk_1_4.tif
# forg passed -  16.347227096557617 file name is -  fSi_1_3.tif
# forg passed -  21.931259155273438 file name is -  fOh_1_2.tif
# forg passed -  29.679779052734375 file name is -  fSi_1_14.tif
# forg passed -  20.92254638671875 file name is -  fSi_1_27.tif
# forg passed -  11.50027847290039 file name is -  fSi_1_10.tif
# forg passed -  25.22916603088379 file name is -  fSi_1_8.tif
# forg passed -  20.888702392578125 file name is -  fSi_1_17.tif
# forg passed -  10.485246658325195 file name is -  fSi_1_11.tif
# forg passed -  13.683061599731445 file name is -  fSi_1_19.tif
# forg passed -  20.789470672607422 file name is -  fSk_1_3.tif
# forg passed -  16.164657592773438 file name is -  fSi_1_20.tif
# forg passed -  21.403518676757812 file name is -  fSi_1_5.tif
# forg passed -  15.5774507522583 file name is -  fSi_1_33.tif
# forg passed -  17.209911346435547 file name is -  fOh_1_1.tif
# forg passed -  30.55276107788086 file name is -  fSi_1_31.tif
# forg passed -  17.173851013183594 file name is -  fSi_1_34.tif
# forg passed -  28.680057525634766 file name is -  fSi_1_2.tif
# forg passed -  23.968212127685547 file name is -  fSk_1_5.tif
# forg passed -  26.822063446044922 file name is -  fOh_1_3.tif
# forg passed -  16.99932861328125 file name is -  fSi_1_28.tif
# forg passed -  17.286399841308594 file name is -  fSi_1_29.tif
# forg passed -  19.543071746826172 file name is -  fSi_1_21.tif
# forg passed -  11.980157852172852 file name is -  fSi_1_18.tif
# forg passed -  15.762664794921875 file name is -  fSi_1_9.tif
# forg passed -  14.010781288146973 file name is -  fSk_1_1.tif
# forg passed -  28.845842361450195 file name is -  fSi_1_7.tif
# forg passed -  13.991456985473633 file name is -  fSi_1_1.tif
# forg passed -  16.794326782226562 file name is -  fSi_1_30.tif
# forg passed -  19.445476531982422 file name is -  fSk_1_2.tif
# forg passed -  20.054832458496094 file name is -  fSi_1_16.tif
# forg passed -  13.888387680053711 file name is -  fSi_1_25.tif
# forg passed -  12.727405548095703 file name is -  fSi_1_26.tif
# forg passed -  15.832077026367188 file name is -  fSi_1_24.tif
# forg passed -  16.883541107177734 file name is -  fSk_1_6.tif
# When k is  60
# gen flagged -  32.96334457397461 file name is -  g_60_26.tif
# gen flagged -  44.75325012207031 file name is -  g_60_27.tif
# gen flagged -  36.44465637207031 file name is -  g_60_17.tif
# gen flagged -  35.15583038330078 file name is -  g_60_15.tif
# gen flagged -  51.21253967285156 file name is -  g_60_13.tif
# gen flagged -  37.80775451660156 file name is -  g_60_16.tif
# gen flagged -  43.28976821899414 file name is -  g_60_2.tif
# gen flagged -  34.58653259277344 file name is -  g_60_20.tif
# gen flagged -  37.24943923950195 file name is -  g_60_24.tif
# gen flagged -  35.83232879638672 file name is -  g_60_19.tif
# gen flagged -  35.340049743652344 file name is -  g_60_11.tif
# forg passed -  23.79835319519043 file name is -  fSi_60_35.tif
# forg passed -  26.512958526611328 file name is -  fSk_60_4.tif
# forg passed -  20.046436309814453 file name is -  fSi_60_6.tif
# forg passed -  25.384944915771484 file name is -  fSi_60_30.tif
# forg passed -  31.338830947875977 file name is -  fSi_60_20.tif
# forg passed -  30.79034423828125 file name is -  fSi_60_26.tif
# forg passed -  21.499006271362305 file name is -  fSk_60_1.tif
# forg passed -  25.47482681274414 file name is -  fSi_60_25.tif
# When k is  11
# forg passed -  10.537322044372559 file name is -  fSk_11_3.tif
# forg passed -  27.94542694091797 file name is -  fSi_11_30.tif
# forg passed -  19.381431579589844 file name is -  fSi_11_16.tif
# forg passed -  9.934000015258789 file name is -  fSk_11_6.tif
# forg passed -  12.481521606445312 file name is -  fSi_11_22.tif
# forg passed -  6.389072418212891 file name is -  fSi_11_17.tif
# forg passed -  13.462417602539062 file name is -  fSi_11_23.tif
# forg passed -  23.475631713867188 file name is -  fSi_11_1.tif
# forg passed -  8.250155448913574 file name is -  fSi_11_29.tif
# forg passed -  21.186599731445312 file name is -  fSi_11_5.tif
# forg passed -  14.433416366577148 file name is -  fSi_11_4.tif
# forg passed -  30.750558853149414 file name is -  fSi_11_24.tif
# forg passed -  23.64430809020996 file name is -  fSi_11_13.tif
# forg passed -  24.198213577270508 file name is -  fSi_11_27.tif
# forg passed -  12.000823974609375 file name is -  fSi_11_18.tif
# forg passed -  18.498205184936523 file name is -  fSk_80_5.tif
# forg passed -  23.950565338134766 file name is -  fSi_80_11.tif
# When k is  4
# forg passed -  23.15884017944336 file name is -  fSi_4_2.tif
# forg passed -  30.736095428466797 file name is -  fSk_4_4.tif
# forg passed -  14.591226577758789 file name is -  fSi_4_35.tif
# forg passed -  27.3712158203125 file name is -  fSk_4_1.tif
# forg passed -  18.30204200744629 file name is -  fSi_4_14.tif
# forg passed -  13.450700759887695 file name is -  fSi_4_11.tif
# forg passed -  25.026275634765625 file name is -  fSi_4_7.tif
# forg passed -  24.259357452392578 file name is -  fSi_4_17.tif
# forg passed -  29.23651885986328 file name is -  fSi_4_10.tif
# forg passed -  24.424060821533203 file name is -  fSi_4_18.tif
# forg passed -  25.678237915039062 file name is -  fSi_4_5.tif
# forg passed -  13.804925918579102 file name is -  fSi_4_26.tif
# forg passed -  25.197341918945312 file name is -  fSi_4_27.tif
# forg passed -  18.24053192138672 file name is -  fSi_4_23.tif
# forg passed -  17.618669509887695 file name is -  fSi_4_9.tif
# forg passed -  16.691059112548828 file name is -  fSi_4_20.tif
# forg passed -  12.327259063720703 file name is -  fSi_4_32.tif
# forg passed -  15.50265884399414 file name is -  fSi_4_34.tif
# forg passed -  22.677478790283203 file name is -  fSi_4_1.tif
# forg passed -  22.334165573120117 file name is -  fSi_4_19.tif
# forg passed -  11.498847961425781 file name is -  fSi_4_6.tif
# forg passed -  11.437939643859863 file name is -  fSi_4_33.tif
# forg passed -  23.26610565185547 file name is -  fSi_4_13.tif
# forg passed -  16.98548698425293 file name is -  fSi_4_24.tif
# forg passed -  15.878377914428711 file name is -  fSi_4_15.tif
# forg passed -  25.764339447021484 file name is -  fOh_4_1.tif
# forg passed -  11.791985511779785 file name is -  fSi_4_12.tif
# forg passed -  13.568395614624023 file name is -  fOh_4_2.tif
# forg passed -  26.33209228515625 file name is -  fSk_4_6.tif
# forg passed -  17.827617645263672 file name is -  fSi_4_25.tif
# forg passed -  13.257467269897461 file name is -  fSi_4_16.tif
# forg passed -  16.707996368408203 file name is -  fSi_4_3.tif
# forg passed -  23.60504913330078 file name is -  fSi_4_31.tif
# forg passed -  18.5008602142334 file name is -  fSi_4_29.tif
# forg passed -  13.898548126220703 file name is -  fSi_4_28.tif
# forg passed -  31.06635284423828 file name is -  fSi_4_30.tif
# forg passed -  24.310466766357422 file name is -  fSi_4_4.tif
# forg passed -  17.38888168334961 file name is -  fSi_4_36.tif
# forg passed -  17.235984802246094 file name is -  fSi_4_8.tif
# forg passed -  14.380358695983887 file name is -  fSi_4_22.tif
# forg passed -  27.66953468322754 file name is -  fSk_4_2.tif
# When k is  79
# forg passed -  21.576723098754883 file name is -  fSi_79_21.tif
# forg passed -  19.760530471801758 file name is -  fSi_79_5.tif
# forg passed -  22.429035186767578 file name is -  fSk_79_1.tif
# forg passed -  23.593067169189453 file name is -  fSi_79_2.tif
# forg passed -  20.977298736572266 file name is -  fSi_79_26.tif
# forg passed -  18.86078643798828 file name is -  fSk_79_3.tif
# forg passed -  19.143733978271484 file name is -  fSi_79_10.tif
# forg passed -  23.125608444213867 file name is -  fSi_79_29.tif
# forg passed -  26.451892852783203 file name is -  fSi_79_35.tif
# forg passed -  17.6814022064209 file name is -  fSi_79_8.tif
# forg passed -  19.261940002441406 file name is -  fOh_79_1.tif
# forg passed -  23.33094024658203 file name is -  fSi_79_32.tif
# forg passed -  22.8203182220459 file name is -  fSi_79_7.tif
# forg passed -  22.675857543945312 file name is -  fSi_79_19.tif
# forg passed -  23.190853118896484 file name is -  fSi_79_15.tif
# forg passed -  18.339553833007812 file name is -  fSi_79_9.tif
# forg passed -  19.780969619750977 file name is -  fSk_79_6.tif
# forg passed -  19.217809677124023 file name is -  fSi_79_13.tif
# forg passed -  25.694229125976562 file name is -  fSi_79_24.tif
# forg passed -  22.978492736816406 file name is -  fSi_79_20.tif
# forg passed -  22.69141387939453 file name is -  fSi_79_4.tif
# forg passed -  30.118783950805664 file name is -  fSi_79_36.tif
# forg passed -  19.096473693847656 file name is -  fSk_79_4.tif
# forg passed -  26.890344619750977 file name is -  fSi_79_1.tif
# forg passed -  27.387718200683594 file name is -  fSi_79_22.tif
# forg passed -  22.630769729614258 file name is -  fSi_79_14.tif
# forg passed -  20.147106170654297 file name is -  fSi_79_34.tif
# forg passed -  25.565303802490234 file name is -  fSi_79_11.tif
# forg passed -  24.19565200805664 file name is -  fSk_79_2.tif
# forg passed -  21.91089630126953 file name is -  fSi_79_23.tif
# forg passed -  21.936307907104492 file name is -  fSi_79_3.tif
# forg passed -  19.039262771606445 file name is -  fSi_79_17.tif
# forg passed -  22.068574905395508 file name is -  fSi_79_16.tif
# forg passed -  22.908294677734375 file name is -  fSi_79_25.tif
# forg passed -  25.166759490966797 file name is -  fSi_79_33.tif
# forg passed -  29.60881805419922 file name is -  fOh_79_2.tif
# forg passed -  27.204326629638672 file name is -  fSi_79_6.tif
# forg passed -  18.068065643310547 file name is -  fSk_79_5.tif
# forg passed -  20.035985946655273 file name is -  fSi_79_27.tif
# forg passed -  27.81389617919922 file name is -  fSi_79_28.tif
# When k is  38
# gen flagged -  43.77729415893555 file name is -  g_38_24.tif
# gen flagged -  42.0815315246582 file name is -  g_38_14.tif
# gen flagged -  36.32685852050781 file name is -  g_38_13.tif
# gen flagged -  34.326759338378906 file name is -  g_38_27.tif
# gen flagged -  40.312278747558594 file name is -  g_38_22.tif
# gen flagged -  40.067752838134766 file name is -  g_38_20.tif
# gen flagged -  51.03834915161133 file name is -  g_38_17.tif
# gen flagged -  39.24846649169922 file name is -  g_38_19.tif
# gen flagged -  32.137046813964844 file name is -  g_38_16.tif
# gen flagged -  42.72593688964844 file name is -  g_38_23.tif
# gen flagged -  40.99573516845703 file name is -  g_38_26.tif
# gen flagged -  44.90465545654297 file name is -  g_38_15.tif
# gen flagged -  39.13044738769531 file name is -  g_38_11.tif
# forg passed -  20.09735107421875 file name is -  fSi_38_32.tif
# forg passed -  27.415416717529297 file name is -  fSi_38_6.tif
# forg passed -  31.898696899414062 file name is -  fSk_38_4.tif
